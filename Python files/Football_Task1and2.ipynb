# %% [markdown]
# # International football results from 1872 to 2019

# %% [markdown]
# ## Context
#
# Well, what happened was that I was looking for a semi-definite easy-to-read list of international football matches and couldn't find anything decent. So I took it upon myself to collect it for my own use. I might as well share it.
#
# ## Content
#
# This dataset includes 40,838 results of international football matches starting from the very first official match in 1972 up to 2019. The matches range from FIFA World Cup to FIFI Wild Cup to regular friendly matches. The matches are strictly men's full internationals and the data does not include Olympic Games or matches where at least one of the teams was the nation's B-team, U-23 or a league select team.
#
# 'results.csv' includes the following columns:
#
# 1. date - date of the match
# 2. home_team - the name of the home team
# 3. away_team - the name of the away team
# 4. home_score - full-time home team score including extra time, not including penalty-shootouts
# 5. away_score - full-time away team score including extra time, not including penalty-shootouts
# 6. tournament - the name of the tournament
# 7. city - the name of the city/town/administrative unit where the match was played
# 8. country - the name of the country where the match was played
# 9. neutral - TRUE/FALSE column indicating whether the match was played at a neutral venue
#
#
# Note on team and country names: For home and away teams the current name of the team has been used. For example, when in 1882 a team who called themselves Ireland played against England, in this dataset, it is called Northern Ireland because the current team of Northern Ireland is the successor of the 1882 Ireland team. This is done so it is easier to track the history and statistics of teams.
#
# For country names, the name of the country at the time of the match is used. So when Ghana played in Accra, Gold Coast in the 1950s, even though the names of the home team and the country don't match, it was a home match for Ghana. This is indicated by the neutral column, which says FALSE for those matches, meaning it was not at a neutral venue.
#
# ## Acknowledgements
#
# The data is gathered from several sources including but not limited to Wikipedia, fifa.com, rsssf.com and individual football associations' websites.
#
# ## Inspiration
#
# Some directions to take when exploring the data:
#
# 1. Who is the best team of all time
# 2. Which teams dominated different eras of football
# 3. What trends have there been in international football throughout the ages - home advantage, total goals scored, distribution of teams' strength etc
# 4. Can we say anything about geopolitics from football fixtures - how has the number of countries changed, which teams like to play each other
# 5. Which countries host the most matches where they themselves are not participating in
# 6. How much, if at all, does hosting a major tournament help a country's chances in the tournament
# 7. Which teams are the most active in playing friendlies and friendly tournaments - does it help or hurt them
#
# The world's your oyster, my friend.

# %% [markdown]
# # Stage 1 - Import the Dataset and Libraries:

# %% [markdown]
# ## Import Libraries:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Code for Parallelising this workflow:

# %%
from multiprocessing import  Pool

def parallelize_dataframe(df, func, n_cores=5):
    df_split = np.array_split(df, n_cores)
    pool = Pool(n_cores)
#     df = pd.concat(pool.map(func, df_split))
    dictionary = (pool.map(func, df_split))
    pool.close()
    pool.join()
#     return df
    return dictionary

# %% [markdown]
# ## Import Dataset:

# %%
path_directory = '/Users/y.s.lee/OneDrive/MSc Data Science/Semester 3/Data VIsualisation NEW (COMP5048)/Assignments/Assignment 2/Data/'

data_football_original = pd.read_csv(path_directory + 'results.csv')

# %% [markdown]
# # Stage 2 - Review the Dataset:

# %%
data_football = data_football_original.copy()
data_football.head()
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland           2           2   Friendly   London
# 4  1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#     country  neutral
# 0  Scotland    False
# 1   England    False
# 2  Scotland    False
# 3   England    False
# 4  Scotland    False

# %%
data_football.tail()
# Out:
#              date         home_team        away_team  home_score  away_score  \
# 40834  2019-07-18    American Samoa           Tahiti           8           1
# 40835  2019-07-18              Fiji  Solomon Islands           4           4
# 40836  2019-07-19           Senegal          Algeria           0           1
# 40837  2019-07-19        Tajikistan      North Korea           0           1
# 40838  2019-07-20  Papua New Guinea             Fiji           1           1
#
#                    tournament       city country  neutral
# 40834           Pacific Games       Apia   Samoa     True
# 40835           Pacific Games       Apia   Samoa     True
# 40836  African Cup of Nations      Cairo   Egypt     True
# 40837    Intercontinental Cup  Ahmedabad   India     True
# 40838           Pacific Games       Apia   Samoa     True

# %%
data_football.shape
# Out:
# (40839, 9)

# %%
data_football.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40839 entries, 0 to 40838
# Data columns (total 9 columns):
# date          40839 non-null object
# home_team     40839 non-null object
# away_team     40839 non-null object
# home_score    40839 non-null int64
# away_score    40839 non-null int64
# tournament    40839 non-null object
# city          40839 non-null object
# country       40839 non-null object
# neutral       40839 non-null bool
# dtypes: bool(1), int64(2), object(6)
# memory usage: 2.5+ MB

# %% [markdown]
# # Stage 3 - Clean the Dataset:

# %%
# Visualise it:

plt.figure(figsize=(10,10))
sns.heatmap(data_football.isnull(), cbar = False, cmap = "YlGnBu")

# %% [markdown]
# From the figure above, it seems like the dataset is complete and does not have missing data.

# %% [markdown]
# # Stage 4 - Exploratory Data Analysis:

# %% [markdown]
# ### List the unique types of tournament:

# %%
data_football.tournament.unique()
# Out:
# array(['Friendly', 'British Championship', 'Copa Lipton', 'Copa Newton',
#        'Copa Premio Honor Argentino', 'Copa Premio Honor Uruguayo',
#        'Copa Roca', 'Copa América', 'Copa Chevallier Boutell',
#        'Nordic Championship', 'International Cup', 'Baltic Cup',
#        'Balkan Cup', 'FIFA World Cup', 'Copa Rio Branco',
#        'FIFA World Cup qualification', 'CCCF Championship',
#        'NAFU Championship', 'Copa Oswaldo Cruz',
#        'Pan American Championship', 'Copa del Pacífico',
#        "Copa Bernardo O'Higgins", 'AFC Asian Cup qualification',
#        'Atlantic Cup', 'AFC Asian Cup', 'African Cup of Nations',
#        'Copa Paz del Chaco', 'Merdeka Tournament',
#        'UEFA Euro qualification', 'UEFA Euro',
#        'Windward Islands Tournament',
#        'African Cup of Nations qualification', 'Vietnam Independence Cup',
#        'Copa Carlos Dittborn', 'CONCACAF Championship',
#        'Copa Juan Pinto Durán', 'UAFA Cup', 'South Pacific Games',
#        'CONCACAF Championship qualification', 'Copa Artigas', 'GaNEFo',
#        "King's Cup", 'Gulf Cup', 'Indonesia Tournament', 'Korea Cup',
#        'Brazil Independence Cup', 'Copa Ramón Castilla',
#        'Oceania Nations Cup', 'CECAFA Cup', 'Copa Félix Bogado',
#        'Kirin Cup', 'CFU Caribbean Cup qualification',
#        'CFU Caribbean Cup', 'Amílcar Cabral Cup', 'Mundialito',
#        'West African Cup', 'Nehru Cup', 'Merlion Cup', 'UDEAC Cup',
#        'Rous Cup', 'Lunar New Year Cup', 'Tournoi de France',
#        'Malta International Tournament', 'Island Games', 'Dynasty Cup',
#        'UNCAF Cup', 'Gold Cup', 'USA Cup',
#        'Jordan International Tournament', 'Confederations Cup',
#        'United Arab Emirates Friendship Tournament',
#        'Oceania Nations Cup qualification', 'Simba Tournament',
#        'SAFF Cup', 'AFF Championship', 'King Hassan II Tournament',
#        'Cyprus International Tournament', 'Dunhill Cup', 'COSAFA Cup',
#        'Gold Cup qualification', 'SKN Football Festival', 'UNIFFAC Cup',
#        'WAFF Championship', 'Millennium Cup', "Prime Minister's Cup",
#        'EAFF Championship', 'AFC Challenge Cup', 'FIFI Wild Cup',
#        'ELF Cup', 'Viva World Cup', 'UAFA Cup qualification',
#        'AFC Challenge Cup qualification', 'African Nations Championship',
#        'VFF Cup', 'Dragon Cup', 'ABCS Tournament',
#        'Nile Basin Tournament', 'Nations Cup', 'Pacific Games', 'OSN Cup',
#        'CONIFA World Football Cup', 'CONIFA European Football Cup',
#        'Copa América qualification', 'World Unity Cup',
#        'Intercontinental Cup', 'AFF Championship qualification',
#        'UEFA Nations League', 'Atlantic Heritage Cup',
#        'Inter Games Football Tournament'], dtype=object)

# %% [markdown]
# ### Determine how many matches in each tournament:

# %%
data_football.tournament.value_counts()
# Out:
# Friendly                                16911
# FIFA World Cup qualification             7100
# UEFA Euro qualification                  2432
# African Cup of Nations qualification     1616
# FIFA World Cup                            900
# Copa América                              813
# AFC Asian Cup qualification               724
# African Cup of Nations                    690
# CECAFA Cup                                620
# CFU Caribbean Cup qualification           606
# Merdeka Tournament                        503
# British Championship                      501
# AFC Asian Cup                             370
# Island Games                              350
# Gulf Cup                                  333
# Gold Cup                                  327
# AFF Championship                          293
# COSAFA Cup                                292
# UEFA Euro                                 286
# Nordic Championship                       283
# African Nations Championship              268
# CFU Caribbean Cup                         251
# Amílcar Cabral Cup                        235
# King's Cup                                234
# South Pacific Games                       205
# UNCAF Cup                                 164
# Korea Cup                                 159
# UEFA Nations League                       142
# Confederations Cup                        140
# SAFF Cup                                  136
#                                         ...
# Copa Premio Honor Uruguayo                 15
# UNIFFAC Cup                                15
# Dunhill Cup                                15
# Millennium Cup                             15
# GaNEFo                                     14
# Nile Basin Tournament                      14
# Intercontinental Cup                       14
# Copa Artigas                               13
# Jordan International Tournament            13
# King Hassan II Tournament                  12
# Copa Premio Honor Argentino                12
# Atlantic Cup                               11
# Rous Cup                                   11
# SKN Football Festival                      11
# Copa Bernardo O'Higgins                    10
# Tournoi de France                          10
# FIFI Wild Cup                              10
# VFF Cup                                     9
# UAFA Cup qualification                      9
# NAFU Championship                           7
# Mundialito                                  7
# Copa Félix Bogado                           6
# Copa Ramón Castilla                         6
# Nations Cup                                 6
# Dragon Cup                                  4
# OSN Cup                                     4
# World Unity Cup                             4
# Atlantic Heritage Cup                       2
# Copa América qualification                  2
# AFF Championship qualification              2
# Name: tournament, Length: 109, dtype: int64

# %% [markdown]
# ### Visualise the popularity of the tournaments:

# %%
data_football_tournamentCount = data_football.tournament.value_counts().to_frame().reset_index().rename(columns={'tournament': 'count', 'index': 'tournament'})
data_football_tournamentCount
# Out:
#                                tournament  count
# 0                                Friendly  16911
# 1            FIFA World Cup qualification   7100
# 2                 UEFA Euro qualification   2432
# 3    African Cup of Nations qualification   1616
# 4                          FIFA World Cup    900
# 5                            Copa América    813
# 6             AFC Asian Cup qualification    724
# 7                  African Cup of Nations    690
# 8                              CECAFA Cup    620
# 9         CFU Caribbean Cup qualification    606
# 10                     Merdeka Tournament    503
# 11                   British Championship    501
# 12                          AFC Asian Cup    370
# 13                           Island Games    350
# 14                               Gulf Cup    333
# 15                               Gold Cup    327
# 16                       AFF Championship    293
# 17                             COSAFA Cup    292
# 18                              UEFA Euro    286
# 19                    Nordic Championship    283
# 20           African Nations Championship    268
# 21                      CFU Caribbean Cup    251
# 22                     Amílcar Cabral Cup    235
# 23                             King's Cup    234
# 24                    South Pacific Games    205
# 25                              UNCAF Cup    164
# 26                              Korea Cup    159
# 27                    UEFA Nations League    142
# 28                     Confederations Cup    140
# 29                               SAFF Cup    136
# ..                                    ...    ...
# 79             Copa Premio Honor Uruguayo     15
# 80                            UNIFFAC Cup     15
# 81                            Dunhill Cup     15
# 82                         Millennium Cup     15
# 83                                 GaNEFo     14
# 84                  Nile Basin Tournament     14
# 85                   Intercontinental Cup     14
# 86                           Copa Artigas     13
# 87        Jordan International Tournament     13
# 88              King Hassan II Tournament     12
# 89            Copa Premio Honor Argentino     12
# 90                           Atlantic Cup     11
# 91                               Rous Cup     11
# 92                  SKN Football Festival     11
# 93                Copa Bernardo O'Higgins     10
# 94                      Tournoi de France     10
# 95                          FIFI Wild Cup     10
# 96                                VFF Cup      9
# 97                 UAFA Cup qualification      9
# 98                      NAFU Championship      7
# 99                             Mundialito      7
# 100                     Copa Félix Bogado      6
# 101                   Copa Ramón Castilla      6
# 102                           Nations Cup      6
# 103                            Dragon Cup      4
# 104                               OSN Cup      4
# 105                       World Unity Cup      4
# 106                 Atlantic Heritage Cup      2
# 107            Copa América qualification      2
# 108        AFF Championship qualification      2
#
# [109 rows x 2 columns]

# %%
print('The number of Tournaments are =', (len(data_football_tournamentCount)-1))
# Out:
# The number of Tournaments are = 108

# %%
plt.figure(figsize=(16,10))

g = sns.barplot(x='tournament',
            y='count',
            hue=None,
            data=data_football_tournamentCount,
            hue_order=None)

loc, labels = plt.xticks()
g.set_xticklabels(labels, rotation=90)
# Out:
# [Text(0, 0, 'Friendly'),
#  Text(0, 0, 'FIFA World Cup qualification'),
#  Text(0, 0, 'UEFA Euro qualification'),
#  Text(0, 0, 'African Cup of Nations qualification'),
#  Text(0, 0, 'FIFA World Cup'),
#  Text(0, 0, 'Copa América'),
#  Text(0, 0, 'AFC Asian Cup qualification'),
#  Text(0, 0, 'African Cup of Nations'),
#  Text(0, 0, 'CECAFA Cup'),
#  Text(0, 0, 'CFU Caribbean Cup qualification'),
#  Text(0, 0, 'Merdeka Tournament'),
#  Text(0, 0, 'British Championship'),
#  Text(0, 0, 'AFC Asian Cup'),
#  Text(0, 0, 'Island Games'),
#  Text(0, 0, 'Gulf Cup'),
#  Text(0, 0, 'Gold Cup'),
#  Text(0, 0, 'AFF Championship'),
#  Text(0, 0, 'COSAFA Cup'),
#  Text(0, 0, 'UEFA Euro'),
#  Text(0, 0, 'Nordic Championship'),
#  Text(0, 0, 'African Nations Championship'),
#  Text(0, 0, 'CFU Caribbean Cup'),
#  Text(0, 0, 'Amílcar Cabral Cup'),
#  Text(0, 0, "King's Cup"),
#  Text(0, 0, 'South Pacific Games'),
#  Text(0, 0, 'UNCAF Cup'),
#  Text(0, 0, 'Korea Cup'),
#  Text(0, 0, 'UEFA Nations League'),
#  Text(0, 0, 'Confederations Cup'),
#  Text(0, 0, 'SAFF Cup'),
#  Text(0, 0, 'International Cup'),
#  Text(0, 0, 'CCCF Championship'),
#  Text(0, 0, 'UAFA Cup'),
#  Text(0, 0, 'EAFF Championship'),
#  Text(0, 0, 'CONIFA World Football Cup'),
#  Text(0, 0, 'Oceania Nations Cup'),
#  Text(0, 0, 'Windward Islands Tournament'),
#  Text(0, 0, 'AFC Challenge Cup'),
#  Text(0, 0, 'WAFF Championship'),
#  Text(0, 0, 'AFC Challenge Cup qualification'),
#  Text(0, 0, 'Nehru Cup'),
#  Text(0, 0, 'Balkan Cup'),
#  Text(0, 0, 'Baltic Cup'),
#  Text(0, 0, 'Indonesia Tournament'),
#  Text(0, 0, 'Cyprus International Tournament'),
#  Text(0, 0, 'Oceania Nations Cup qualification'),
#  Text(0, 0, 'Kirin Cup'),
#  Text(0, 0, 'UDEAC Cup'),
#  Text(0, 0, 'Vietnam Independence Cup'),
#  Text(0, 0, 'Gold Cup qualification'),
#  Text(0, 0, 'Viva World Cup'),
#  Text(0, 0, 'West African Cup'),
#  Text(0, 0, 'Malta International Tournament'),
#  Text(0, 0, 'Pacific Games'),
#  Text(0, 0, 'CONIFA European Football Cup'),
#  Text(0, 0, 'CONCACAF Championship'),
#  Text(0, 0, 'Pan American Championship'),
#  Text(0, 0, 'Brazil Independence Cup'),
#  Text(0, 0, 'USA Cup'),
#  Text(0, 0, 'United Arab Emirates Friendship Tournament'),
#  Text(0, 0, 'Dynasty Cup'),
#  Text(0, 0, 'Copa Chevallier Boutell'),
#  Text(0, 0, 'Copa Lipton'),
#  Text(0, 0, 'Copa Newton'),
#  Text(0, 0, 'Merlion Cup'),
#  Text(0, 0, 'Lunar New Year Cup'),
#  Text(0, 0, 'Copa Roca'),
#  Text(0, 0, 'Copa Paz del Chaco'),
#  Text(0, 0, "Prime Minister's Cup"),
#  Text(0, 0, 'CONCACAF Championship qualification'),
#  Text(0, 0, 'ABCS Tournament'),
#  Text(0, 0, 'Inter Games Football Tournament'),
#  Text(0, 0, 'Copa del Pacífico'),
#  Text(0, 0, 'Copa Rio Branco'),
#  Text(0, 0, 'Simba Tournament'),
#  Text(0, 0, 'Copa Juan Pinto Durán'),
#  Text(0, 0, 'Copa Carlos Dittborn'),
#  Text(0, 0, 'Copa Oswaldo Cruz'),
#  Text(0, 0, 'ELF Cup'),
#  Text(0, 0, 'Copa Premio Honor Uruguayo'),
#  Text(0, 0, 'UNIFFAC Cup'),
#  Text(0, 0, 'Dunhill Cup'),
#  Text(0, 0, 'Millennium Cup'),
#  Text(0, 0, 'GaNEFo'),
#  Text(0, 0, 'Nile Basin Tournament'),
#  Text(0, 0, 'Intercontinental Cup'),
#  Text(0, 0, 'Copa Artigas'),
#  Text(0, 0, 'Jordan International Tournament'),
#  Text(0, 0, 'King Hassan II Tournament'),
#  Text(0, 0, 'Copa Premio Honor Argentino'),
#  Text(0, 0, 'Atlantic Cup'),
#  Text(0, 0, 'Rous Cup'),
#  Text(0, 0, 'SKN Football Festival'),
#  Text(0, 0, "Copa Bernardo O'Higgins"),
#  Text(0, 0, 'Tournoi de France'),
#  Text(0, 0, 'FIFI Wild Cup'),
#  Text(0, 0, 'VFF Cup'),
#  Text(0, 0, 'UAFA Cup qualification'),
#  Text(0, 0, 'NAFU Championship'),
#  Text(0, 0, 'Mundialito'),
#  Text(0, 0, 'Copa Félix Bogado'),
#  Text(0, 0, 'Copa Ramón Castilla'),
#  Text(0, 0, 'Nations Cup'),
#  Text(0, 0, 'Dragon Cup'),
#  Text(0, 0, 'OSN Cup'),
#  Text(0, 0, 'World Unity Cup'),
#  Text(0, 0, 'Atlantic Heritage Cup'),
#  Text(0, 0, 'Copa América qualification'),
#  Text(0, 0, 'AFF Championship qualification')]

# %% [markdown]
# ### Split the above visualisation into smaller parts:

# %%
plt.figure(figsize=(16,10))

g = sns.barplot(x='tournament',
            y='count',
            hue=None,
            data=data_football_tournamentCount.head(20),
            hue_order=None)

loc, labels = plt.xticks()
g.set_xticklabels(labels, rotation=90)
# Out:
# [Text(0, 0, 'Friendly'),
#  Text(0, 0, 'FIFA World Cup qualification'),
#  Text(0, 0, 'UEFA Euro qualification'),
#  Text(0, 0, 'African Cup of Nations qualification'),
#  Text(0, 0, 'FIFA World Cup'),
#  Text(0, 0, 'Copa América'),
#  Text(0, 0, 'AFC Asian Cup qualification'),
#  Text(0, 0, 'African Cup of Nations'),
#  Text(0, 0, 'CECAFA Cup'),
#  Text(0, 0, 'CFU Caribbean Cup qualification'),
#  Text(0, 0, 'Merdeka Tournament'),
#  Text(0, 0, 'British Championship'),
#  Text(0, 0, 'AFC Asian Cup'),
#  Text(0, 0, 'Island Games'),
#  Text(0, 0, 'Gulf Cup'),
#  Text(0, 0, 'Gold Cup'),
#  Text(0, 0, 'AFF Championship'),
#  Text(0, 0, 'COSAFA Cup'),
#  Text(0, 0, 'UEFA Euro'),
#  Text(0, 0, 'Nordic Championship')]

# %%
plt.figure(figsize=(16,10))

g = sns.barplot(x='tournament',
            y='count',
            hue=None,
            data=data_football_tournamentCount.tail(88),
            hue_order=None)

loc, labels = plt.xticks()
g.set_xticklabels(labels, rotation=90)
# Out:
# [Text(0, 0, 'CFU Caribbean Cup'),
#  Text(0, 0, 'Amílcar Cabral Cup'),
#  Text(0, 0, "King's Cup"),
#  Text(0, 0, 'South Pacific Games'),
#  Text(0, 0, 'UNCAF Cup'),
#  Text(0, 0, 'Korea Cup'),
#  Text(0, 0, 'UEFA Nations League'),
#  Text(0, 0, 'Confederations Cup'),
#  Text(0, 0, 'SAFF Cup'),
#  Text(0, 0, 'International Cup'),
#  Text(0, 0, 'CCCF Championship'),
#  Text(0, 0, 'UAFA Cup'),
#  Text(0, 0, 'EAFF Championship'),
#  Text(0, 0, 'CONIFA World Football Cup'),
#  Text(0, 0, 'Oceania Nations Cup'),
#  Text(0, 0, 'Windward Islands Tournament'),
#  Text(0, 0, 'AFC Challenge Cup'),
#  Text(0, 0, 'WAFF Championship'),
#  Text(0, 0, 'AFC Challenge Cup qualification'),
#  Text(0, 0, 'Nehru Cup'),
#  Text(0, 0, 'Balkan Cup'),
#  Text(0, 0, 'Baltic Cup'),
#  Text(0, 0, 'Indonesia Tournament'),
#  Text(0, 0, 'Cyprus International Tournament'),
#  Text(0, 0, 'Oceania Nations Cup qualification'),
#  Text(0, 0, 'Kirin Cup'),
#  Text(0, 0, 'UDEAC Cup'),
#  Text(0, 0, 'Vietnam Independence Cup'),
#  Text(0, 0, 'Gold Cup qualification'),
#  Text(0, 0, 'Viva World Cup'),
#  Text(0, 0, 'West African Cup'),
#  Text(0, 0, 'Malta International Tournament'),
#  Text(0, 0, 'Pacific Games'),
#  Text(0, 0, 'CONIFA European Football Cup'),
#  Text(0, 0, 'CONCACAF Championship'),
#  Text(0, 0, 'Pan American Championship'),
#  Text(0, 0, 'Brazil Independence Cup'),
#  Text(0, 0, 'USA Cup'),
#  Text(0, 0, 'United Arab Emirates Friendship Tournament'),
#  Text(0, 0, 'Dynasty Cup'),
#  Text(0, 0, 'Copa Chevallier Boutell'),
#  Text(0, 0, 'Copa Lipton'),
#  Text(0, 0, 'Copa Newton'),
#  Text(0, 0, 'Merlion Cup'),
#  Text(0, 0, 'Lunar New Year Cup'),
#  Text(0, 0, 'Copa Roca'),
#  Text(0, 0, 'Copa Paz del Chaco'),
#  Text(0, 0, "Prime Minister's Cup"),
#  Text(0, 0, 'CONCACAF Championship qualification'),
#  Text(0, 0, 'ABCS Tournament'),
#  Text(0, 0, 'Inter Games Football Tournament'),
#  Text(0, 0, 'Copa del Pacífico'),
#  Text(0, 0, 'Copa Rio Branco'),
#  Text(0, 0, 'Simba Tournament'),
#  Text(0, 0, 'Copa Juan Pinto Durán'),
#  Text(0, 0, 'Copa Carlos Dittborn'),
#  Text(0, 0, 'Copa Oswaldo Cruz'),
#  Text(0, 0, 'ELF Cup'),
#  Text(0, 0, 'Copa Premio Honor Uruguayo'),
#  Text(0, 0, 'UNIFFAC Cup'),
#  Text(0, 0, 'Dunhill Cup'),
#  Text(0, 0, 'Millennium Cup'),
#  Text(0, 0, 'GaNEFo'),
#  Text(0, 0, 'Nile Basin Tournament'),
#  Text(0, 0, 'Intercontinental Cup'),
#  Text(0, 0, 'Copa Artigas'),
#  Text(0, 0, 'Jordan International Tournament'),
#  Text(0, 0, 'King Hassan II Tournament'),
#  Text(0, 0, 'Copa Premio Honor Argentino'),
#  Text(0, 0, 'Atlantic Cup'),
#  Text(0, 0, 'Rous Cup'),
#  Text(0, 0, 'SKN Football Festival'),
#  Text(0, 0, "Copa Bernardo O'Higgins"),
#  Text(0, 0, 'Tournoi de France'),
#  Text(0, 0, 'FIFI Wild Cup'),
#  Text(0, 0, 'VFF Cup'),
#  Text(0, 0, 'UAFA Cup qualification'),
#  Text(0, 0, 'NAFU Championship'),
#  Text(0, 0, 'Mundialito'),
#  Text(0, 0, 'Copa Félix Bogado'),
#  Text(0, 0, 'Copa Ramón Castilla'),
#  Text(0, 0, 'Nations Cup'),
#  Text(0, 0, 'Dragon Cup'),
#  Text(0, 0, 'OSN Cup'),
#  Text(0, 0, 'World Unity Cup'),
#  Text(0, 0, 'Atlantic Heritage Cup'),
#  Text(0, 0, 'Copa América qualification'),
#  Text(0, 0, 'AFF Championship qualification')]

# %% [markdown]
# # Task 1 Analysis - Understand ranking of teams based on results from various competitions
#
# For this task, the idea is to determine the outcome of each matches between the home and away teams, where the wining team will gain a score in points towards their ranking. The cumulative frequency of wining matches by each team will then determine its position on a ranking (leadership) board. The scores can be taken as three categories, winning the match, losing the match, and having a draw.

# %% [markdown]
# ## 1.1 Remove 'Friendly' matches:

# %%
data_football = data_football_original.copy()
data_football = data_football[data_football.tournament != 'Friendly']

# %%
data_football.head()
# Out:
#           date         home_team         away_team  home_score  away_score  \
# 29  1884-01-26  Northern Ireland          Scotland           0           5
# 30  1884-02-09             Wales  Northern Ireland           6           0
# 31  1884-02-23  Northern Ireland           England           1           8
# 32  1884-03-15          Scotland           England           1           0
# 33  1884-03-17             Wales           England           0           4
#
#               tournament     city              country  neutral
# 29  British Championship  Belfast  Republic of Ireland    False
# 30  British Championship  Wrexham                Wales    False
# 31  British Championship  Belfast  Republic of Ireland    False
# 32  British Championship  Glasgow             Scotland    False
# 33  British Championship  Wrexham                Wales    False

# %%
data_football.tail()
# Out:
#              date         home_team        away_team  home_score  away_score  \
# 40834  2019-07-18    American Samoa           Tahiti           8           1
# 40835  2019-07-18              Fiji  Solomon Islands           4           4
# 40836  2019-07-19           Senegal          Algeria           0           1
# 40837  2019-07-19        Tajikistan      North Korea           0           1
# 40838  2019-07-20  Papua New Guinea             Fiji           1           1
#
#                    tournament       city country  neutral
# 40834           Pacific Games       Apia   Samoa     True
# 40835           Pacific Games       Apia   Samoa     True
# 40836  African Cup of Nations      Cairo   Egypt     True
# 40837    Intercontinental Cup  Ahmedabad   India     True
# 40838           Pacific Games       Apia   Samoa     True

# %%
data_football.shape
# Out:
# (23928, 9)

# %% [markdown]
# ## 1.2 Calculate the Ranking Points:
#
# The points are awarded as follows:
# 1. win = 1, draw = 0 and loss = -1
#
# For this dataset, it was not possible to use the same ranking formula as seen in the references below:
# - ref 1: https://www.get-digital-help.com/team-ranking-with-criteria/
# - ref 2: https://www.goal.com/en-us/news/fifa-world-ranking-how-it-is-calculated-what-it-is-used-for/16w60sntgv7x61a6q08b7ooi0p

# %%
def task1_matchOutcomes(data):
    data = data.reset_index()
    data = data.drop(['index'], axis = 1)
    data_football = data
    
    data_football['match_outcome'] = np.nan

    list_teamOutcomes = []

    for idx in range(len(data_football)):
#         print(idx)
        if (data_football['home_score'][idx] > data_football['away_score'][idx]):
#             print('home')
            list_teamOutcomes.append('win')

        elif (data_football['home_score'][idx] < data_football['away_score'][idx]):
#             print('away')
            list_teamOutcomes.append('loss')

        else:
#             print('draw')
            list_teamOutcomes.append('draw')

    data_football['match_outcome'] = list_teamOutcomes
    
    return data_football;

# %%
def task1_rankPoints_homeTeam(data):
    
    data_football = data
    
    data_football['home_team_rank_points'] = np.nan

    list_teamOutcomes = []

    for idx in range(len(data_football)):
#         print(idx)
        if (data_football['match_outcome'][idx] == 'loss'):
#             print('home')
            list_teamOutcomes.append(int(-1))

        elif (data_football['match_outcome'][idx] == 'win'):
#             print('away')
            list_teamOutcomes.append(int(1))

        else:
            # else it is a DRAW:
#             print('draw')
            list_teamOutcomes.append(int(0))

    data_football['home_team_rank_points'] = list_teamOutcomes
    
    return data_football;

# %%
def task1_rankPoints_awayTeam(data):
    
    data_football = data
    
    data_football['away_team_rank_points'] = np.nan

    list_teamOutcomes = []

    for idx in range(len(data_football)):
#         print(idx)
        if (data_football['home_team_rank_points'][idx] == 1):
#             print('home')
            list_teamOutcomes.append(int(-1))

        elif (data_football['home_team_rank_points'][idx] == -1):
#             print('away')
            list_teamOutcomes.append(int(1))

        else:
            # else it is a DRAW:
#             print('draw')
            list_teamOutcomes.append(int(0))

    data_football['away_team_rank_points'] = list_teamOutcomes
    
    return data_football;

# %% [markdown]
# #### 1.2.1 - Assign the an Outcome to each matches: Using User Defined Func -> task1_matchOutcomes()

# %%
data_football = task1_matchOutcomes(data_football)
data_football.head()
# Out:
#          date         home_team         away_team  home_score  away_score  \
# 0  1884-01-26  Northern Ireland          Scotland           0           5
# 1  1884-02-09             Wales  Northern Ireland           6           0
# 2  1884-02-23  Northern Ireland           England           1           8
# 3  1884-03-15          Scotland           England           1           0
# 4  1884-03-17             Wales           England           0           4
#
#              tournament     city              country  neutral match_outcome
# 0  British Championship  Belfast  Republic of Ireland    False          loss
# 1  British Championship  Wrexham                Wales    False           win
# 2  British Championship  Belfast  Republic of Ireland    False          loss
# 3  British Championship  Glasgow             Scotland    False           win
# 4  British Championship  Wrexham                Wales    False          loss

# %% [markdown]
# #### 1.2.2 - Assign Scores to each matches based on outcome: Using User Defined Func -> task1_rankPoints_homeTeam() and task1_rankPoints_awayTeam()

# %%
data_football = task1_rankPoints_homeTeam(data_football)
data_football = task1_rankPoints_awayTeam(data_football)

# %%
data_football.head(15)
# Out:
#           date         home_team         away_team  home_score  away_score  \
# 0   1884-01-26  Northern Ireland          Scotland           0           5
# 1   1884-02-09             Wales  Northern Ireland           6           0
# 2   1884-02-23  Northern Ireland           England           1           8
# 3   1884-03-15          Scotland           England           1           0
# 4   1884-03-17             Wales           England           0           4
# 5   1884-03-29          Scotland             Wales           4           1
# 6   1885-02-28           England  Northern Ireland           4           0
# 7   1885-03-14           England             Wales           1           1
# 8   1885-03-14          Scotland  Northern Ireland           8           2
# 9   1885-03-21           England          Scotland           1           1
# 10  1885-03-23             Wales          Scotland           1           8
# 11  1885-04-11  Northern Ireland             Wales           2           8
# 12  1886-02-27             Wales  Northern Ireland           5           0
# 13  1886-03-13  Northern Ireland           England           1           6
# 14  1886-03-20  Northern Ireland          Scotland           2           7
#
#               tournament        city              country  neutral  \
# 0   British Championship     Belfast  Republic of Ireland    False
# 1   British Championship     Wrexham                Wales    False
# 2   British Championship     Belfast  Republic of Ireland    False
# 3   British Championship     Glasgow             Scotland    False
# 4   British Championship     Wrexham                Wales    False
# 5   British Championship     Glasgow             Scotland    False
# 6   British Championship  Manchester              England    False
# 7   British Championship   Blackburn              England    False
# 8   British Championship     Glasgow             Scotland    False
# 9   British Championship      London              England    False
# 10  British Championship     Wrexham                Wales    False
# 11  British Championship     Belfast  Republic of Ireland    False
# 12  British Championship     Wrexham                Wales    False
# 13  British Championship     Belfast  Republic of Ireland    False
# 14  British Championship     Belfast  Republic of Ireland    False
#
#    match_outcome  home_team_rank_points  away_team_rank_points
# 0           loss                     -1                      1
# 1            win                      1                     -1
# 2           loss                     -1                      1
# 3            win                      1                     -1
# 4           loss                     -1                      1
# 5            win                      1                     -1
# 6            win                      1                     -1
# 7           draw                      0                      0
# 8            win                      1                     -1
# 9           draw                      0                      0
# 10          loss                     -1                      1
# 11          loss                     -1                      1
# 12           win                      1                     -1
# 13          loss                     -1                      1
# 14          loss                     -1                      1

# %% [markdown]
# ## 1.3 End of Year rankings:
# This section takes the added feature columns from the section above and uses it to generate a new dictionary containing the relevant data for Task 1. The data generated will consist of the Tournament type, the team names, the years of games played within each teams and finally a list of the scores accummulated throughout the year.
#
# The Example Dict: {Tournament: Team: {Year: [list of all scores]}}

# %%
def task1_EndYearRanks(data_football):
    # Dict of End of Year Ranks by Tournaments:
    dict_EndYearRanks = {}

    # Step 1 - Make of Copy of the Dataset:
    data_tournaments = data_football.copy()

    # Step 2 - Change the format of the Date column to DateTime:
    data_tournaments['date'] = pd.to_datetime(data_tournaments['date'])
    data_tournaments['year'] = data_tournaments['date'].dt.year

    # Step 3 - Take a subset of the DataFrame by Tournament type:
    tournament_list = list(data_tournaments['tournament'].unique())
    data_tournamentTypes_homeTeam = {}

    for i, tournamentName in enumerate(tournament_list):
    #     print(i, tournamentName)
        subset_data = data_tournaments[data_tournaments['tournament'] == tournamentName].iloc[:,:]
    #     print(subset_data)

        # List of team names:
        teamNames_list = list(subset_data['home_team'].unique())

        # Dict:
        dict_teamScores = {}

        # Step 4 - Collect the ranking point(Home Team):
        for j, teamNames  in enumerate(teamNames_list):
            print(j, teamNames)

            # Step 5 - Grab a Subset from main dataset:
            print('At index: ',i, '; Current HomeTeam is: ', teamNames_list[j])
            data_subset_team = subset_data.loc[subset_data['home_team'] == teamNames_list[j]]
            data_subset_team2 = subset_data.loc[subset_data['away_team'] == teamNames_list[j]]
    #         print(data_subset_team)

            # Step 6 - 
            # List of dates: by YEAR
            years_list = list(subset_data['year'].unique())

            # Dict:
            dict_yearAndScores = {}

            # Step 7 - make a list of the column['home_team_rank_points']:
            for (k, year), (m, year)  in zip(enumerate(years_list), enumerate(years_list)):
                data_subset_team_byYear = data_subset_team.loc[data_subset_team['year'] == years_list[k]]
                data_subset_team_byYear2 = data_subset_team2.loc[data_subset_team2['year'] == years_list[m]]

                # Dictionaries and Lists:
                input_scores = []
                total_score = 0
                subset_cummulative_scores = []

                # Make a list of the Input Socres from subset of Data:
                for l in data_subset_team_byYear.index:
                    point_values = data_subset_team_byYear['home_team_rank_points'][l]
                    input_scores.append(point_values)
                    
                for l in data_subset_team_byYear2.index:
                    point_values2 = data_subset_team_byYear2['away_team_rank_points'][l]
                    input_scores.append(point_values2)
                        
                # Step 8 - Sum of the Ranking point for this year:
                # Sum Calculations:
                total_score = sum(input_scores)
                subset_cummulative_scores.append(total_score)
                    
                # Append to Dict {dict_yearAndScores}: dict[key] = value
                subset_cummulative_scores = ','.join( str(a) for a in subset_cummulative_scores )
                dict_yearAndScores[str(year)] = subset_cummulative_scores
                            
            # Append to Dict {dict_teamScores}: dict[key] = value
            dict_teamScores[teamNames] = dict_yearAndScores

            
        # Step 9 - Update to the overall Dictionary: 
        # Append to Dict {dict_teamScores}: dict[key] = value
        data_tournamentTypes_homeTeam[tournamentName] = dict_teamScores
        dict_tournamentTypes_homeTeam = data_tournamentTypes_homeTeam
        
    return dict_tournamentTypes_homeTeam;

# %% [markdown]
# #### 1.3.1 - generate new dictionary for end of year ranking: Using User Defined Func -> task1_EndYearRanks()

# %%
dict_tournamentTypes_homeTeam = task1_EndYearRanks(data_football)
# Out:
# 0 Northern Ireland
# At index:  0 ; Current HomeTeam is:  Northern Ireland
# 1 Wales
# At index:  0 ; Current HomeTeam is:  Wales
# 2 Scotland
# At index:  0 ; Current HomeTeam is:  Scotland
# 3 England
# At index:  0 ; Current HomeTeam is:  England
# 0 Argentina
# At index:  1 ; Current HomeTeam is:  Argentina
# 1 Uruguay
# At index:  1 ; Current HomeTeam is:  Uruguay
# 0 Argentina
# At index:  2 ; Current HomeTeam is:  Argentina
# 1 Uruguay
# At index:  2 ; Current HomeTeam is:  Uruguay
# 0 Argentina
# At index:  3 ; Current HomeTeam is:  Argentina
# 0 Uruguay
# At index:  4 ; Current HomeTeam is:  Uruguay
# 0 Argentina
# At index:  5 ; Current HomeTeam is:  Argentina
# 1 Brazil
# At index:  5 ; Current HomeTeam is:  Brazil
# 0 Chile
# At index:  6 ; Current HomeTeam is:  Chile
# 1 Argentina
# At index:  6 ; Current HomeTeam is:  Argentina
# 2 Brazil
# At index:  6 ; Current HomeTeam is:  Brazil
# 3 Uruguay
# At index:  6 ; Current HomeTeam is:  Uruguay
# 4 Paraguay
# At index:  6 ; Current HomeTeam is:  Paraguay
# 5 Bolivia
# At index:  6 ; Current HomeTeam is:  Bolivia
# 6 Peru
# At index:  6 ; Current HomeTeam is:  Peru
# 7 Ecuador
# At index:  6 ; Current HomeTeam is:  Ecuador
# 8 Colombia
# At index:  6 ; Current HomeTeam is:  Colombia
# 9 Venezuela
# At index:  6 ; Current HomeTeam is:  Venezuela
# 10 United States
# At index:  6 ; Current HomeTeam is:  United States
# 11 Mexico
# At index:  6 ; Current HomeTeam is:  Mexico
# 12 Honduras
# At index:  6 ; Current HomeTeam is:  Honduras
# 13 Costa Rica
# At index:  6 ; Current HomeTeam is:  Costa Rica
# 14 Haiti
# At index:  6 ; Current HomeTeam is:  Haiti
# 15 Jamaica
# At index:  6 ; Current HomeTeam is:  Jamaica
# 16 Panama
# At index:  6 ; Current HomeTeam is:  Panama
# 17 Japan
# At index:  6 ; Current HomeTeam is:  Japan
# 18 Qatar
# At index:  6 ; Current HomeTeam is:  Qatar
# 0 Argentina
# At index:  7 ; Current HomeTeam is:  Argentina
# 1 Paraguay
# At index:  7 ; Current HomeTeam is:  Paraguay
# 0 Denmark
# At index:  8 ; Current HomeTeam is:  Denmark
# 1 Norway
# At index:  8 ; Current HomeTeam is:  Norway
# 2 Sweden
# At index:  8 ; Current HomeTeam is:  Sweden
# 3 Finland
# At index:  8 ; Current HomeTeam is:  Finland
# 4 Faroe Islands
# At index:  8 ; Current HomeTeam is:  Faroe Islands
# 5 Iceland
# At index:  8 ; Current HomeTeam is:  Iceland
# 0 Czechoslovakia
# At index:  9 ; Current HomeTeam is:  Czechoslovakia
# 1 Hungary
# At index:  9 ; Current HomeTeam is:  Hungary
# 2 Italy
# At index:  9 ; Current HomeTeam is:  Italy
# 3 Austria
# At index:  9 ; Current HomeTeam is:  Austria
# 4 Switzerland
# At index:  9 ; Current HomeTeam is:  Switzerland
# 5 Yugoslavia
# At index:  9 ; Current HomeTeam is:  Yugoslavia
# 0 Latvia
# At index:  10 ; Current HomeTeam is:  Latvia
# 1 Estonia
# At index:  10 ; Current HomeTeam is:  Estonia
# 2 Lithuania
# At index:  10 ; Current HomeTeam is:  Lithuania
# 3 Finland
# At index:  10 ; Current HomeTeam is:  Finland
# 0 Romania
# At index:  11 ; Current HomeTeam is:  Romania
# 1 Greece
# At index:  11 ; Current HomeTeam is:  Greece
# 2 Bulgaria
# At index:  11 ; Current HomeTeam is:  Bulgaria
# 3 Yugoslavia
# At index:  11 ; Current HomeTeam is:  Yugoslavia
# 4 Turkey
# At index:  11 ; Current HomeTeam is:  Turkey
# 5 Albania
# At index:  11 ; Current HomeTeam is:  Albania
# 6 Hungary
# At index:  11 ; Current HomeTeam is:  Hungary
# 7 Poland
# At index:  11 ; Current HomeTeam is:  Poland
# 0 Belgium
# At index:  12 ; Current HomeTeam is:  Belgium
# 1 France
# At index:  12 ; Current HomeTeam is:  France
# 2 Brazil
# At index:  12 ; Current HomeTeam is:  Brazil
# 3 Peru
# At index:  12 ; Current HomeTeam is:  Peru
# 4 Argentina
# At index:  12 ; Current HomeTeam is:  Argentina
# 5 Chile
# At index:  12 ; Current HomeTeam is:  Chile
# 6 Bolivia
# At index:  12 ; Current HomeTeam is:  Bolivia
# 7 Paraguay
# At index:  12 ; Current HomeTeam is:  Paraguay
# 8 Uruguay
# At index:  12 ; Current HomeTeam is:  Uruguay
# 9 Austria
# At index:  12 ; Current HomeTeam is:  Austria
# 10 Czechoslovakia
# At index:  12 ; Current HomeTeam is:  Czechoslovakia
# 11 Egypt
# At index:  12 ; Current HomeTeam is:  Egypt
# 12 Italy
# At index:  12 ; Current HomeTeam is:  Italy
# 13 Netherlands
# At index:  12 ; Current HomeTeam is:  Netherlands
# 14 Germany
# At index:  12 ; Current HomeTeam is:  Germany
# 15 Cuba
# At index:  12 ; Current HomeTeam is:  Cuba
# 16 Hungary
# At index:  12 ; Current HomeTeam is:  Hungary
# 17 Spain
# At index:  12 ; Current HomeTeam is:  Spain
# 18 Switzerland
# At index:  12 ; Current HomeTeam is:  Switzerland
# 19 Mexico
# At index:  12 ; Current HomeTeam is:  Mexico
# 20 England
# At index:  12 ; Current HomeTeam is:  England
# 21 Sweden
# At index:  12 ; Current HomeTeam is:  Sweden
# 22 Scotland
# At index:  12 ; Current HomeTeam is:  Scotland
# 23 South Korea
# At index:  12 ; Current HomeTeam is:  South Korea
# 24 Colombia
# At index:  12 ; Current HomeTeam is:  Colombia
# 25 Russia
# At index:  12 ; Current HomeTeam is:  Russia
# 26 Bulgaria
# At index:  12 ; Current HomeTeam is:  Bulgaria
# 27 North Korea
# At index:  12 ; Current HomeTeam is:  North Korea
# 28 Portugal
# At index:  12 ; Current HomeTeam is:  Portugal
# 29 Israel
# At index:  12 ; Current HomeTeam is:  Israel
# 30 Morocco
# At index:  12 ; Current HomeTeam is:  Morocco
# 31 El Salvador
# At index:  12 ; Current HomeTeam is:  El Salvador
# 32 DR Congo
# At index:  12 ; Current HomeTeam is:  DR Congo
# 33 German DR
# At index:  12 ; Current HomeTeam is:  German DR
# 34 Poland
# At index:  12 ; Current HomeTeam is:  Poland
# 35 Yugoslavia
# At index:  12 ; Current HomeTeam is:  Yugoslavia
# 36 Haiti
# At index:  12 ; Current HomeTeam is:  Haiti
# 37 Australia
# At index:  12 ; Current HomeTeam is:  Australia
# 38 Iran
# At index:  12 ; Current HomeTeam is:  Iran
# 39 Algeria
# At index:  12 ; Current HomeTeam is:  Algeria
# 40 Honduras
# At index:  12 ; Current HomeTeam is:  Honduras
# 41 Canada
# At index:  12 ; Current HomeTeam is:  Canada
# 42 Northern Ireland
# At index:  12 ; Current HomeTeam is:  Northern Ireland
# 43 Denmark
# At index:  12 ; Current HomeTeam is:  Denmark
# 44 Iraq
# At index:  12 ; Current HomeTeam is:  Iraq
# 45 United Arab Emirates
# At index:  12 ; Current HomeTeam is:  United Arab Emirates
# 46 United States
# At index:  12 ; Current HomeTeam is:  United States
# 47 Costa Rica
# At index:  12 ; Current HomeTeam is:  Costa Rica
# 48 Cameroon
# At index:  12 ; Current HomeTeam is:  Cameroon
# 49 Republic of Ireland
# At index:  12 ; Current HomeTeam is:  Republic of Ireland
# 50 Norway
# At index:  12 ; Current HomeTeam is:  Norway
# 51 Nigeria
# At index:  12 ; Current HomeTeam is:  Nigeria
# 52 Romania
# At index:  12 ; Current HomeTeam is:  Romania
# 53 Saudi Arabia
# At index:  12 ; Current HomeTeam is:  Saudi Arabia
# 54 Greece
# At index:  12 ; Current HomeTeam is:  Greece
# 55 Jamaica
# At index:  12 ; Current HomeTeam is:  Jamaica
# 56 Serbia
# At index:  12 ; Current HomeTeam is:  Serbia
# 57 South Africa
# At index:  12 ; Current HomeTeam is:  South Africa
# 58 Japan
# At index:  12 ; Current HomeTeam is:  Japan
# 59 Croatia
# At index:  12 ; Current HomeTeam is:  Croatia
# 60 China PR
# At index:  12 ; Current HomeTeam is:  China PR
# 61 Tunisia
# At index:  12 ; Current HomeTeam is:  Tunisia
# 62 Senegal
# At index:  12 ; Current HomeTeam is:  Senegal
# 63 Slovenia
# At index:  12 ; Current HomeTeam is:  Slovenia
# 64 Ecuador
# At index:  12 ; Current HomeTeam is:  Ecuador
# 65 Turkey
# At index:  12 ; Current HomeTeam is:  Turkey
# 66 Trinidad and Tobago
# At index:  12 ; Current HomeTeam is:  Trinidad and Tobago
# 67 Angola
# At index:  12 ; Current HomeTeam is:  Angola
# 68 Czech Republic
# At index:  12 ; Current HomeTeam is:  Czech Republic
# 69 Togo
# At index:  12 ; Current HomeTeam is:  Togo
# 70 Ivory Coast
# At index:  12 ; Current HomeTeam is:  Ivory Coast
# 71 Ghana
# At index:  12 ; Current HomeTeam is:  Ghana
# 72 Ukraine
# At index:  12 ; Current HomeTeam is:  Ukraine
# 73 New Zealand
# At index:  12 ; Current HomeTeam is:  New Zealand
# 74 Slovakia
# At index:  12 ; Current HomeTeam is:  Slovakia
# 75 Bosnia and Herzegovina
# At index:  12 ; Current HomeTeam is:  Bosnia and Herzegovina
# 76 Iceland
# At index:  12 ; Current HomeTeam is:  Iceland
# 77 Panama
# At index:  12 ; Current HomeTeam is:  Panama
# 0 Brazil
# At index:  13 ; Current HomeTeam is:  Brazil
# 1 Uruguay
# At index:  13 ; Current HomeTeam is:  Uruguay
# 0 Sweden
# At index:  14 ; Current HomeTeam is:  Sweden
# 1 Lithuania
# At index:  14 ; Current HomeTeam is:  Lithuania
# 2 Yugoslavia
# At index:  14 ; Current HomeTeam is:  Yugoslavia
# 3 Poland
# At index:  14 ; Current HomeTeam is:  Poland
# 4 Switzerland
# At index:  14 ; Current HomeTeam is:  Switzerland
# 5 Haiti
# At index:  14 ; Current HomeTeam is:  Haiti
# 6 Republic of Ireland
# At index:  14 ; Current HomeTeam is:  Republic of Ireland
# 7 Mexico
# At index:  14 ; Current HomeTeam is:  Mexico
# 8 Luxembourg
# At index:  14 ; Current HomeTeam is:  Luxembourg
# 9 Spain
# At index:  14 ; Current HomeTeam is:  Spain
# 10 Egypt
# At index:  14 ; Current HomeTeam is:  Egypt
# 11 Portugal
# At index:  14 ; Current HomeTeam is:  Portugal
# 12 Bulgaria
# At index:  14 ; Current HomeTeam is:  Bulgaria
# 13 Italy
# At index:  14 ; Current HomeTeam is:  Italy
# 14 Israel
# At index:  14 ; Current HomeTeam is:  Israel
# 15 Netherlands
# At index:  14 ; Current HomeTeam is:  Netherlands
# 16 Austria
# At index:  14 ; Current HomeTeam is:  Austria
# 17 Belgium
# At index:  14 ; Current HomeTeam is:  Belgium
# 18 Romania
# At index:  14 ; Current HomeTeam is:  Romania
# 19 Finland
# At index:  14 ; Current HomeTeam is:  Finland
# 20 Latvia
# At index:  14 ; Current HomeTeam is:  Latvia
# 21 Germany
# At index:  14 ; Current HomeTeam is:  Germany
# 22 Norway
# At index:  14 ; Current HomeTeam is:  Norway
# 23 Greece
# At index:  14 ; Current HomeTeam is:  Greece
# 24 Hungary
# At index:  14 ; Current HomeTeam is:  Hungary
# 25 Czechoslovakia
# At index:  14 ; Current HomeTeam is:  Czechoslovakia
# 26 Cuba
# At index:  14 ; Current HomeTeam is:  Cuba
# 27 United States
# At index:  14 ; Current HomeTeam is:  United States
# 28 Northern Ireland
# At index:  14 ; Current HomeTeam is:  Northern Ireland
# 29 Wales
# At index:  14 ; Current HomeTeam is:  Wales
# 30 France
# At index:  14 ; Current HomeTeam is:  France
# 31 Scotland
# At index:  14 ; Current HomeTeam is:  Scotland
# 32 England
# At index:  14 ; Current HomeTeam is:  England
# 33 Turkey
# At index:  14 ; Current HomeTeam is:  Turkey
# 34 Saarland
# At index:  14 ; Current HomeTeam is:  Saarland
# 35 Paraguay
# At index:  14 ; Current HomeTeam is:  Paraguay
# 36 Chile
# At index:  14 ; Current HomeTeam is:  Chile
# 37 Japan
# At index:  14 ; Current HomeTeam is:  Japan
# 38 Brazil
# At index:  14 ; Current HomeTeam is:  Brazil
# 39 Guatemala
# At index:  14 ; Current HomeTeam is:  Guatemala
# 40 Costa Rica
# At index:  14 ; Current HomeTeam is:  Costa Rica
# 41 Sudan
# At index:  14 ; Current HomeTeam is:  Sudan
# 42 Peru
# At index:  14 ; Current HomeTeam is:  Peru
# 43 Indonesia
# At index:  14 ; Current HomeTeam is:  Indonesia
# 44 Denmark
# At index:  14 ; Current HomeTeam is:  Denmark
# 45 German DR
# At index:  14 ; Current HomeTeam is:  German DR
# 46 Syria
# At index:  14 ; Current HomeTeam is:  Syria
# 47 China PR
# At index:  14 ; Current HomeTeam is:  China PR
# 48 Colombia
# At index:  14 ; Current HomeTeam is:  Colombia
# 49 Canada
# At index:  14 ; Current HomeTeam is:  Canada
# 50 Russia
# At index:  14 ; Current HomeTeam is:  Russia
# 51 Uruguay
# At index:  14 ; Current HomeTeam is:  Uruguay
# 52 Curaçao
# At index:  14 ; Current HomeTeam is:  Curaçao
# 53 Iceland
# At index:  14 ; Current HomeTeam is:  Iceland
# 54 Bolivia
# At index:  14 ; Current HomeTeam is:  Bolivia
# 55 Argentina
# At index:  14 ; Current HomeTeam is:  Argentina
# 56 Ghana
# At index:  14 ; Current HomeTeam is:  Ghana
# 57 Honduras
# At index:  14 ; Current HomeTeam is:  Honduras
# 58 Nigeria
# At index:  14 ; Current HomeTeam is:  Nigeria
# 59 Suriname
# At index:  14 ; Current HomeTeam is:  Suriname
# 60 Morocco
# At index:  14 ; Current HomeTeam is:  Morocco
# 61 South Korea
# At index:  14 ; Current HomeTeam is:  South Korea
# 62 Cyprus
# At index:  14 ; Current HomeTeam is:  Cyprus
# 63 Tunisia
# At index:  14 ; Current HomeTeam is:  Tunisia
# 64 Ecuador
# At index:  14 ; Current HomeTeam is:  Ecuador
# 65 Albania
# At index:  14 ; Current HomeTeam is:  Albania
# 66 Jamaica
# At index:  14 ; Current HomeTeam is:  Jamaica
# 67 Trinidad and Tobago
# At index:  14 ; Current HomeTeam is:  Trinidad and Tobago
# 68 Venezuela
# At index:  14 ; Current HomeTeam is:  Venezuela
# 69 North Korea
# At index:  14 ; Current HomeTeam is:  North Korea
# 70 Australia
# At index:  14 ; Current HomeTeam is:  Australia
# 71 Bermuda
# At index:  14 ; Current HomeTeam is:  Bermuda
# 72 Zambia
# At index:  14 ; Current HomeTeam is:  Zambia
# 73 Algeria
# At index:  14 ; Current HomeTeam is:  Algeria
# 74 El Salvador
# At index:  14 ; Current HomeTeam is:  El Salvador
# 75 Cameroon
# At index:  14 ; Current HomeTeam is:  Cameroon
# 76 Senegal
# At index:  14 ; Current HomeTeam is:  Senegal
# 77 Libya
# At index:  14 ; Current HomeTeam is:  Libya
# 78 Ethiopia
# At index:  14 ; Current HomeTeam is:  Ethiopia
# 79 Zimbabwe
# At index:  14 ; Current HomeTeam is:  Zimbabwe
# 80 Malta
# At index:  14 ; Current HomeTeam is:  Malta
# 81 Guinea
# At index:  14 ; Current HomeTeam is:  Guinea
# 82 Puerto Rico
# At index:  14 ; Current HomeTeam is:  Puerto Rico
# 83 Lesotho
# At index:  14 ; Current HomeTeam is:  Lesotho
# 84 Togo
# At index:  14 ; Current HomeTeam is:  Togo
# 85 Benin
# At index:  14 ; Current HomeTeam is:  Benin
# 86 DR Congo
# At index:  14 ; Current HomeTeam is:  DR Congo
# 87 Kenya
# At index:  14 ; Current HomeTeam is:  Kenya
# 88 Congo
# At index:  14 ; Current HomeTeam is:  Congo
# 89 Sierra Leone
# At index:  14 ; Current HomeTeam is:  Sierra Leone
# 90 Ivory Coast
# At index:  14 ; Current HomeTeam is:  Ivory Coast
# 91 Antigua and Barbuda
# At index:  14 ; Current HomeTeam is:  Antigua and Barbuda
# 92 Tanzania
# At index:  14 ; Current HomeTeam is:  Tanzania
# 93 Mauritius
# At index:  14 ; Current HomeTeam is:  Mauritius
# 94 New Zealand
# At index:  14 ; Current HomeTeam is:  New Zealand
# 95 Iraq
# At index:  14 ; Current HomeTeam is:  Iraq
# 96 Iran
# At index:  14 ; Current HomeTeam is:  Iran
# 97 Thailand
# At index:  14 ; Current HomeTeam is:  Thailand
# 98 Hong Kong
# At index:  14 ; Current HomeTeam is:  Hong Kong
# 99 Vietnam Republic
# At index:  14 ; Current HomeTeam is:  Vietnam Republic
# 100 Burkina Faso
# At index:  14 ; Current HomeTeam is:  Burkina Faso
# 101 Niger
# At index:  14 ; Current HomeTeam is:  Niger
# 102 Mauritania
# At index:  14 ; Current HomeTeam is:  Mauritania
# 103 Dominican Republic
# At index:  14 ; Current HomeTeam is:  Dominican Republic
# 104 Panama
# At index:  14 ; Current HomeTeam is:  Panama
# 105 Malawi
# At index:  14 ; Current HomeTeam is:  Malawi
# 106 Guyana
# At index:  14 ; Current HomeTeam is:  Guyana
# 107 Barbados
# At index:  14 ; Current HomeTeam is:  Barbados
# 108 Saudi Arabia
# At index:  14 ; Current HomeTeam is:  Saudi Arabia
# 109 Uganda
# At index:  14 ; Current HomeTeam is:  Uganda
# 110 Singapore
# At index:  14 ; Current HomeTeam is:  Singapore
# 111 Malaysia
# At index:  14 ; Current HomeTeam is:  Malaysia
# 112 Bahrain
# At index:  14 ; Current HomeTeam is:  Bahrain
# 113 Qatar
# At index:  14 ; Current HomeTeam is:  Qatar
# 114 Kuwait
# At index:  14 ; Current HomeTeam is:  Kuwait
# 115 Grenada
# At index:  14 ; Current HomeTeam is:  Grenada
# 116 Gambia
# At index:  14 ; Current HomeTeam is:  Gambia
# 117 Mozambique
# At index:  14 ; Current HomeTeam is:  Mozambique
# 118 Somalia
# At index:  14 ; Current HomeTeam is:  Somalia
# 119 Madagascar
# At index:  14 ; Current HomeTeam is:  Madagascar
# 120 Liberia
# At index:  14 ; Current HomeTeam is:  Liberia
# 121 Fiji
# At index:  14 ; Current HomeTeam is:  Fiji
# 122 Angola
# At index:  14 ; Current HomeTeam is:  Angola
# 123 Macau
# At index:  14 ; Current HomeTeam is:  Macau
# 124 Brunei
# At index:  14 ; Current HomeTeam is:  Brunei
# 125 Nepal
# At index:  14 ; Current HomeTeam is:  Nepal
# 126 Jordan
# At index:  14 ; Current HomeTeam is:  Jordan
# 127 Yemen
# At index:  14 ; Current HomeTeam is:  Yemen
# 128 Yemen DPR
# At index:  14 ; Current HomeTeam is:  Yemen DPR
# 129 Bangladesh
# At index:  14 ; Current HomeTeam is:  Bangladesh
# 130 India
# At index:  14 ; Current HomeTeam is:  India
# 131 United Arab Emirates
# At index:  14 ; Current HomeTeam is:  United Arab Emirates
# 132 Oman
# At index:  14 ; Current HomeTeam is:  Oman
# 133 Pakistan
# At index:  14 ; Current HomeTeam is:  Pakistan
# 134 Gabon
# At index:  14 ; Current HomeTeam is:  Gabon
# 135 Saint Lucia
# At index:  14 ; Current HomeTeam is:  Saint Lucia
# 136 Saint Vincent and the Grenadines
# At index:  14 ; Current HomeTeam is:  Saint Vincent and the Grenadines
# 137 Faroe Islands
# At index:  14 ; Current HomeTeam is:  Faroe Islands
# 138 Vanuatu
# At index:  14 ; Current HomeTeam is:  Vanuatu
# 139 Solomon Islands
# At index:  14 ; Current HomeTeam is:  Solomon Islands
# 140 Nicaragua
# At index:  14 ; Current HomeTeam is:  Nicaragua
# 141 Estonia
# At index:  14 ; Current HomeTeam is:  Estonia
# 142 Tahiti
# At index:  14 ; Current HomeTeam is:  Tahiti
# 143 San Marino
# At index:  14 ; Current HomeTeam is:  San Marino
# 144 South Africa
# At index:  14 ; Current HomeTeam is:  South Africa
# 145 Burundi
# At index:  14 ; Current HomeTeam is:  Burundi
# 146 Namibia
# At index:  14 ; Current HomeTeam is:  Namibia
# 147 Eswatini
# At index:  14 ; Current HomeTeam is:  Eswatini
# 148 Botswana
# At index:  14 ; Current HomeTeam is:  Botswana
# 149 Sri Lanka
# At index:  14 ; Current HomeTeam is:  Sri Lanka
# 150 Vietnam
# At index:  14 ; Current HomeTeam is:  Vietnam
# 151 Czech Republic
# At index:  14 ; Current HomeTeam is:  Czech Republic
# 152 Lebanon
# At index:  14 ; Current HomeTeam is:  Lebanon
# 153 Dominica
# At index:  14 ; Current HomeTeam is:  Dominica
# 154 Aruba
# At index:  14 ; Current HomeTeam is:  Aruba
# 155 North Macedonia
# At index:  14 ; Current HomeTeam is:  North Macedonia
# 156 Serbia
# At index:  14 ; Current HomeTeam is:  Serbia
# 157 Saint Kitts and Nevis
# At index:  14 ; Current HomeTeam is:  Saint Kitts and Nevis
# 158 Cayman Islands
# At index:  14 ; Current HomeTeam is:  Cayman Islands
# 159 Guinea-Bissau
# At index:  14 ; Current HomeTeam is:  Guinea-Bissau
# 160 Belize
# At index:  14 ; Current HomeTeam is:  Belize
# 161 Rwanda
# At index:  14 ; Current HomeTeam is:  Rwanda
# 162 Armenia
# At index:  14 ; Current HomeTeam is:  Armenia
# 163 Azerbaijan
# At index:  14 ; Current HomeTeam is:  Azerbaijan
# 164 Belarus
# At index:  14 ; Current HomeTeam is:  Belarus
# 165 Liechtenstein
# At index:  14 ; Current HomeTeam is:  Liechtenstein
# 166 Moldova
# At index:  14 ; Current HomeTeam is:  Moldova
# 167 Slovenia
# At index:  14 ; Current HomeTeam is:  Slovenia
# 168 Papua New Guinea
# At index:  14 ; Current HomeTeam is:  Papua New Guinea
# 169 Slovakia
# At index:  14 ; Current HomeTeam is:  Slovakia
# 170 Philippines
# At index:  14 ; Current HomeTeam is:  Philippines
# 171 Ukraine
# At index:  14 ; Current HomeTeam is:  Ukraine
# 172 Bosnia and Herzegovina
# At index:  14 ; Current HomeTeam is:  Bosnia and Herzegovina
# 173 Georgia
# At index:  14 ; Current HomeTeam is:  Georgia
# 174 Croatia
# At index:  14 ; Current HomeTeam is:  Croatia
# 175 Tonga
# At index:  14 ; Current HomeTeam is:  Tonga
# 176 Samoa
# At index:  14 ; Current HomeTeam is:  Samoa
# 177 Cambodia
# At index:  14 ; Current HomeTeam is:  Cambodia
# 178 Tajikistan
# At index:  14 ; Current HomeTeam is:  Tajikistan
# 179 Turkmenistan
# At index:  14 ; Current HomeTeam is:  Turkmenistan
# 180 Kazakhstan
# At index:  14 ; Current HomeTeam is:  Kazakhstan
# 181 Uzbekistan
# At index:  14 ; Current HomeTeam is:  Uzbekistan
# 182 Maldives
# At index:  14 ; Current HomeTeam is:  Maldives
# 183 Kyrgyzstan
# At index:  14 ; Current HomeTeam is:  Kyrgyzstan
# 184 Anguilla
# At index:  14 ; Current HomeTeam is:  Anguilla
# 185 British Virgin Islands
# At index:  14 ; Current HomeTeam is:  British Virgin Islands
# 186 Bahamas
# At index:  14 ; Current HomeTeam is:  Bahamas
# 187 Montserrat
# At index:  14 ; Current HomeTeam is:  Montserrat
# 188 U.S. Virgin Islands
# At index:  14 ; Current HomeTeam is:  U.S. Virgin Islands
# 189 Djibouti
# At index:  14 ; Current HomeTeam is:  Djibouti
# 190 São Tomé and Príncipe
# At index:  14 ; Current HomeTeam is:  São Tomé and Príncipe
# 191 Seychelles
# At index:  14 ; Current HomeTeam is:  Seychelles
# 192 Cape Verde
# At index:  14 ; Current HomeTeam is:  Cape Verde
# 193 Central African Republic
# At index:  14 ; Current HomeTeam is:  Central African Republic
# 194 Chad
# At index:  14 ; Current HomeTeam is:  Chad
# 195 Equatorial Guinea
# At index:  14 ; Current HomeTeam is:  Equatorial Guinea
# 196 Eritrea
# At index:  14 ; Current HomeTeam is:  Eritrea
# 197 Mali
# At index:  14 ; Current HomeTeam is:  Mali
# 198 Andorra
# At index:  14 ; Current HomeTeam is:  Andorra
# 199 Mongolia
# At index:  14 ; Current HomeTeam is:  Mongolia
# 200 Palestine
# At index:  14 ; Current HomeTeam is:  Palestine
# 201 American Samoa
# At index:  14 ; Current HomeTeam is:  American Samoa
# 202 Laos
# At index:  14 ; Current HomeTeam is:  Laos
# 203 Cook Islands
# At index:  14 ; Current HomeTeam is:  Cook Islands
# 204 Afghanistan
# At index:  14 ; Current HomeTeam is:  Afghanistan
# 205 Turks and Caicos Islands
# At index:  14 ; Current HomeTeam is:  Turks and Caicos Islands
# 206 New Caledonia
# At index:  14 ; Current HomeTeam is:  New Caledonia
# 207 East Timor
# At index:  14 ; Current HomeTeam is:  East Timor
# 208 Burma
# At index:  14 ; Current HomeTeam is:  Burma
# 209 Comoros
# At index:  14 ; Current HomeTeam is:  Comoros
# 210 Montenegro
# At index:  14 ; Current HomeTeam is:  Montenegro
# 211 Bhutan
# At index:  14 ; Current HomeTeam is:  Bhutan
# 212 Guam
# At index:  14 ; Current HomeTeam is:  Guam
# 213 South Sudan
# At index:  14 ; Current HomeTeam is:  South Sudan
# 214 Gibraltar
# At index:  14 ; Current HomeTeam is:  Gibraltar
# 215 Kosovo
# At index:  14 ; Current HomeTeam is:  Kosovo
# 0 Curaçao
# At index:  15 ; Current HomeTeam is:  Curaçao
# 1 Costa Rica
# At index:  15 ; Current HomeTeam is:  Costa Rica
# 2 El Salvador
# At index:  15 ; Current HomeTeam is:  El Salvador
# 3 Nicaragua
# At index:  15 ; Current HomeTeam is:  Nicaragua
# 4 Guatemala
# At index:  15 ; Current HomeTeam is:  Guatemala
# 5 Panama
# At index:  15 ; Current HomeTeam is:  Panama
# 6 Honduras
# At index:  15 ; Current HomeTeam is:  Honduras
# 7 Aruba
# At index:  15 ; Current HomeTeam is:  Aruba
# 8 Cuba
# At index:  15 ; Current HomeTeam is:  Cuba
# 9 Haiti
# At index:  15 ; Current HomeTeam is:  Haiti
# 0 Mexico
# At index:  16 ; Current HomeTeam is:  Mexico
# 1 Cuba
# At index:  16 ; Current HomeTeam is:  Cuba
# 2 Canada
# At index:  16 ; Current HomeTeam is:  Canada
# 3 United States
# At index:  16 ; Current HomeTeam is:  United States
# 0 Brazil
# At index:  17 ; Current HomeTeam is:  Brazil
# 1 Paraguay
# At index:  17 ; Current HomeTeam is:  Paraguay
# 0 Chile
# At index:  18 ; Current HomeTeam is:  Chile
# 1 Mexico
# At index:  18 ; Current HomeTeam is:  Mexico
# 2 Panama
# At index:  18 ; Current HomeTeam is:  Panama
# 3 Peru
# At index:  18 ; Current HomeTeam is:  Peru
# 4 Brazil
# At index:  18 ; Current HomeTeam is:  Brazil
# 5 Argentina
# At index:  18 ; Current HomeTeam is:  Argentina
# 6 Costa Rica
# At index:  18 ; Current HomeTeam is:  Costa Rica
# 0 Peru
# At index:  19 ; Current HomeTeam is:  Peru
# 1 Chile
# At index:  19 ; Current HomeTeam is:  Chile
# 0 Brazil
# At index:  20 ; Current HomeTeam is:  Brazil
# 1 Chile
# At index:  20 ; Current HomeTeam is:  Chile
# 0 Philippines
# At index:  21 ; Current HomeTeam is:  Philippines
# 1 Malaysia
# At index:  21 ; Current HomeTeam is:  Malaysia
# 2 South Korea
# At index:  21 ; Current HomeTeam is:  South Korea
# 3 Cambodia
# At index:  21 ; Current HomeTeam is:  Cambodia
# 4 Vietnam Republic
# At index:  21 ; Current HomeTeam is:  Vietnam Republic
# 5 Singapore
# At index:  21 ; Current HomeTeam is:  Singapore
# 6 Iran
# At index:  21 ; Current HomeTeam is:  Iran
# 7 India
# At index:  21 ; Current HomeTeam is:  India
# 8 Israel
# At index:  21 ; Current HomeTeam is:  Israel
# 9 Pakistan
# At index:  21 ; Current HomeTeam is:  Pakistan
# 10 Hong Kong
# At index:  21 ; Current HomeTeam is:  Hong Kong
# 11 Thailand
# At index:  21 ; Current HomeTeam is:  Thailand
# 12 Japan
# At index:  21 ; Current HomeTeam is:  Japan
# 13 Indonesia
# At index:  21 ; Current HomeTeam is:  Indonesia
# 14 Burma
# At index:  21 ; Current HomeTeam is:  Burma
# 15 Kuwait
# At index:  21 ; Current HomeTeam is:  Kuwait
# 16 Bahrain
# At index:  21 ; Current HomeTeam is:  Bahrain
# 17 Syria
# At index:  21 ; Current HomeTeam is:  Syria
# 18 Iraq
# At index:  21 ; Current HomeTeam is:  Iraq
# 19 Jordan
# At index:  21 ; Current HomeTeam is:  Jordan
# 20 Lebanon
# At index:  21 ; Current HomeTeam is:  Lebanon
# 21 Saudi Arabia
# At index:  21 ; Current HomeTeam is:  Saudi Arabia
# 22 Qatar
# At index:  21 ; Current HomeTeam is:  Qatar
# 23 China PR
# At index:  21 ; Current HomeTeam is:  China PR
# 24 North Korea
# At index:  21 ; Current HomeTeam is:  North Korea
# 25 Bangladesh
# At index:  21 ; Current HomeTeam is:  Bangladesh
# 26 Oman
# At index:  21 ; Current HomeTeam is:  Oman
# 27 Sri Lanka
# At index:  21 ; Current HomeTeam is:  Sri Lanka
# 28 United Arab Emirates
# At index:  21 ; Current HomeTeam is:  United Arab Emirates
# 29 Yemen
# At index:  21 ; Current HomeTeam is:  Yemen
# 30 Nepal
# At index:  21 ; Current HomeTeam is:  Nepal
# 31 Macau
# At index:  21 ; Current HomeTeam is:  Macau
# 32 Kyrgyzstan
# At index:  21 ; Current HomeTeam is:  Kyrgyzstan
# 33 Turkmenistan
# At index:  21 ; Current HomeTeam is:  Turkmenistan
# 34 Tajikistan
# At index:  21 ; Current HomeTeam is:  Tajikistan
# 35 Kazakhstan
# At index:  21 ; Current HomeTeam is:  Kazakhstan
# 36 Uzbekistan
# At index:  21 ; Current HomeTeam is:  Uzbekistan
# 37 Maldives
# At index:  21 ; Current HomeTeam is:  Maldives
# 38 Vietnam
# At index:  21 ; Current HomeTeam is:  Vietnam
# 39 Bhutan
# At index:  21 ; Current HomeTeam is:  Bhutan
# 40 Palestine
# At index:  21 ; Current HomeTeam is:  Palestine
# 41 Laos
# At index:  21 ; Current HomeTeam is:  Laos
# 42 Guam
# At index:  21 ; Current HomeTeam is:  Guam
# 43 Australia
# At index:  21 ; Current HomeTeam is:  Australia
# 44 Chinese Taipei
# At index:  21 ; Current HomeTeam is:  Chinese Taipei
# 45 Afghanistan
# At index:  21 ; Current HomeTeam is:  Afghanistan
# 0 Brazil
# At index:  22 ; Current HomeTeam is:  Brazil
# 1 Uruguay
# At index:  22 ; Current HomeTeam is:  Uruguay
# 2 Argentina
# At index:  22 ; Current HomeTeam is:  Argentina
# 3 Paraguay
# At index:  22 ; Current HomeTeam is:  Paraguay
# 0 Hong Kong
# At index:  23 ; Current HomeTeam is:  Hong Kong
# 1 Israel
# At index:  23 ; Current HomeTeam is:  Israel
# 2 South Korea
# At index:  23 ; Current HomeTeam is:  South Korea
# 3 Chinese Taipei
# At index:  23 ; Current HomeTeam is:  Chinese Taipei
# 4 India
# At index:  23 ; Current HomeTeam is:  India
# 5 Iran
# At index:  23 ; Current HomeTeam is:  Iran
# 6 Burma
# At index:  23 ; Current HomeTeam is:  Burma
# 7 Thailand
# At index:  23 ; Current HomeTeam is:  Thailand
# 8 Cambodia
# At index:  23 ; Current HomeTeam is:  Cambodia
# 9 Kuwait
# At index:  23 ; Current HomeTeam is:  Kuwait
# 10 China PR
# At index:  23 ; Current HomeTeam is:  China PR
# 11 Iraq
# At index:  23 ; Current HomeTeam is:  Iraq
# 12 North Korea
# At index:  23 ; Current HomeTeam is:  North Korea
# 13 Malaysia
# At index:  23 ; Current HomeTeam is:  Malaysia
# 14 Qatar
# At index:  23 ; Current HomeTeam is:  Qatar
# 15 Bangladesh
# At index:  23 ; Current HomeTeam is:  Bangladesh
# 16 United Arab Emirates
# At index:  23 ; Current HomeTeam is:  United Arab Emirates
# 17 Syria
# At index:  23 ; Current HomeTeam is:  Syria
# 18 Saudi Arabia
# At index:  23 ; Current HomeTeam is:  Saudi Arabia
# 19 Singapore
# At index:  23 ; Current HomeTeam is:  Singapore
# 20 Japan
# At index:  23 ; Current HomeTeam is:  Japan
# 21 Bahrain
# At index:  23 ; Current HomeTeam is:  Bahrain
# 22 Indonesia
# At index:  23 ; Current HomeTeam is:  Indonesia
# 23 Uzbekistan
# At index:  23 ; Current HomeTeam is:  Uzbekistan
# 24 Lebanon
# At index:  23 ; Current HomeTeam is:  Lebanon
# 25 Turkmenistan
# At index:  23 ; Current HomeTeam is:  Turkmenistan
# 26 Jordan
# At index:  23 ; Current HomeTeam is:  Jordan
# 27 Oman
# At index:  23 ; Current HomeTeam is:  Oman
# 28 Australia
# At index:  23 ; Current HomeTeam is:  Australia
# 29 Vietnam
# At index:  23 ; Current HomeTeam is:  Vietnam
# 30 Palestine
# At index:  23 ; Current HomeTeam is:  Palestine
# 31 Philippines
# At index:  23 ; Current HomeTeam is:  Philippines
# 32 Kyrgyzstan
# At index:  23 ; Current HomeTeam is:  Kyrgyzstan
# 33 Yemen
# At index:  23 ; Current HomeTeam is:  Yemen
# 0 Sudan
# At index:  24 ; Current HomeTeam is:  Sudan
# 1 Egypt
# At index:  24 ; Current HomeTeam is:  Egypt
# 2 Ethiopia
# At index:  24 ; Current HomeTeam is:  Ethiopia
# 3 Tunisia
# At index:  24 ; Current HomeTeam is:  Tunisia
# 4 Ghana
# At index:  24 ; Current HomeTeam is:  Ghana
# 5 Nigeria
# At index:  24 ; Current HomeTeam is:  Nigeria
# 6 DR Congo
# At index:  24 ; Current HomeTeam is:  DR Congo
# 7 Ivory Coast
# At index:  24 ; Current HomeTeam is:  Ivory Coast
# 8 Algeria
# At index:  24 ; Current HomeTeam is:  Algeria
# 9 Congo
# At index:  24 ; Current HomeTeam is:  Congo
# 10 Cameroon
# At index:  24 ; Current HomeTeam is:  Cameroon
# 11 Mali
# At index:  24 ; Current HomeTeam is:  Mali
# 12 Kenya
# At index:  24 ; Current HomeTeam is:  Kenya
# 13 Morocco
# At index:  24 ; Current HomeTeam is:  Morocco
# 14 Guinea
# At index:  24 ; Current HomeTeam is:  Guinea
# 15 Uganda
# At index:  24 ; Current HomeTeam is:  Uganda
# 16 Mauritius
# At index:  24 ; Current HomeTeam is:  Mauritius
# 17 Burkina Faso
# At index:  24 ; Current HomeTeam is:  Burkina Faso
# 18 Libya
# At index:  24 ; Current HomeTeam is:  Libya
# 19 Malawi
# At index:  24 ; Current HomeTeam is:  Malawi
# 20 Mozambique
# At index:  24 ; Current HomeTeam is:  Mozambique
# 21 Senegal
# At index:  24 ; Current HomeTeam is:  Senegal
# 22 Zambia
# At index:  24 ; Current HomeTeam is:  Zambia
# 23 South Africa
# At index:  24 ; Current HomeTeam is:  South Africa
# 24 Sierra Leone
# At index:  24 ; Current HomeTeam is:  Sierra Leone
# 25 Gabon
# At index:  24 ; Current HomeTeam is:  Gabon
# 26 Angola
# At index:  24 ; Current HomeTeam is:  Angola
# 27 Liberia
# At index:  24 ; Current HomeTeam is:  Liberia
# 28 Togo
# At index:  24 ; Current HomeTeam is:  Togo
# 29 Zimbabwe
# At index:  24 ; Current HomeTeam is:  Zimbabwe
# 30 Rwanda
# At index:  24 ; Current HomeTeam is:  Rwanda
# 31 Namibia
# At index:  24 ; Current HomeTeam is:  Namibia
# 32 Equatorial Guinea
# At index:  24 ; Current HomeTeam is:  Equatorial Guinea
# 33 Niger
# At index:  24 ; Current HomeTeam is:  Niger
# 34 Botswana
# At index:  24 ; Current HomeTeam is:  Botswana
# 35 Cape Verde
# At index:  24 ; Current HomeTeam is:  Cape Verde
# 36 Guinea-Bissau
# At index:  24 ; Current HomeTeam is:  Guinea-Bissau
# 37 Madagascar
# At index:  24 ; Current HomeTeam is:  Madagascar
# 38 Mauritania
# At index:  24 ; Current HomeTeam is:  Mauritania
# 39 Benin
# At index:  24 ; Current HomeTeam is:  Benin
# 40 Burundi
# At index:  24 ; Current HomeTeam is:  Burundi
# 41 Tanzania
# At index:  24 ; Current HomeTeam is:  Tanzania
# 0 Paraguay
# At index:  25 ; Current HomeTeam is:  Paraguay
# 1 Bolivia
# At index:  25 ; Current HomeTeam is:  Bolivia
# 0 Cambodia
# At index:  26 ; Current HomeTeam is:  Cambodia
# 1 Indonesia
# At index:  26 ; Current HomeTeam is:  Indonesia
# 2 Singapore
# At index:  26 ; Current HomeTeam is:  Singapore
# 3 Malaysia
# At index:  26 ; Current HomeTeam is:  Malaysia
# 4 Hong Kong
# At index:  26 ; Current HomeTeam is:  Hong Kong
# 5 Burma
# At index:  26 ; Current HomeTeam is:  Burma
# 6 South Korea
# At index:  26 ; Current HomeTeam is:  South Korea
# 7 India
# At index:  26 ; Current HomeTeam is:  India
# 8 Japan
# At index:  26 ; Current HomeTeam is:  Japan
# 9 Pakistan
# At index:  26 ; Current HomeTeam is:  Pakistan
# 10 Vietnam Republic
# At index:  26 ; Current HomeTeam is:  Vietnam Republic
# 11 Philippines
# At index:  26 ; Current HomeTeam is:  Philippines
# 12 Thailand
# At index:  26 ; Current HomeTeam is:  Thailand
# 13 Bangladesh
# At index:  26 ; Current HomeTeam is:  Bangladesh
# 14 Kuwait
# At index:  26 ; Current HomeTeam is:  Kuwait
# 15 Iraq
# At index:  26 ; Current HomeTeam is:  Iraq
# 16 Libya
# At index:  26 ; Current HomeTeam is:  Libya
# 17 Syria
# At index:  26 ; Current HomeTeam is:  Syria
# 18 Morocco
# At index:  26 ; Current HomeTeam is:  Morocco
# 19 New Zealand
# At index:  26 ; Current HomeTeam is:  New Zealand
# 20 Ghana
# At index:  26 ; Current HomeTeam is:  Ghana
# 21 Algeria
# At index:  26 ; Current HomeTeam is:  Algeria
# 22 Liberia
# At index:  26 ; Current HomeTeam is:  Liberia
# 23 Oman
# At index:  26 ; Current HomeTeam is:  Oman
# 24 Uzbekistan
# At index:  26 ; Current HomeTeam is:  Uzbekistan
# 25 Bulgaria
# At index:  26 ; Current HomeTeam is:  Bulgaria
# 26 Bahrain
# At index:  26 ; Current HomeTeam is:  Bahrain
# 27 Bosnia and Herzegovina
# At index:  26 ; Current HomeTeam is:  Bosnia and Herzegovina
# 28 Lesotho
# At index:  26 ; Current HomeTeam is:  Lesotho
# 29 Nepal
# At index:  26 ; Current HomeTeam is:  Nepal
# 0 Russia
# At index:  27 ; Current HomeTeam is:  Russia
# 1 France
# At index:  27 ; Current HomeTeam is:  France
# 2 Romania
# At index:  27 ; Current HomeTeam is:  Romania
# 3 Greece
# At index:  27 ; Current HomeTeam is:  Greece
# 4 Republic of Ireland
# At index:  27 ; Current HomeTeam is:  Republic of Ireland
# 5 Turkey
# At index:  27 ; Current HomeTeam is:  Turkey
# 6 Czechoslovakia
# At index:  27 ; Current HomeTeam is:  Czechoslovakia
# 7 Norway
# At index:  27 ; Current HomeTeam is:  Norway
# 8 Yugoslavia
# At index:  27 ; Current HomeTeam is:  Yugoslavia
# 9 German DR
# At index:  27 ; Current HomeTeam is:  German DR
# 10 Poland
# At index:  27 ; Current HomeTeam is:  Poland
# 11 Portugal
# At index:  27 ; Current HomeTeam is:  Portugal
# 12 Austria
# At index:  27 ; Current HomeTeam is:  Austria
# 13 Denmark
# At index:  27 ; Current HomeTeam is:  Denmark
# 14 Hungary
# At index:  27 ; Current HomeTeam is:  Hungary
# 15 Spain
# At index:  27 ; Current HomeTeam is:  Spain
# 16 Bulgaria
# At index:  27 ; Current HomeTeam is:  Bulgaria
# 17 Iceland
# At index:  27 ; Current HomeTeam is:  Iceland
# 18 England
# At index:  27 ; Current HomeTeam is:  England
# 19 Sweden
# At index:  27 ; Current HomeTeam is:  Sweden
# 20 Netherlands
# At index:  27 ; Current HomeTeam is:  Netherlands
# 21 Northern Ireland
# At index:  27 ; Current HomeTeam is:  Northern Ireland
# 22 Italy
# At index:  27 ; Current HomeTeam is:  Italy
# 23 Malta
# At index:  27 ; Current HomeTeam is:  Malta
# 24 Wales
# At index:  27 ; Current HomeTeam is:  Wales
# 25 Belgium
# At index:  27 ; Current HomeTeam is:  Belgium
# 26 Switzerland
# At index:  27 ; Current HomeTeam is:  Switzerland
# 27 Albania
# At index:  27 ; Current HomeTeam is:  Albania
# 28 Luxembourg
# At index:  27 ; Current HomeTeam is:  Luxembourg
# 29 Finland
# At index:  27 ; Current HomeTeam is:  Finland
# 30 Scotland
# At index:  27 ; Current HomeTeam is:  Scotland
# 31 Cyprus
# At index:  27 ; Current HomeTeam is:  Cyprus
# 32 Germany
# At index:  27 ; Current HomeTeam is:  Germany
# 33 Faroe Islands
# At index:  27 ; Current HomeTeam is:  Faroe Islands
# 34 San Marino
# At index:  27 ; Current HomeTeam is:  San Marino
# 35 Estonia
# At index:  27 ; Current HomeTeam is:  Estonia
# 36 Israel
# At index:  27 ; Current HomeTeam is:  Israel
# 37 Czech Republic
# At index:  27 ; Current HomeTeam is:  Czech Republic
# 38 Georgia
# At index:  27 ; Current HomeTeam is:  Georgia
# 39 Latvia
# At index:  27 ; Current HomeTeam is:  Latvia
# 40 Liechtenstein
# At index:  27 ; Current HomeTeam is:  Liechtenstein
# 41 North Macedonia
# At index:  27 ; Current HomeTeam is:  North Macedonia
# 42 Slovakia
# At index:  27 ; Current HomeTeam is:  Slovakia
# 43 Slovenia
# At index:  27 ; Current HomeTeam is:  Slovenia
# 44 Ukraine
# At index:  27 ; Current HomeTeam is:  Ukraine
# 45 Armenia
# At index:  27 ; Current HomeTeam is:  Armenia
# 46 Croatia
# At index:  27 ; Current HomeTeam is:  Croatia
# 47 Belarus
# At index:  27 ; Current HomeTeam is:  Belarus
# 48 Moldova
# At index:  27 ; Current HomeTeam is:  Moldova
# 49 Azerbaijan
# At index:  27 ; Current HomeTeam is:  Azerbaijan
# 50 Lithuania
# At index:  27 ; Current HomeTeam is:  Lithuania
# 51 Bosnia and Herzegovina
# At index:  27 ; Current HomeTeam is:  Bosnia and Herzegovina
# 52 Andorra
# At index:  27 ; Current HomeTeam is:  Andorra
# 53 Serbia
# At index:  27 ; Current HomeTeam is:  Serbia
# 54 Kazakhstan
# At index:  27 ; Current HomeTeam is:  Kazakhstan
# 55 Montenegro
# At index:  27 ; Current HomeTeam is:  Montenegro
# 56 Gibraltar
# At index:  27 ; Current HomeTeam is:  Gibraltar
# 57 Kosovo
# At index:  27 ; Current HomeTeam is:  Kosovo
# 0 Czechoslovakia
# At index:  28 ; Current HomeTeam is:  Czechoslovakia
# 1 France
# At index:  28 ; Current HomeTeam is:  France
# 2 Russia
# At index:  28 ; Current HomeTeam is:  Russia
# 3 Denmark
# At index:  28 ; Current HomeTeam is:  Denmark
# 4 Spain
# At index:  28 ; Current HomeTeam is:  Spain
# 5 Hungary
# At index:  28 ; Current HomeTeam is:  Hungary
# 6 England
# At index:  28 ; Current HomeTeam is:  England
# 7 Italy
# At index:  28 ; Current HomeTeam is:  Italy
# 8 Belgium
# At index:  28 ; Current HomeTeam is:  Belgium
# 9 Germany
# At index:  28 ; Current HomeTeam is:  Germany
# 10 Yugoslavia
# At index:  28 ; Current HomeTeam is:  Yugoslavia
# 11 Netherlands
# At index:  28 ; Current HomeTeam is:  Netherlands
# 12 Greece
# At index:  28 ; Current HomeTeam is:  Greece
# 13 Romania
# At index:  28 ; Current HomeTeam is:  Romania
# 14 Portugal
# At index:  28 ; Current HomeTeam is:  Portugal
# 15 Republic of Ireland
# At index:  28 ; Current HomeTeam is:  Republic of Ireland
# 16 Sweden
# At index:  28 ; Current HomeTeam is:  Sweden
# 17 Scotland
# At index:  28 ; Current HomeTeam is:  Scotland
# 18 Turkey
# At index:  28 ; Current HomeTeam is:  Turkey
# 19 Bulgaria
# At index:  28 ; Current HomeTeam is:  Bulgaria
# 20 Switzerland
# At index:  28 ; Current HomeTeam is:  Switzerland
# 21 Czech Republic
# At index:  28 ; Current HomeTeam is:  Czech Republic
# 22 Croatia
# At index:  28 ; Current HomeTeam is:  Croatia
# 23 Serbia
# At index:  28 ; Current HomeTeam is:  Serbia
# 24 Norway
# At index:  28 ; Current HomeTeam is:  Norway
# 25 Slovenia
# At index:  28 ; Current HomeTeam is:  Slovenia
# 26 Latvia
# At index:  28 ; Current HomeTeam is:  Latvia
# 27 Austria
# At index:  28 ; Current HomeTeam is:  Austria
# 28 Poland
# At index:  28 ; Current HomeTeam is:  Poland
# 29 Ukraine
# At index:  28 ; Current HomeTeam is:  Ukraine
# 30 Albania
# At index:  28 ; Current HomeTeam is:  Albania
# 31 Wales
# At index:  28 ; Current HomeTeam is:  Wales
# 32 Iceland
# At index:  28 ; Current HomeTeam is:  Iceland
# 33 Slovakia
# At index:  28 ; Current HomeTeam is:  Slovakia
# 34 Northern Ireland
# At index:  28 ; Current HomeTeam is:  Northern Ireland
# 0 Saint Lucia
# At index:  29 ; Current HomeTeam is:  Saint Lucia
# 1 Grenada
# At index:  29 ; Current HomeTeam is:  Grenada
# 2 Dominica
# At index:  29 ; Current HomeTeam is:  Dominica
# 3 Saint Vincent and the Grenadines
# At index:  29 ; Current HomeTeam is:  Saint Vincent and the Grenadines
# 4 Barbados
# At index:  29 ; Current HomeTeam is:  Barbados
# 0 Nigeria
# At index:  30 ; Current HomeTeam is:  Nigeria
# 1 Ghana
# At index:  30 ; Current HomeTeam is:  Ghana
# 2 Kenya
# At index:  30 ; Current HomeTeam is:  Kenya
# 3 Uganda
# At index:  30 ; Current HomeTeam is:  Uganda
# 4 Tunisia
# At index:  30 ; Current HomeTeam is:  Tunisia
# 5 Sudan
# At index:  30 ; Current HomeTeam is:  Sudan
# 6 Morocco
# At index:  30 ; Current HomeTeam is:  Morocco
# 7 Guinea
# At index:  30 ; Current HomeTeam is:  Guinea
# 8 Ivory Coast
# At index:  30 ; Current HomeTeam is:  Ivory Coast
# 9 Ethiopia
# At index:  30 ; Current HomeTeam is:  Ethiopia
# 10 Mali
# At index:  30 ; Current HomeTeam is:  Mali
# 11 Senegal
# At index:  30 ; Current HomeTeam is:  Senegal
# 12 Liberia
# At index:  30 ; Current HomeTeam is:  Liberia
# 13 DR Congo
# At index:  30 ; Current HomeTeam is:  DR Congo
# 14 Libya
# At index:  30 ; Current HomeTeam is:  Libya
# 15 Burkina Faso
# At index:  30 ; Current HomeTeam is:  Burkina Faso
# 16 Cameroon
# At index:  30 ; Current HomeTeam is:  Cameroon
# 17 Algeria
# At index:  30 ; Current HomeTeam is:  Algeria
# 18 Tanzania
# At index:  30 ; Current HomeTeam is:  Tanzania
# 19 Mauritius
# At index:  30 ; Current HomeTeam is:  Mauritius
# 20 Togo
# At index:  30 ; Current HomeTeam is:  Togo
# 21 Zambia
# At index:  30 ; Current HomeTeam is:  Zambia
# 22 Egypt
# At index:  30 ; Current HomeTeam is:  Egypt
# 23 Niger
# At index:  30 ; Current HomeTeam is:  Niger
# 24 Gabon
# At index:  30 ; Current HomeTeam is:  Gabon
# 25 Madagascar
# At index:  30 ; Current HomeTeam is:  Madagascar
# 26 Benin
# At index:  30 ; Current HomeTeam is:  Benin
# 27 Congo
# At index:  30 ; Current HomeTeam is:  Congo
# 28 Central African Republic
# At index:  30 ; Current HomeTeam is:  Central African Republic
# 29 Somalia
# At index:  30 ; Current HomeTeam is:  Somalia
# 30 Burundi
# At index:  30 ; Current HomeTeam is:  Burundi
# 31 Gambia
# At index:  30 ; Current HomeTeam is:  Gambia
# 32 Malawi
# At index:  30 ; Current HomeTeam is:  Malawi
# 33 Lesotho
# At index:  30 ; Current HomeTeam is:  Lesotho
# 34 Mozambique
# At index:  30 ; Current HomeTeam is:  Mozambique
# 35 Mauritania
# At index:  30 ; Current HomeTeam is:  Mauritania
# 36 Zimbabwe
# At index:  30 ; Current HomeTeam is:  Zimbabwe
# 37 Sierra Leone
# At index:  30 ; Current HomeTeam is:  Sierra Leone
# 38 Rwanda
# At index:  30 ; Current HomeTeam is:  Rwanda
# 39 Angola
# At index:  30 ; Current HomeTeam is:  Angola
# 40 Eswatini
# At index:  30 ; Current HomeTeam is:  Eswatini
# 41 Equatorial Guinea
# At index:  30 ; Current HomeTeam is:  Equatorial Guinea
# 42 Chad
# At index:  30 ; Current HomeTeam is:  Chad
# 43 Guinea-Bissau
# At index:  30 ; Current HomeTeam is:  Guinea-Bissau
# 44 Botswana
# At index:  30 ; Current HomeTeam is:  Botswana
# 45 Cape Verde
# At index:  30 ; Current HomeTeam is:  Cape Verde
# 46 South Africa
# At index:  30 ; Current HomeTeam is:  South Africa
# 47 Namibia
# At index:  30 ; Current HomeTeam is:  Namibia
# 48 Seychelles
# At index:  30 ; Current HomeTeam is:  Seychelles
# 49 São Tomé and Príncipe
# At index:  30 ; Current HomeTeam is:  São Tomé and Príncipe
# 50 Eritrea
# At index:  30 ; Current HomeTeam is:  Eritrea
# 51 Djibouti
# At index:  30 ; Current HomeTeam is:  Djibouti
# 52 Comoros
# At index:  30 ; Current HomeTeam is:  Comoros
# 53 South Sudan
# At index:  30 ; Current HomeTeam is:  South Sudan
# 0 Vietnam Republic
# At index:  31 ; Current HomeTeam is:  Vietnam Republic
# 1 Indonesia
# At index:  31 ; Current HomeTeam is:  Indonesia
# 2 Malaysia
# At index:  31 ; Current HomeTeam is:  Malaysia
# 3 Australia
# At index:  31 ; Current HomeTeam is:  Australia
# 4 Hong Kong
# At index:  31 ; Current HomeTeam is:  Hong Kong
# 5 South Korea
# At index:  31 ; Current HomeTeam is:  South Korea
# 6 New Zealand
# At index:  31 ; Current HomeTeam is:  New Zealand
# 7 Singapore
# At index:  31 ; Current HomeTeam is:  Singapore
# 8 Cambodia
# At index:  31 ; Current HomeTeam is:  Cambodia
# 9 Laos
# At index:  31 ; Current HomeTeam is:  Laos
# 0 Chile
# At index:  32 ; Current HomeTeam is:  Chile
# 1 Argentina
# At index:  32 ; Current HomeTeam is:  Argentina
# 0 Guatemala
# At index:  33 ; Current HomeTeam is:  Guatemala
# 1 Costa Rica
# At index:  33 ; Current HomeTeam is:  Costa Rica
# 2 Mexico
# At index:  33 ; Current HomeTeam is:  Mexico
# 3 Jamaica
# At index:  33 ; Current HomeTeam is:  Jamaica
# 4 Nicaragua
# At index:  33 ; Current HomeTeam is:  Nicaragua
# 5 Honduras
# At index:  33 ; Current HomeTeam is:  Honduras
# 6 El Salvador
# At index:  33 ; Current HomeTeam is:  El Salvador
# 7 Haiti
# At index:  33 ; Current HomeTeam is:  Haiti
# 8 Curaçao
# At index:  33 ; Current HomeTeam is:  Curaçao
# 9 Cuba
# At index:  33 ; Current HomeTeam is:  Cuba
# 10 Trinidad and Tobago
# At index:  33 ; Current HomeTeam is:  Trinidad and Tobago
# 0 Uruguay
# At index:  34 ; Current HomeTeam is:  Uruguay
# 1 Chile
# At index:  34 ; Current HomeTeam is:  Chile
# 0 Lebanon
# At index:  35 ; Current HomeTeam is:  Lebanon
# 1 Syria
# At index:  35 ; Current HomeTeam is:  Syria
# 2 Jordan
# At index:  35 ; Current HomeTeam is:  Jordan
# 3 Kuwait
# At index:  35 ; Current HomeTeam is:  Kuwait
# 4 Libya
# At index:  35 ; Current HomeTeam is:  Libya
# 5 Iraq
# At index:  35 ; Current HomeTeam is:  Iraq
# 6 Bahrain
# At index:  35 ; Current HomeTeam is:  Bahrain
# 7 Palestine
# At index:  35 ; Current HomeTeam is:  Palestine
# 8 Saudi Arabia
# At index:  35 ; Current HomeTeam is:  Saudi Arabia
# 9 Algeria
# At index:  35 ; Current HomeTeam is:  Algeria
# 10 Mauritania
# At index:  35 ; Current HomeTeam is:  Mauritania
# 11 Egypt
# At index:  35 ; Current HomeTeam is:  Egypt
# 12 Qatar
# At index:  35 ; Current HomeTeam is:  Qatar
# 13 United Arab Emirates
# At index:  35 ; Current HomeTeam is:  United Arab Emirates
# 14 Yemen
# At index:  35 ; Current HomeTeam is:  Yemen
# 15 Sudan
# At index:  35 ; Current HomeTeam is:  Sudan
# 16 Morocco
# At index:  35 ; Current HomeTeam is:  Morocco
# 0 Fiji
# At index:  36 ; Current HomeTeam is:  Fiji
# 1 Solomon Islands
# At index:  36 ; Current HomeTeam is:  Solomon Islands
# 2 New Caledonia
# At index:  36 ; Current HomeTeam is:  New Caledonia
# 3 Papua New Guinea
# At index:  36 ; Current HomeTeam is:  Papua New Guinea
# 4 Tahiti
# At index:  36 ; Current HomeTeam is:  Tahiti
# 5 Vanuatu
# At index:  36 ; Current HomeTeam is:  Vanuatu
# 6 Cook Islands
# At index:  36 ; Current HomeTeam is:  Cook Islands
# 7 Guam
# At index:  36 ; Current HomeTeam is:  Guam
# 8 Kiribati
# At index:  36 ; Current HomeTeam is:  Kiribati
# 9 Tonga
# At index:  36 ; Current HomeTeam is:  Tonga
# 10 Wallis Islands and Futuna
# At index:  36 ; Current HomeTeam is:  Wallis Islands and Futuna
# 11 Niue
# At index:  36 ; Current HomeTeam is:  Niue
# 12 Samoa
# At index:  36 ; Current HomeTeam is:  Samoa
# 13 American Samoa
# At index:  36 ; Current HomeTeam is:  American Samoa
# 14 Tuvalu
# At index:  36 ; Current HomeTeam is:  Tuvalu
# 15 Micronesia
# At index:  36 ; Current HomeTeam is:  Micronesia
# 0 El Salvador
# At index:  37 ; Current HomeTeam is:  El Salvador
# 1 Honduras
# At index:  37 ; Current HomeTeam is:  Honduras
# 2 Jamaica
# At index:  37 ; Current HomeTeam is:  Jamaica
# 3 Cuba
# At index:  37 ; Current HomeTeam is:  Cuba
# 4 Curaçao
# At index:  37 ; Current HomeTeam is:  Curaçao
# 5 Guatemala
# At index:  37 ; Current HomeTeam is:  Guatemala
# 6 Nicaragua
# At index:  37 ; Current HomeTeam is:  Nicaragua
# 0 Paraguay
# At index:  38 ; Current HomeTeam is:  Paraguay
# 1 Uruguay
# At index:  38 ; Current HomeTeam is:  Uruguay
# 0 Palestine
# At index:  39 ; Current HomeTeam is:  Palestine
# 1 Cambodia
# At index:  39 ; Current HomeTeam is:  Cambodia
# 2 China PR
# At index:  39 ; Current HomeTeam is:  China PR
# 3 North Vietnam
# At index:  39 ; Current HomeTeam is:  North Vietnam
# 4 North Korea
# At index:  39 ; Current HomeTeam is:  North Korea
# 0 Burma
# At index:  40 ; Current HomeTeam is:  Burma
# 1 Thailand
# At index:  40 ; Current HomeTeam is:  Thailand
# 2 Indonesia
# At index:  40 ; Current HomeTeam is:  Indonesia
# 3 Laos
# At index:  40 ; Current HomeTeam is:  Laos
# 4 South Korea
# At index:  40 ; Current HomeTeam is:  South Korea
# 5 Vietnam Republic
# At index:  40 ; Current HomeTeam is:  Vietnam Republic
# 6 Singapore
# At index:  40 ; Current HomeTeam is:  Singapore
# 7 Hong Kong
# At index:  40 ; Current HomeTeam is:  Hong Kong
# 8 Cambodia
# At index:  40 ; Current HomeTeam is:  Cambodia
# 9 Malaysia
# At index:  40 ; Current HomeTeam is:  Malaysia
# 10 Bangladesh
# At index:  40 ; Current HomeTeam is:  Bangladesh
# 11 India
# At index:  40 ; Current HomeTeam is:  India
# 12 Brunei
# At index:  40 ; Current HomeTeam is:  Brunei
# 13 Pakistan
# At index:  40 ; Current HomeTeam is:  Pakistan
# 14 Nepal
# At index:  40 ; Current HomeTeam is:  Nepal
# 15 Philippines
# At index:  40 ; Current HomeTeam is:  Philippines
# 16 North Korea
# At index:  40 ; Current HomeTeam is:  North Korea
# 17 China PR
# At index:  40 ; Current HomeTeam is:  China PR
# 18 Japan
# At index:  40 ; Current HomeTeam is:  Japan
# 19 Egypt
# At index:  40 ; Current HomeTeam is:  Egypt
# 20 Estonia
# At index:  40 ; Current HomeTeam is:  Estonia
# 21 Sweden
# At index:  40 ; Current HomeTeam is:  Sweden
# 22 Qatar
# At index:  40 ; Current HomeTeam is:  Qatar
# 23 Hungary
# At index:  40 ; Current HomeTeam is:  Hungary
# 24 Latvia
# At index:  40 ; Current HomeTeam is:  Latvia
# 25 Vietnam
# At index:  40 ; Current HomeTeam is:  Vietnam
# 26 Poland
# At index:  40 ; Current HomeTeam is:  Poland
# 27 United Arab Emirates
# At index:  40 ; Current HomeTeam is:  United Arab Emirates
# 28 Burkina Faso
# At index:  40 ; Current HomeTeam is:  Burkina Faso
# 0 Bahrain
# At index:  41 ; Current HomeTeam is:  Bahrain
# 1 Saudi Arabia
# At index:  41 ; Current HomeTeam is:  Saudi Arabia
# 2 Kuwait
# At index:  41 ; Current HomeTeam is:  Kuwait
# 3 Qatar
# At index:  41 ; Current HomeTeam is:  Qatar
# 4 Oman
# At index:  41 ; Current HomeTeam is:  Oman
# 5 Iraq
# At index:  41 ; Current HomeTeam is:  Iraq
# 6 United Arab Emirates
# At index:  41 ; Current HomeTeam is:  United Arab Emirates
# 7 Yemen
# At index:  41 ; Current HomeTeam is:  Yemen
# 0 Malaysia
# At index:  42 ; Current HomeTeam is:  Malaysia
# 1 Indonesia
# At index:  42 ; Current HomeTeam is:  Indonesia
# 2 South Korea
# At index:  42 ; Current HomeTeam is:  South Korea
# 3 Hong Kong
# At index:  42 ; Current HomeTeam is:  Hong Kong
# 4 Cambodia
# At index:  42 ; Current HomeTeam is:  Cambodia
# 5 India
# At index:  42 ; Current HomeTeam is:  India
# 6 Burma
# At index:  42 ; Current HomeTeam is:  Burma
# 7 Philippines
# At index:  42 ; Current HomeTeam is:  Philippines
# 8 Laos
# At index:  42 ; Current HomeTeam is:  Laos
# 9 Singapore
# At index:  42 ; Current HomeTeam is:  Singapore
# 10 Algeria
# ...
# 0 Northern Cyprus
# At index:  86 ; Current HomeTeam is:  Northern Cyprus
# 1 Republic of St. Pauli
# At index:  86 ; Current HomeTeam is:  Republic of St. Pauli
# 2 Zanzibar
# At index:  86 ; Current HomeTeam is:  Zanzibar
# 3 Gibraltar
# At index:  86 ; Current HomeTeam is:  Gibraltar
# 4 Greenland
# At index:  86 ; Current HomeTeam is:  Greenland
# 0 Găgăuzia
# At index:  87 ; Current HomeTeam is:  Găgăuzia
# 1 Kyrgyzstan
# At index:  87 ; Current HomeTeam is:  Kyrgyzstan
# 2 Tibet
# At index:  87 ; Current HomeTeam is:  Tibet
# 3 Crimea
# At index:  87 ; Current HomeTeam is:  Crimea
# 4 Greenland
# At index:  87 ; Current HomeTeam is:  Greenland
# 5 Northern Cyprus
# At index:  87 ; Current HomeTeam is:  Northern Cyprus
# 6 Tajikistan
# At index:  87 ; Current HomeTeam is:  Tajikistan
# 0 Occitania
# At index:  88 ; Current HomeTeam is:  Occitania
# 1 Sápmi
# At index:  88 ; Current HomeTeam is:  Sápmi
# 2 Provence
# At index:  88 ; Current HomeTeam is:  Provence
# 3 Arameans Suryoye
# At index:  88 ; Current HomeTeam is:  Arameans Suryoye
# 4 Padania
# At index:  88 ; Current HomeTeam is:  Padania
# 5 Iraqi Kurdistan
# At index:  88 ; Current HomeTeam is:  Iraqi Kurdistan
# 6 Gozo
# At index:  88 ; Current HomeTeam is:  Gozo
# 7 Zanzibar
# At index:  88 ; Current HomeTeam is:  Zanzibar
# 8 Northern Cyprus
# At index:  88 ; Current HomeTeam is:  Northern Cyprus
# 9 Western Sahara
# At index:  88 ; Current HomeTeam is:  Western Sahara
# 10 Raetia
# At index:  88 ; Current HomeTeam is:  Raetia
# 11 Darfur
# At index:  88 ; Current HomeTeam is:  Darfur
# 12 Tamil Eelam
# At index:  88 ; Current HomeTeam is:  Tamil Eelam
# 0 Yemen
# At index:  89 ; Current HomeTeam is:  Yemen
# 1 Djibouti
# At index:  89 ; Current HomeTeam is:  Djibouti
# 2 Lebanon
# At index:  89 ; Current HomeTeam is:  Lebanon
# 3 Sudan
# At index:  89 ; Current HomeTeam is:  Sudan
# 4 Somalia
# At index:  89 ; Current HomeTeam is:  Somalia
# 0 Sri Lanka
# At index:  90 ; Current HomeTeam is:  Sri Lanka
# 1 Pakistan
# At index:  90 ; Current HomeTeam is:  Pakistan
# 2 Chinese Taipei
# At index:  90 ; Current HomeTeam is:  Chinese Taipei
# 3 Bangladesh
# At index:  90 ; Current HomeTeam is:  Bangladesh
# 4 Kyrgyzstan
# At index:  90 ; Current HomeTeam is:  Kyrgyzstan
# 5 Philippines
# At index:  90 ; Current HomeTeam is:  Philippines
# 6 Tajikistan
# At index:  90 ; Current HomeTeam is:  Tajikistan
# 7 Bhutan
# At index:  90 ; Current HomeTeam is:  Bhutan
# 8 Nepal
# At index:  90 ; Current HomeTeam is:  Nepal
# 9 Cambodia
# At index:  90 ; Current HomeTeam is:  Cambodia
# 10 Brunei
# At index:  90 ; Current HomeTeam is:  Brunei
# 11 Macau
# At index:  90 ; Current HomeTeam is:  Macau
# 12 Maldives
# At index:  90 ; Current HomeTeam is:  Maldives
# 13 Mongolia
# At index:  90 ; Current HomeTeam is:  Mongolia
# 14 Turkmenistan
# At index:  90 ; Current HomeTeam is:  Turkmenistan
# 15 Burma
# At index:  90 ; Current HomeTeam is:  Burma
# 16 Laos
# At index:  90 ; Current HomeTeam is:  Laos
# 17 India
# At index:  90 ; Current HomeTeam is:  India
# 18 Palestine
# At index:  90 ; Current HomeTeam is:  Palestine
# 19 Afghanistan
# At index:  90 ; Current HomeTeam is:  Afghanistan
# 20 North Korea
# At index:  90 ; Current HomeTeam is:  North Korea
# 21 Guam
# At index:  90 ; Current HomeTeam is:  Guam
# 22 Northern Mariana Islands
# At index:  90 ; Current HomeTeam is:  Northern Mariana Islands
# 0 Guadeloupe
# At index:  91 ; Current HomeTeam is:  Guadeloupe
# 1 Tahiti
# At index:  91 ; Current HomeTeam is:  Tahiti
# 2 Mayotte
# At index:  91 ; Current HomeTeam is:  Mayotte
# 3 New Caledonia
# At index:  91 ; Current HomeTeam is:  New Caledonia
# 4 French Guiana
# At index:  91 ; Current HomeTeam is:  French Guiana
# 5 Martinique
# At index:  91 ; Current HomeTeam is:  Martinique
# 6 Réunion
# At index:  91 ; Current HomeTeam is:  Réunion
# 7 St. Pierre & Miquelon
# At index:  91 ; Current HomeTeam is:  St. Pierre & Miquelon
# 8 Burkina Faso
# At index:  91 ; Current HomeTeam is:  Burkina Faso
# 9 Mauritius
# At index:  91 ; Current HomeTeam is:  Mauritius
# 10 Guinea
# At index:  91 ; Current HomeTeam is:  Guinea
# 11 Liberia
# At index:  91 ; Current HomeTeam is:  Liberia
# 12 Mozambique
# At index:  91 ; Current HomeTeam is:  Mozambique
# 13 Comoros
# At index:  91 ; Current HomeTeam is:  Comoros
# 14 Mauritania
# At index:  91 ; Current HomeTeam is:  Mauritania
# 15 Seychelles
# At index:  91 ; Current HomeTeam is:  Seychelles
# 16 Sierra Leone
# At index:  91 ; Current HomeTeam is:  Sierra Leone
# 17 Burundi
# At index:  91 ; Current HomeTeam is:  Burundi
# 18 Togo
# At index:  91 ; Current HomeTeam is:  Togo
# 19 Kenya
# At index:  91 ; Current HomeTeam is:  Kenya
# 20 Eswatini
# At index:  91 ; Current HomeTeam is:  Eswatini
# 21 Angola
# At index:  91 ; Current HomeTeam is:  Angola
# 22 Mali
# At index:  91 ; Current HomeTeam is:  Mali
# 23 Nigeria
# At index:  91 ; Current HomeTeam is:  Nigeria
# 24 DR Congo
# At index:  91 ; Current HomeTeam is:  DR Congo
# 25 Morocco
# At index:  91 ; Current HomeTeam is:  Morocco
# 26 Ivory Coast
# At index:  91 ; Current HomeTeam is:  Ivory Coast
# 27 Niger
# At index:  91 ; Current HomeTeam is:  Niger
# 28 Rwanda
# At index:  91 ; Current HomeTeam is:  Rwanda
# 29 Uganda
# At index:  91 ; Current HomeTeam is:  Uganda
# 30 Cameroon
# At index:  91 ; Current HomeTeam is:  Cameroon
# 31 Congo
# At index:  91 ; Current HomeTeam is:  Congo
# 32 Sudan
# At index:  91 ; Current HomeTeam is:  Sudan
# 33 Namibia
# At index:  91 ; Current HomeTeam is:  Namibia
# 34 Zimbabwe
# At index:  91 ; Current HomeTeam is:  Zimbabwe
# 35 Gabon
# At index:  91 ; Current HomeTeam is:  Gabon
# 36 Zambia
# At index:  91 ; Current HomeTeam is:  Zambia
# 37 South Africa
# At index:  91 ; Current HomeTeam is:  South Africa
# 38 Ghana
# At index:  91 ; Current HomeTeam is:  Ghana
# 39 Libya
# At index:  91 ; Current HomeTeam is:  Libya
# 40 Ethiopia
# At index:  91 ; Current HomeTeam is:  Ethiopia
# 41 Senegal
# At index:  91 ; Current HomeTeam is:  Senegal
# 42 Tanzania
# At index:  91 ; Current HomeTeam is:  Tanzania
# 43 Djibouti
# At index:  91 ; Current HomeTeam is:  Djibouti
# 44 Lesotho
# At index:  91 ; Current HomeTeam is:  Lesotho
# 45 Tunisia
# At index:  91 ; Current HomeTeam is:  Tunisia
# 46 Somalia
# At index:  91 ; Current HomeTeam is:  Somalia
# 47 Madagascar
# At index:  91 ; Current HomeTeam is:  Madagascar
# 48 Malawi
# At index:  91 ; Current HomeTeam is:  Malawi
# 49 South Sudan
# At index:  91 ; Current HomeTeam is:  South Sudan
# 50 Botswana
# At index:  91 ; Current HomeTeam is:  Botswana
# 51 Gambia
# At index:  91 ; Current HomeTeam is:  Gambia
# 52 Guinea-Bissau
# At index:  91 ; Current HomeTeam is:  Guinea-Bissau
# 53 Benin
# At index:  91 ; Current HomeTeam is:  Benin
# 54 São Tomé and Príncipe
# At index:  91 ; Current HomeTeam is:  São Tomé and Príncipe
# 55 Algeria
# At index:  91 ; Current HomeTeam is:  Algeria
# 56 Egypt
# At index:  91 ; Current HomeTeam is:  Egypt
# 57 Equatorial Guinea
# At index:  91 ; Current HomeTeam is:  Equatorial Guinea
# 0 Thailand
# At index:  92 ; Current HomeTeam is:  Thailand
# 1 Vietnam
# At index:  92 ; Current HomeTeam is:  Vietnam
# 2 Singapore
# At index:  92 ; Current HomeTeam is:  Singapore
# 3 Laos
# At index:  92 ; Current HomeTeam is:  Laos
# 0 Philippines
# At index:  93 ; Current HomeTeam is:  Philippines
# 1 Hong Kong
# At index:  93 ; Current HomeTeam is:  Hong Kong
# 0 Curaçao
# At index:  94 ; Current HomeTeam is:  Curaçao
# 1 Suriname
# At index:  94 ; Current HomeTeam is:  Suriname
# 2 Aruba
# At index:  94 ; Current HomeTeam is:  Aruba
# 3 Bonaire
# At index:  94 ; Current HomeTeam is:  Bonaire
# 0 Egypt
# At index:  95 ; Current HomeTeam is:  Egypt
# 1 Kenya
# At index:  95 ; Current HomeTeam is:  Kenya
# 2 Uganda
# At index:  95 ; Current HomeTeam is:  Uganda
# 3 DR Congo
# At index:  95 ; Current HomeTeam is:  DR Congo
# 4 Tanzania
# At index:  95 ; Current HomeTeam is:  Tanzania
# 0 Republic of Ireland
# At index:  96 ; Current HomeTeam is:  Republic of Ireland
# 1 Scotland
# At index:  96 ; Current HomeTeam is:  Scotland
# 2 Wales
# At index:  96 ; Current HomeTeam is:  Wales
# 0 Fiji
# At index:  97 ; Current HomeTeam is:  Fiji
# 1 New Caledonia
# At index:  97 ; Current HomeTeam is:  New Caledonia
# 2 Papua New Guinea
# At index:  97 ; Current HomeTeam is:  Papua New Guinea
# 3 Solomon Islands
# At index:  97 ; Current HomeTeam is:  Solomon Islands
# 4 Tuvalu
# At index:  97 ; Current HomeTeam is:  Tuvalu
# 5 American Samoa
# At index:  97 ; Current HomeTeam is:  American Samoa
# 6 Tahiti
# At index:  97 ; Current HomeTeam is:  Tahiti
# 7 Vanuatu
# At index:  97 ; Current HomeTeam is:  Vanuatu
# 8 Cook Islands
# At index:  97 ; Current HomeTeam is:  Cook Islands
# 9 Guam
# At index:  97 ; Current HomeTeam is:  Guam
# 10 Kiribati
# At index:  97 ; Current HomeTeam is:  Kiribati
# 11 Samoa
# At index:  97 ; Current HomeTeam is:  Samoa
# 12 Tonga
# At index:  97 ; Current HomeTeam is:  Tonga
# 0 Saudi Arabia
# At index:  98 ; Current HomeTeam is:  Saudi Arabia
# 1 United Arab Emirates
# At index:  98 ; Current HomeTeam is:  United Arab Emirates
# 0 Iraqi Kurdistan
# At index:  99 ; Current HomeTeam is:  Iraqi Kurdistan
# 1 Abkhazia
# At index:  99 ; Current HomeTeam is:  Abkhazia
# 2 Darfur
# At index:  99 ; Current HomeTeam is:  Darfur
# 3 Ellan Vannin
# At index:  99 ; Current HomeTeam is:  Ellan Vannin
# 4 Tamil Eelam
# At index:  99 ; Current HomeTeam is:  Tamil Eelam
# 5 Sápmi
# At index:  99 ; Current HomeTeam is:  Sápmi
# 6 South Ossetia
# At index:  99 ; Current HomeTeam is:  South Ossetia
# 7 Artsakh
# At index:  99 ; Current HomeTeam is:  Artsakh
# 8 Padania
# At index:  99 ; Current HomeTeam is:  Padania
# 9 Arameans Suryoye
# At index:  99 ; Current HomeTeam is:  Arameans Suryoye
# 10 Occitania
# At index:  99 ; Current HomeTeam is:  Occitania
# 11 County of Nice
# At index:  99 ; Current HomeTeam is:  County of Nice
# 12 Chagos Islands
# At index:  99 ; Current HomeTeam is:  Chagos Islands
# 13 United Koreans in Japan
# At index:  99 ; Current HomeTeam is:  United Koreans in Japan
# 14 Raetia
# At index:  99 ; Current HomeTeam is:  Raetia
# 15 Northern Cyprus
# At index:  99 ; Current HomeTeam is:  Northern Cyprus
# 16 Somaliland
# At index:  99 ; Current HomeTeam is:  Somaliland
# 17 Western Armenia
# At index:  99 ; Current HomeTeam is:  Western Armenia
# 18 Székely Land
# At index:  99 ; Current HomeTeam is:  Székely Land
# 19 Barawa
# At index:  99 ; Current HomeTeam is:  Barawa
# 20 Panjab
# At index:  99 ; Current HomeTeam is:  Panjab
# 21 Kárpátalja
# At index:  99 ; Current HomeTeam is:  Kárpátalja
# 22 Tuvalu
# At index:  99 ; Current HomeTeam is:  Tuvalu
# 23 Matabeleland
# At index:  99 ; Current HomeTeam is:  Matabeleland
# 24 Tibet
# At index:  99 ; Current HomeTeam is:  Tibet
# 25 Cascadia
# At index:  99 ; Current HomeTeam is:  Cascadia
# 26 Kabylia
# At index:  99 ; Current HomeTeam is:  Kabylia
# 0 Székely Land
# At index:  100 ; Current HomeTeam is:  Székely Land
# 1 Padania
# At index:  100 ; Current HomeTeam is:  Padania
# 2 Romani people
# At index:  100 ; Current HomeTeam is:  Romani people
# 3 Felvidék
# At index:  100 ; Current HomeTeam is:  Felvidék
# 4 County of Nice
# At index:  100 ; Current HomeTeam is:  County of Nice
# 5 Ellan Vannin
# At index:  100 ; Current HomeTeam is:  Ellan Vannin
# 6 Northern Cyprus
# At index:  100 ; Current HomeTeam is:  Northern Cyprus
# 7 Abkhazia
# At index:  100 ; Current HomeTeam is:  Abkhazia
# 8 Kárpátalja
# At index:  100 ; Current HomeTeam is:  Kárpátalja
# 9 South Ossetia
# At index:  100 ; Current HomeTeam is:  South Ossetia
# 10 Artsakh
# At index:  100 ; Current HomeTeam is:  Artsakh
# 11 Western Armenia
# At index:  100 ; Current HomeTeam is:  Western Armenia
# 12 Sápmi
# At index:  100 ; Current HomeTeam is:  Sápmi
# 13 Chameria
# At index:  100 ; Current HomeTeam is:  Chameria
# 0 Trinidad and Tobago
# At index:  101 ; Current HomeTeam is:  Trinidad and Tobago
# 1 Panama
# At index:  101 ; Current HomeTeam is:  Panama
# 0 Barawa
# At index:  102 ; Current HomeTeam is:  Barawa
# 1 Chagos Islands
# At index:  102 ; Current HomeTeam is:  Chagos Islands
# 0 India
# At index:  103 ; Current HomeTeam is:  India
# 1 Kenya
# At index:  103 ; Current HomeTeam is:  Kenya
# 2 Chinese Taipei
# At index:  103 ; Current HomeTeam is:  Chinese Taipei
# 3 Syria
# At index:  103 ; Current HomeTeam is:  Syria
# 4 Tajikistan
# At index:  103 ; Current HomeTeam is:  Tajikistan
# 5 North Korea
# At index:  103 ; Current HomeTeam is:  North Korea
# 0 Timor-Leste
# At index:  104 ; Current HomeTeam is:  Timor-Leste
# 1 Brunei
# At index:  104 ; Current HomeTeam is:  Brunei
# 0 Germany
# At index:  105 ; Current HomeTeam is:  Germany
# 1 Czech Republic
# At index:  105 ; Current HomeTeam is:  Czech Republic
# 2 Wales
# At index:  105 ; Current HomeTeam is:  Wales
# 3 Norway
# At index:  105 ; Current HomeTeam is:  Norway
# 4 Slovenia
# At index:  105 ; Current HomeTeam is:  Slovenia
# 5 Kazakhstan
# At index:  105 ; Current HomeTeam is:  Kazakhstan
# 6 Latvia
# At index:  105 ; Current HomeTeam is:  Latvia
# 7 Armenia
# At index:  105 ; Current HomeTeam is:  Armenia
# 8 Gibraltar
# At index:  105 ; Current HomeTeam is:  Gibraltar
# 9 Italy
# At index:  105 ; Current HomeTeam is:  Italy
# 10 Turkey
# At index:  105 ; Current HomeTeam is:  Turkey
# 11 Albania
# At index:  105 ; Current HomeTeam is:  Albania
# 12 Lithuania
# At index:  105 ; Current HomeTeam is:  Lithuania
# 13 Romania
# At index:  105 ; Current HomeTeam is:  Romania
# 14 Faroe Islands
# At index:  105 ; Current HomeTeam is:  Faroe Islands
# 15 Azerbaijan
# At index:  105 ; Current HomeTeam is:  Azerbaijan
# 16 Switzerland
# At index:  105 ; Current HomeTeam is:  Switzerland
# 17 England
# At index:  105 ; Current HomeTeam is:  England
# 18 Northern Ireland
# At index:  105 ; Current HomeTeam is:  Northern Ireland
# 19 Finland
# At index:  105 ; Current HomeTeam is:  Finland
# 20 Estonia
# At index:  105 ; Current HomeTeam is:  Estonia
# 21 Belarus
# At index:  105 ; Current HomeTeam is:  Belarus
# 22 Luxembourg
# At index:  105 ; Current HomeTeam is:  Luxembourg
# 23 France
# At index:  105 ; Current HomeTeam is:  France
# 24 Ukraine
# At index:  105 ; Current HomeTeam is:  Ukraine
# 25 Denmark
# At index:  105 ; Current HomeTeam is:  Denmark
# 26 Bulgaria
# At index:  105 ; Current HomeTeam is:  Bulgaria
# 27 Cyprus
# At index:  105 ; Current HomeTeam is:  Cyprus
# 28 Georgia
# At index:  105 ; Current HomeTeam is:  Georgia
# 29 North Macedonia
# At index:  105 ; Current HomeTeam is:  North Macedonia
# 30 Liechtenstein
# At index:  105 ; Current HomeTeam is:  Liechtenstein
# 31 Portugal
# At index:  105 ; Current HomeTeam is:  Portugal
# 32 Sweden
# At index:  105 ; Current HomeTeam is:  Sweden
# 33 Scotland
# At index:  105 ; Current HomeTeam is:  Scotland
# 34 Montenegro
# At index:  105 ; Current HomeTeam is:  Montenegro
# 35 Serbia
# At index:  105 ; Current HomeTeam is:  Serbia
# 36 Andorra
# At index:  105 ; Current HomeTeam is:  Andorra
# 37 Kosovo
# At index:  105 ; Current HomeTeam is:  Kosovo
# 38 Malta
# At index:  105 ; Current HomeTeam is:  Malta
# 39 Iceland
# At index:  105 ; Current HomeTeam is:  Iceland
# 40 Spain
# At index:  105 ; Current HomeTeam is:  Spain
# 41 Bosnia and Herzegovina
# At index:  105 ; Current HomeTeam is:  Bosnia and Herzegovina
# 42 Hungary
# At index:  105 ; Current HomeTeam is:  Hungary
# 43 San Marino
# At index:  105 ; Current HomeTeam is:  San Marino
# 44 Moldova
# At index:  105 ; Current HomeTeam is:  Moldova
# 45 Poland
# At index:  105 ; Current HomeTeam is:  Poland
# 46 Russia
# At index:  105 ; Current HomeTeam is:  Russia
# 47 Israel
# At index:  105 ; Current HomeTeam is:  Israel
# 48 Belgium
# At index:  105 ; Current HomeTeam is:  Belgium
# 49 Croatia
# At index:  105 ; Current HomeTeam is:  Croatia
# 50 Austria
# At index:  105 ; Current HomeTeam is:  Austria
# 51 Greece
# At index:  105 ; Current HomeTeam is:  Greece
# 52 Netherlands
# At index:  105 ; Current HomeTeam is:  Netherlands
# 53 Slovakia
# At index:  105 ; Current HomeTeam is:  Slovakia
# 54 Republic of Ireland
# At index:  105 ; Current HomeTeam is:  Republic of Ireland
# 0 Yorkshire
# At index:  106 ; Current HomeTeam is:  Yorkshire
# 1 Parishes of Jersey
# At index:  106 ; Current HomeTeam is:  Parishes of Jersey
# 0 Jersey
# At index:  107 ; Current HomeTeam is:  Jersey
# 1 Ynys Môn
# At index:  107 ; Current HomeTeam is:  Ynys Môn
# 2 Alderney
# At index:  107 ; Current HomeTeam is:  Alderney
# 3 Saint Helena
# At index:  107 ; Current HomeTeam is:  Saint Helena
# 4 Isle of Man
# At index:  107 ; Current HomeTeam is:  Isle of Man
# 5 Guernsey
# At index:  107 ; Current HomeTeam is:  Guernsey
# 6 Western Isles
# At index:  107 ; Current HomeTeam is:  Western Isles
# 7 Orkney
# At index:  107 ; Current HomeTeam is:  Orkney
# 8 Shetland
# At index:  107 ; Current HomeTeam is:  Shetland

# %%
dict_tournamentTypes_homeTeam
# Out:
# {'British Championship': {'Northern Ireland': {'1884': '-3',
#    '1885': '-3',
#    '1886': '-3',
#    '1887': '-1',
#    '1888': '-3',
#    '1889': '-3',
#    '1890': '-3',
#    '1891': '-1',
#    '1892': '-2',
#    '1893': '-2',
#    '1894': '-2',
#    '1895': '-2',
#    '1896': '-2',
#    '1897': '-1',
#    '1898': '-1',
#    '1899': '-1',
#    '1900': '-3',
#    '1901': '-3',
#    '1902': '-1',
#    '1903': '2',
#    '1904': '0',
#    '1905': '-1',
#    '1906': '-2',
#    '1907': '-3',
#    '1908': '-1',
#    '1909': '-3',
#    '1910': '0',
#    '1911': '-3',
#    '1912': '-1',
#    '1913': '-1',
#    '1914': '2',
#    '1919': '0',
#    '1920': '-2',
#    '1921': '-2',
#    '1922': '-2',
#    '1923': '1',
#    '1924': '-3',
#    '1925': '-1',
#    '1926': '0',
#    '1927': '0',
#    '1928': '-1',
#    '1929': '-2',
#    '1930': '-1',
#    '1931': '-2',
#    '1932': '-3',
#    '1933': '0',
#    '1934': '1',
#    '1935': '-4',
#    '1936': '-1',
#    '1937': '-2',
#    '1938': '-1',
#    '1939': '-1',
#    '1946': '-1',
#    '1947': '2',
#    '1948': '-3',
#    '1949': '-1',
#    '1950': '-2',
#    '1951': '-3',
#    '1952': '-1',
#    '1953': '-1',
#    '1954': '-1',
#    '1955': '-1',
#    '1956': '-1',
#    '1957': '1',
#    '1958': '0',
#    '1959': '-1',
#    '1960': '-3',
#    '1961': '-2',
#    '1962': '-3',
#    '1963': '-1',
#    '1964': '-1',
#    '1965': '-1',
#    '1966': '1',
#    '1969': '-1',
#    '1970': '-3',
#    '1971': '1',
#    '1972': '0',
#    '1973': '1',
#    '1974': '-1',
#    '1975': '0',
#    '1976': '-3',
#    '1977': '-2',
#    '1978': '-2',
#    '1979': '-2',
#    '1980': '2',
#    '1981': '-1',
#    '1982': '-2',
#    '1983': '0',
#    '1984': '-1'},
#   'Wales': {'1884': '-1',
#    '1885': '0',
#    '1886': '-1',
#    '1887': '-3',
#    '1888': '-1',
#    '1889': '0',
#    '1890': '-1',
#    '1891': '-3',
#    '1892': '-2',
#    '1893': '-2',
#    '1894': '-1',
#    '1895': '0',
#    '1896': '-1',
#    '1897': '-2',
#    '1898': '-3',
#    '1899': '-3',
#    '1900': '0',
#    '1901': '0',
#    '1902': '-2',
#    '1903': '-3',
#    '1904': '-1',
#    '1905': '0',
#    '1906': '0',
#    '1907': '2',
#    '1908': '-3',
#    '1909': '1',
#    '1910': '-1',
#    '1911': '0',
#    '1912': '-3',
#    '1913': '0',
#    '1914': '-2',
#    '1919': '0',
#    '1920': '1',
#    '1921': '0',
#    '1922': '0',
#    '1923': '-2',
#    '1924': '3',
#    '1925': '-3',
#    '1926': '-1',
#    '1927': '0',
#    '1928': '-1',
#    '1929': '-2',
#    '1930': '-2',
#    '1931': '-2',
#    '1932': '2',
#    '1933': '2',
#    '1934': '-2',
#    '1935': '1',
#    '1936': '2',
#    '1937': '1',
#    '1938': '-1',
#    '1939': '1',
#    '1946': '0',
#    '1947': '-1',
#    '1948': '-1',
#    '1949': '1',
#    '1950': '-2',
#    '1951': '2',
#    '1952': '-1',
#    '1953': '1',
#    '1954': '-2',
#    '1955': '1',
#    '1956': '-1',
#    '1957': '-1',
#    '1958': '-1',
#    '1959': '-1',
#    '1960': '1',
#    '1961': '0',
#    '1962': '-1',
#    '1963': '-1',
#    '1964': '-1',
#    '1965': '0',
#    '1966': '-1',
#    '1969': '-2',
#    '1970': '1',
#    '1971': '-1',
#    '1972': '-2',
#    '1973': '-3',
#    '1974': '-1',
#    '1975': '-1',
#    '1976': '-1',
#    '1977': '1',
#    '1978': '0',
#    '1979': '1',
#    '1980': '-1',
#    '1981': '1',
#    '1982': '-1',
#    '1983': '-1',
#    '1984': '0'},
#   'Scotland': {'1884': '3',
#    '1885': '2',
#    '1886': '2',
#    '1887': '3',
#    '1888': '1',
#    '1889': '2',
#    '1890': '2',
#    '1891': '2',
#    '1892': '1',
#    '1893': '1',
#    '1894': '2',
#    '1895': '0',
#    '1896': '2',
#    '1897': '2',
#    '1898': '1',
#    '1899': '1',
#    '1900': '3',
#    '1901': '1',
#    '1902': '2',
#    '1903': '1',
#    '1904': '-1',
#    '1905': '-1',
#    '1906': '1',
#    '1907': '0',
#    '1908': '2',
#    '1909': '-1',
#    '1910': '1',
#    '1911': '1',
#    '1912': '2',
#    '1913': '0',
#    '1914': '0',
#    '1919': '0',
#    '1920': '0',
#    '1921': '3',
#    '1922': '1',
#    '1923': '2',
#    '1924': '0',
#    '1925': '4',
#    '1926': '3',
#    '1927': '0',
#    '1928': '1',
#    '1929': '3',
#    '1930': '0',
#    '1931': '3',
#    '1932': '-1',
#    '1933': '-1',
#    '1934': '-1',
#    '1935': '2',
#    '1936': '0',
#    '1937': '0',
#    '1938': '3',
#    '1939': '-1',
#    '1946': '-1',
#    '1947': '-2',
#    '1948': '1',
#    '1949': '1',
#    '1950': '2',
#    '1951': '1',
#    '1952': '0',
#    '1953': '0',
#    '1954': '1',
#    '1955': '-1',
#    '1956': '1',
#    '1957': '-1',
#    '1958': '0',
#    '1959': '0',
#    '1960': '0',
#    '1961': '1',
#    '1962': '3',
#    '1963': '1',
#    '1964': '1',
#    '1965': '0',
#    '1966': '-1',
#    '1969': '0',
#    '1970': '1',
#    '1971': '-2',
#    '1972': '1',
#    '1973': '-1',
#    '1974': '1',
#    '1975': '0',
#    '1976': '3',
#    '1977': '2',
#    '1978': '-1',
#    '1979': '-1',
#    '1980': '-1',
#    '1981': '1',
#    '1982': '0',
#    '1983': '-1',
#    '1984': '1'},
#   'England': {'1884': '1',
#    '1885': '1',
#    '1886': '2',
#    '1887': '1',
#    '1888': '3',
#    '1889': '1',
#    '1890': '2',
#    '1891': '2',
#    '1892': '3',
#    '1893': '3',
#    '1894': '1',
#    '1895': '2',
#    '1896': '1',
#    '1897': '1',
#    '1898': '3',
#    '1899': '3',
#    '1900': '0',
#    '1901': '2',
#    '1902': '1',
#    '1903': '0',
#    '1904': '2',
#    '1905': '2',
#    '1906': '1',
#    '1907': '1',
#    '1908': '2',
#    '1909': '3',
#    '1910': '0',
#    '1911': '2',
#    '1912': '2',
#    '1913': '1',
#    '1914': '0',
#    '1919': '0',
#    '1920': '1',
#    '1921': '-1',
#    '1922': '1',
#    '1923': '-1',
#    '1924': '0',
#    '1925': '0',
#    '1926': '-2',
#    '1927': '0',
#    '1928': '1',
#    '1929': '1',
#    '1930': '3',
#    '1931': '1',
#    '1932': '2',
#    '1933': '-1',
#    '1934': '2',
#    '1935': '1',
#    '1936': '-1',
#    '1937': '1',
#    '1938': '-1',
#    '1939': '1',
#    '1946': '2',
#    '1947': '1',
#    '1948': '3',
#    '1949': '-1',
#    '1950': '2',
#    '1951': '0',
#    '1952': '2',
#    '1953': '0',
#    '1954': '2',
#    '1955': '1',
#    '1956': '1',
#    '1957': '1',
#    '1958': '1',
#    '1959': '2',
#    '1960': '2',
#    '1961': '1',
#    '1962': '1',
#    '1963': '1',
#    '1964': '1',
#    '1965': '1',
#    '1966': '1',
#    '1969': '3',
#    '1970': '1',
#    '1971': '2',
#    '1972': '1',
#    '1973': '3',
#    '1974': '1',
#    '1975': '1',
#    '1976': '1',
#    '1977': '-1',
#    '1978': '3',
#    '1979': '2',
#    '1980': '0',
#    '1981': '-1',
#    '1982': '3',
#    '1983': '2',
#    '1984': '0'}},
#  'Copa Lipton': {'Argentina': {'1905': '0',
#    '1906': '1',
#    '1908': '0',
#    '1909': '1',
#    '1910': '-1',
#    '1911': '-1',
#    '1912': '-1',
#    '1913': '1',
#    '1915': '1',
#    '1916': '1',
#    '1917': '1',
#    '1918': '0',
#    '1919': '-1',
#    '1922': '-1',
#    '1923': '0',
#    '1924': '-1',
#    '1927': '-1',
#    '1928': '0',
#    '1929': '0',
#    '1937': '1',
#    '1942': '0',
#    '1945': '0',
#    '1957': '0',
#    '1962': '1',
#    '1968': '1',
#    '1973': '0',
#    '1976': '1',
#    '1992': '0'},
#   'Uruguay': {'1905': '0',
#    '1906': '-1',
#    '1908': '0',
#    '1909': '-1',
#    '1910': '1',
#    '1911': '1',
#    '1912': '1',
#    '1913': '-1',
#    '1915': '-1',
#    '1916': '-1',
#    '1917': '-1',
#    '1918': '0',
#    '1919': '1',
#    '1922': '1',
#    '1923': '0',
#    '1924': '1',
#    '1927': '1',
#    '1928': '0',
#    '1929': '0',
#    '1937': '-1',
#    '1942': '0',
#    '1945': '0',
#    '1957': '0',
#    '1962': '-1',
#    '1968': '-1',
#    '1973': '0',
#    '1976': '-1',
#    '1992': '0'}},
#  'Copa Newton': {'Argentina': {'1906': '1',
#    '1908': '1',
#    '1909': '0',
#    '1911': '1',
#    '1912': '0',
#    '1913': '-1',
#    '1915': '-1',
#    '1916': '1',
#    '1917': '-1',
#    '1918': '1',
#    '1919': '-1',
#    '1920': '-1',
#    '1922': '0',
#    '1924': '1',
#    '1927': '1',
#    '1928': '1',
#    '1929': '-1',
#    '1930': '0',
#    '1937': '1',
#    '1942': '1',
#    '1945': '1',
#    '1957': '0',
#    '1968': '-1',
#    '1973': '0',
#    '1975': '1',
#    '1976': '1'},
#   'Uruguay': {'1906': '-1',
#    '1908': '-1',
#    '1909': '0',
#    '1911': '-1',
#    '1912': '0',
#    '1913': '1',
#    '1915': '1',
#    '1916': '-1',
#    '1917': '1',
#    '1918': '-1',
#    '1919': '1',
#    '1920': '1',
#    '1922': '0',
#    '1924': '-1',
#    '1927': '-1',
#    '1928': '-1',
#    '1929': '1',
#    '1930': '0',
#    '1937': '-1',
#    '1942': '-1',
#    '1945': '-1',
#    '1957': '0',
#    '1968': '1',
#    '1973': '0',
#    '1975': '-1',
#    '1976': '-1'}},
#  'Copa Premio Honor Argentino': {'Argentina': {'1908': '-1',
#    '1909': '1',
#    '1910': '-1',
#    '1911': '1',
#    '1912': '-1',
#    '1913': '1',
#    '1914': '1',
#    '1918': '1',
#    '1919': '1',
#    '1920': '1'}},
#  'Copa Premio Honor Uruguayo': {'Uruguay': {'1911': '1',
#    '1912': '1',
#    '1913': '1',
#    '1914': '1',
#    '1915': '-1',
#    '1916': '-1',
#    '1917': '-1',
#    '1918': '1',
#    '1919': '1',
#    '1920': '1',
#    '1922': '1',
#    '1923': '-1'}},
#  'Copa Roca': {'Argentina': {'1914': '-1',
#    '1922': '-1',
#    '1923': '1',
#    '1939': '0',
#    '1940': '2',
#    '1945': '-1',
#    '1957': '0',
#    '1960': '0',
#    '1963': '0',
#    '1971': '0',
#    '1976': '-2'},
#   'Brazil': {'1914': '1',
#    '1922': '1',
#    '1923': '-1',
#    '1939': '0',
#    '1940': '-2',
#    '1945': '1',
#    '1957': '0',
#    '1960': '0',
#    '1963': '0',
#    '1971': '0',
#    '1976': '2'}},
#  'Copa América': {'Chile': {'1916': '-2',
#    '1917': '-3',
#    '1919': '-3',
#    '1920': '-2',
#    '1921': '0',
#    '1922': '-3',
#    '1923': '0',
#    '1924': '-3',
#    '1925': '0',
#    '1926': '1',
#    '1927': '0',
#    '1929': '0',
#    '1935': '-3',
#    '1936': '-1',
#    '1937': '-1',
#    '1939': '-2',
#    '1941': '0',
#    '1942': '-2',
#    '1945': '3',
#    '1946': '-1',
#    '1947': '2',
#    '1949': '-2',
#    '1953': '0',
#    '1955': '2',
#    '1956': '1',
#    '1957': '-3',
#    '1959': '-1',
#    '1963': '0',
#    '1966': '1',
#    '1967': '1',
#    '1975': '-1',
#    '1979': '2',
#    '1983': '1',
#    '1987': '2',
#    '1989': '0',
#    '1991': '1',
#    '1993': '-1',
#    '1995': '-2',
#    '1997': '-3',
#    '1999': '-1',
#    '2001': '0',
#    '2004': '-2',
#    '2007': '-1',
#    '2011': '1',
#    '2015': '4',
#    '2016': '3',
#    '2019': '-1'},
#   'Argentina': {'1916': '1',
#    '1917': '1',
#    '1919': '-1',
#    '1920': '1',
#    '1921': '3',
#    '1922': '0',
#    '1923': '1',
#    '1924': '1',
#    '1925': '3',
#    '1926': '1',
#    '1927': '3',
#    '1929': '3',
#    '1935': '1',
#    '1936': '1',
#    '1937': '3',
#    '1939': '0',
#    '1941': '4',
#    '1942': '3',
#    '1945': '5',
#    '1946': '5',
#    '1947': '6',
#    '1949': '0',
#    '1953': '0',
#    '1955': '4',
#    '1956': '1',
#    '1957': '4',
#    '1959': '6',
#    '1963': '1',
#    '1966': '0',
#    '1967': '3',
#    '1975': '0',
#    '1979': '-1',
#    '1983': '1',
#    '1987': '-1',
#    '1989': '0',
#    '1991': '6',
#    '1993': '2',
#    '1995': '1',
#    '1997': '0',
#    '1999': '0',
#    '2001': '0',
#    '2004': '3',
#    '2007': '4',
#    '2011': '1',
#    '2015': '3',
#    '2016': '5',
#    '2019': '1'},
#   'Brazil': {'1916': '-1',
#    '1917': '-1',
#    '1919': '3',
#    '1920': '-1',
#    '1921': '-1',
#    '1922': '2',
#    '1923': '-3',
#    '1924': '0',
#    '1925': '1',
#    '1926': '0',
#    '1927': '0',
#    '1929': '0',
#    '1935': '0',
#    '1936': '1',
#    '1937': '1',
#    '1939': '0',
#    '1941': '0',
#    '1942': '1',
#    '1945': '4',
#    '1946': '2',
#    '1947': '0',
#    '1949': '6',
#    '1953': '1',
#    '1955': '0',
#    '1956': '1',
#    '1957': '2',
#    '1959': '4',
#    '1963': '-1',
#    '1966': '0',
#    '1967': '0',
#    '1975': '4',
#    '1979': '0',
#    '1983': '0',
#    '1987': '0',
#    '1989': '5',
#    '1991': '2',
#    '1993': '0',
#    '1995': '4',
#    '1997': '6',
#    '1999': '6',
#    '2001': '0',
#    '2004': '2',
#    '2007': '3',
#    '2011': '1',
#    '2015': '1',
#    '2016': '0',
#    '2019': '4'},
#   'Uruguay': {'1916': '2',
#    '1917': '3',
#    '1919': '1',
#    '1920': '2',
#    '1921': '-1',
#    '1922': '1',
#    '1923': '3',
#    '1924': '2',
#    '1925': '0',
#    '1926': '4',
#    '1927': '1',
#    '1929': '-1',
#    '1935': '3',
#    '1936': '0',
#    '1937': '-1',
#    '1939': '2',
#    '1941': '2',
#    '1942': '6',
#    '1945': '0',
#    '1946': '-1',
#    '1947': '3',
#    '1949': '-2',
#    '1953': '1',
#    '1955': '0',
#    '1956': '4',
#    '1957': '2',
#    '1959': '1',
#    '1963': '0',
#    '1966': '0',
#    '1967': '4',
#    '1975': '0',
#    '1979': '0',
#    '1983': '4',
#    '1987': '2',
#    '1989': '1',
#    '1991': '1',
#    '1993': '0',
#    '1995': '4',
#    '1997': '-1',
#    '1999': '-2',
#    '2001': '0',
#    '2004': '2',
#    '2007': '0',
#    '2011': '3',
#    '2015': '-1',
#    '2016': '-1',
#    '2019': '2'},
#   'Paraguay': {'1916': '0',
#    '1917': '0',
#    '1919': '0',
#    '1920': '0',
#    '1921': '-1',
#    '1922': '0',
#    '1923': '-1',
#    '1924': '0',
#    '1925': '-4',
#    '1926': '-2',
#    '1927': '0',
#    '1929': '1',
#    '1935': '0',
#    '1936': '0',
#    '1937': '-1',
#    '1939': '0',
#    '1941': '0',
#    '1942': '0',
#    '1945': '0',
#    '1946': '0',
#    '1947': '4',
#    '1949': '4',
#    '1953': '4',
#    '1955': '-2',
#    '1956': '-3',
#    '1957': '0',
#    '1959': '-3',
#    '1963': '3',
#    '1966': '1',
#    '1967': '-1',
#    '1975': '-1',
#    '1979': '3',
#    '1983': '0',
#    '1987': '-1',
#    '1989': '0',
#    '1991': '0',
#    '1993': '-1',
#    '1995': '1',
#    '1997': '-1',
#    '1999': '2',
#    '2001': '-1',
#    '2004': '1',
#    '2007': '0',
#    '2011': '-1',
#    '2015': '-1',
#    '2016': '-2',
#    '2019': '-1'},
#   'Bolivia': {'1916': '0',
#    '1917': '0',
#    '1919': '0',
#    '1920': '0',
#    '1921': '0',
#    '1922': '0',
#    '1923': '0',
#    '1924': '0',
#    '1925': '0',
#    '1926': '-4',
#    '1927': '-3',
#    '1929': '0',
#    '1935': '0',
#    '1936': '0',
#    '1937': '0',
#    '1939': '0',
#    '1941': '0',
#    '1942': '0',
#    '1945': '-4',
#    '1946': '-5',
#    '1947': '-5',
#    '1949': '1',
#    '1953': '-2',
#    '1955': '0',
#    '1956': '0',
#    '1957': '0',
#    '1959': '-5',
#    '1963': '5',
#    '1966': '0',
#    '1967': '-4',
#    '1975': '-2',
#    '1979': '0',
#    '1983': '-2',
#    '1987': '-1',
#    '1989': '-2',
#    '1991': '-2',
#    '1993': '-1',
#    '1995': '-1',
#    '1997': '4',
#    '1999': '-1',
#    '2001': '-3',
#    '2004': '-1',
#    '2007': '-1',
#    '2011': '-2',
#    '2015': '-1',
#    '2016': '-3',
#    '2019': '-3'},
#   'Peru': {'1916': '0',
#    '1917': '0',
#    '1919': '0',
#    '1920': '0',
#    '1921': '0',
#    '1922': '0',
#    '1923': '0',
#    '1924': '0',
#    '1925': '0',
#    '1926': '0',
#    '1927': '-1',
#    '1929': '-3',
#    '1935': '-1',
#    '1936': '-1',
#    '1937': '-1',
#    '1939': '4',
#    '1941': '-2',
#    '1942': '-2',
#    '1945': '0',
#    '1946': '0',
#    '1947': '-1',
#    '1949': '3',
#    '1953': '0',
#    '1955': '1',
#    '1956': '-4',
#    '1957': '2',
#    '1959': '-1',
#    '1963': '-1',
#    '1966': '0',
#    '1967': '0',
#    '1975': '4',
#    '1979': '-1',
#    '1983': '1',
#    '1987': '0',
#    '1989': '-1',
#    '1991': '-2',
#    '1993': '0',
#    '1995': '-2',
#    '1997': '0',
#    '1999': '1',
#    '2001': '-1',
#    '2004': '0',
#    '2007': '-1',
#    '2011': '1',
#    '2015': '1',
#    '2016': '2',
#    '2019': '0'},
#   'Ecuador': {'1916': '0',
#    '1917': '0',
#    '1919': '0',
#    '1920': '0',
#    '1921': '0',
#    '1922': '0',
#    '1923': '0',
#    '1924': '0',
#    '1925': '0',
#    '1926': '0',
#    '1927': '0',
#    '1929': '0',
#    '1935': '0',
#    '1936': '0',
#    '1937': '0',
#    '1939': '-4',
#    '1941': '-4',
#    '1942': '-6',
#    '1945': '-5',
#    '1946': '0',
#    '1947': '-4',
#    '1949': '-5',
#    '1953': '-4',
#    '1955': '-5',
#    '1956': '0',
#    '1957': '-5',
#    '1959': '-1',
#    '1963': '-2',
#    '1966': '-1',
#    '1967': '0',
#    '1975': '-3',
#    '1979': '-2',
#    '1983': '-2',
#    '1987': '-1',
#    '1989': '0',
#    '1991': '-1',
#    '1993': '2',
#    '1995': '-1',
#    '1997': '2',
#    '1999': '-3',
#    '2001': '-1',
#    '2004': '-3',
#    '2007': '-3',
#    '2011': '-2',
#    '2015': '-1',
#    '2016': '0',
#    '2019': '-2'},
#   'Colombia': {'1916': '0',
#    '1917': '0',
#    '1919': '0',
#    '1920': '0',
#    '1921': '0',
#    '1922': '0',
#    '1923': '0',
#    '1924': '0',
#    '1925': '0',
#    '1926': '0',
#    '1927': '0',
#    '1929': '0',
#    '1935': '0',
#    '1936': '0',
#    '1937': '0',
#    '1939': '0',
#    '1941': '0',
#    '1942': '0',
#    '1945': '-3',
#    '1946': '0',
#    '1947': '-5',
#    '1949': '-5',
#    '1953': '0',
#    '1955': '0',
#    '1956': '0',
#    '1957': '-2',
#    '1959': '0',
#    '1963': '-5',
#    '1966': '-1',
#    '1967': '0',
#    '1975': '3',
#    '1979': '1',
#    '1983': '0',
#    '1987': '2',
#    '1989': '0',
#    '1991': '-1',
#    '1993': '2',
#    '1995': '0',
#    '1997': '-2',
#    '1999': '2',
#    '2001': '6',
#    '2004': '1',
#    '2007': '-1',
#    '2011': '1',
#    '2015': '0',
#    '2016': '1',
#    '2019': '3'},
#   'Venezuela': {'1916': '0',
#    '1917': '0',
#    '1919': '0',
#    '1920': '0',
#    '1921': '0',
#    '1922': '0',
#    '1923': '0',
#    '1924': '0',
#    '1925': '0',
#    '1926': '0',
#    '1927': '0',
#    '1929': '0',
#    '1935': '0',
#    '1936': '0',
#    '1937': '0',
#    '1939': '0',
#    '1941': '0',
#    '1942': '0',
#    '1945': '0',
#    '1946': '0',
#    '1947': '0',
#    '1949': '0',
#    '1953': '0',
#    '1955': '0',
#    '1956': '0',
#    '1957': '0',
#    '1959': '0',
#    '1963': '0',
#    '1966': '0',
#    '1967': '-3',
#    '1975': '-4',
#    '1979': '-2',
#    '1983': '-3',
#    '1987': '-2',
#    '1989': '-3',
#    '1991': '-4',
#    '1993': '-1',
#    '1995': '-3',
#    '1997': '-3',
#    '1999': '-3',
#    '2001': '-3',
#    '2004': '-2',
#    '2007': '0',
#    '2011': '1',
#    '2015': '-1',
#    '2016': '1',
#    '2019': '0'},
#   'United States': {'1916': '0',
#    '1917': '0',
#    '1919': '0',
#    '1920': '0',
#    '1921': '0',
#    '1922': '0',
#    '1923': '0',
#    '1924': '0',
#    '1925': '0',
#    '1926': '0',
#    '1927': '0',
#    '1929': '0',
#    '1935': '0',
#    '1936': '0',
#    '1937': '0',
#    '1939': '0',
#    '1941': '0',
#    '1942': '0',
#    '1945': '0',
#    '1946': '0',
#    '1947': '0',
#    '1949': '0',
#    '1953': '0',
#    '1955': '0',
#    '1956': '0',
#    '1957': '0',
#    '1959': '0',
#    '1963': '0',
#    '1966': '0',
#    '1967': '0',
#    '1975': '0',
#    '1979': '0',
#    '1983': '0',
#    '1987': '0',
#    '1989': '0',
#    '1991': '0',
#    '1993': '-2',
#    '1995': '-1',
#    '1997': '0',
#    '1999': '0',
#    '2001': '0',
#    '2004': '0',
#    '2007': '-3',
#    '2011': '0',
#    '2015': '0',
#    '2016': '0',
#    '2019': '0'},
#   'Mexico': {'1916': '0',
#    '1917': '0',
#    '1919': '0',
#    '1920': '0',
#    '1921': '0',
#    '1922': '0',
#    '1923': '0',
#    '1924': '0',
#    '1925': '0',
#    '1926': '0',
#    '1927': '0',
#    '1929': '0',
#    '1935': '0',
#    '1936': '0',
#    '1937': '0',
#    '1939': '0',
#    '1941': '0',
#    '1942': '0',
#    '1945': '0',
#    '1946': '0',
#    '1947': '0',
#    '1949': '0',
#    '1953': '0',
#    '1955': '0',
#    '1956': '0',
#    '1957': '0',
#    '1959': '0',
#    '1963': '0',
#    '1966': '0',
#    '1967': '0',
#    '1975': '0',
#    '1979': '0',
#    '1983': '0',
#    '1987': '0',
#    '1989': '0',
#    '1991': '0',
#    '1993': '0',
#    '1995': '0',
#    '1997': '0',
#    '1999': '1',
#    '2001': '1',
#    '2004': '1',
#    '2007': '3',
#    '2011': '-3',
#    '2015': '-1',
#    '2016': '1',
#    '2019': '0'},
#   'Honduras': {'1916': '0',
#    '1917': '0',
#    '1919': '0',
#    '1920': '0',
#    '1921': '0',
#    '1922': '0',
#    '1923': '0',
#    '1924': '0',
#    '1925': '0',
#    '1926': '0',
#    '1927': '0',
#    '1929': '0',
#    '1935': '0',
#    '1936': '0',
#    '1937': '0',
#    '1939': '0',
#    '1941': '0',
#    '1942': '0',
#    '1945': '0',
#    '1946': '0',
#    '1947': '0',
#    '1949': '0',
#    '1953': '0',
#    '1955': '0',
#    '1956': '0',
#    '1957': '0',
#    '1959': '0',
#    '1963': '0',
#    '1966': '0',
#    '1967': '0',
#    '1975': '0',
#    '1979': '0',
#    '1983': '0',
#    '1987': '0',
#    '1989': '0',
#    '1991': '0',
#    '1993': '0',
#    '1995': '0',
#    '1997': '0',
#    '1999': '0',
#    '2001': '1',
#    '2004': '0',
#    '2007': '0',
#    '2011': '0',
#    '2015': '0',
#    '2016': '0',
#    '2019': '0'},
#   'Costa Rica': {'1916': '0',
#    '1917': '0',
#    '1919': '0',
#    '1920': '0',
#    '1921': '0',
#    '1922': '0',
#    '1923': '0',
#    '1924': '0',
#    '1925': '0',
#    '1926': '0',
#    '1927': '0',
#    '1929': '0',
#    '1935': '0',
#    '1936': '0',
#    '1937': '0',
#    '1939': '0',
#    '1941': '0',
#    '1942': '0',
#    '1945': '0',
#    '1946': '0',
#    '1947': '0',
#    '1949': '0',
#    '1953': '0',
#    '1955': '0',
#    '1956': '0',
#    '1957': '0',
#    '1959': '0',
#    '1963': '0',
#    '1966': '0',
#    '1967': '0',
#    '1975': '0',
#    '1979': '0',
#    '1983': '0',
#    '1987': '0',
#    '1989': '0',
#    '1991': '0',
#    '1993': '0',
#    '1995': '0',
#    '1997': '-2',
#    '1999': '0',
#    '2001': '1',
#    '2004': '-2',
#    '2007': '0',
#    '2011': '-1',
#    '2015': '0',
#    '2016': '0',
#    '2019': '0'},
#   'Haiti': {'1916': '0',
#    '1917': '0',
#    '1919': '0',
#    '1920': '0',
#    '1921': '0',
#    '1922': '0',
#    '1923': '0',
#    '1924': '0',
#    '1925': '0',
#    '1926': '0',
#    '1927': '0',
#    '1929': '0',
#    '1935': '0',
#    '1936': '0',
#    '1937': '0',
#    '1939': '0',
#    '1941': '0',
#    '1942': '0',
#    '1945': '0',
#    '1946': '0',
#    '1947': '0',
#    '1949': '0',
#    '1953': '0',
#    '1955': '0',
#    '1956': '0',
#    '1957': '0',
#    '1959': '0',
#    '1963': '0',
#    '1966': '0',
#    '1967': '0',
#    '1975': '0',
#    '1979': '0',
#    '1983': '0',
#    '1987': '0',
#    '1989': '0',
#    '1991': '0',
#    '1993': '0',
#    '1995': '0',
#    '1997': '0',
#    '1999': '0',
#    '2001': '0',
#    '2004': '0',
#    '2007': '0',
#    '2011': '0',
#    '2015': '0',
#    '2016': '-3',
#    '2019': '0'},
#   'Jamaica': {'1916': '0',
#    '1917': '0',
#    '1919': '0',
#    '1920': '0',
#    '1921': '0',
#    '1922': '0',
#    '1923': '0',
#    '1924': '0',
#    '1925': '0',
#    '1926': '0',
#    '1927': '0',
#    '1929': '0',
#    '1935': '0',
#    '1936': '0',
#    '1937': '0',
#    '1939': '0',
#    '1941': '0',
#    '1942': '0',
#    '1945': '0',
#    '1946': '0',
#    '1947': '0',
#    '1949': '0',
#    '1953': '0',
#    '1955': '0',
#    '1956': '0',
#    '1957': '0',
#    '1959': '0',
#    '1963': '0',
#    '1966': '0',
#    '1967': '0',
#    '1975': '0',
#    '1979': '0',
#    '1983': '0',
#    '1987': '0',
#    '1989': '0',
#    '1991': '0',
#    '1993': '0',
#    '1995': '0',
#    '1997': '0',
#    '1999': '0',
#    '2001': '0',
#    '2004': '0',
#    '2007': '0',
#    '2011': '0',
#    '2015': '-3',
#    '2016': '-3',
#    '2019': '0'},
#   'Panama': {'1916': '0',
#    '1917': '0',
#    '1919': '0',
#    '1920': '0',
#    '1921': '0',
#    '1922': '0',
#    '1923': '0',
#    '1924': '0',
#    '1925': '0',
#    '1926': '0',
#    '1927': '0',
#    '1929': '0',
#    '1935': '0',
#    '1936': '0',
#    '1937': '0',
#    '1939': '0',
#    '1941': '0',
#    '1942': '0',
#    '1945': '0',
#    '1946': '0',
#    '1947': '0',
#    '1949': '0',
#    '1953': '0',
#    '1955': '0',
#    '1956': '0',
#    '1957': '0',
#    '1959': '0',
#    '1963': '0',
#    '1966': '0',
#    '1967': '0',
#    '1975': '0',
#    '1979': '0',
#    '1983': '0',
#    '1987': '0',
#    '1989': '0',
#    '1991': '0',
#    '1993': '0',
#    '1995': '0',
#    '1997': '0',
#    '1999': '0',
#    '2001': '0',
#    '2004': '0',
#    '2007': '0',
#    '2011': '0',
#    '2015': '0',
#    '2016': '-1',
#    '2019': '0'},
#   'Japan': {'1916': '0',
#    '1917': '0',
#    '1919': '0',
#    '1920': '0',
#    '1921': '0',
#    '1922': '0',
#    '1923': '0',
#    '1924': '0',
#    '1925': '0',
#    '1926': '0',
#    '1927': '0',
#    '1929': '0',
#    '1935': '0',
#    '1936': '0',
#    '1937': '0',
#    '1939': '0',
#    '1941': '0',
#    '1942': '0',
#    '1945': '0',
#    '1946': '0',
#    '1947': '0',
#    '1949': '0',
#    '1953': '0',
#    '1955': '0',
#    '1956': '0',
#    '1957': '0',
#    '1959': '0',
#    '1963': '0',
#    '1966': '0',
#    '1967': '0',
#    '1975': '0',
#    '1979': '0',
#    '1983': '0',
#    '1987': '0',
#    '1989': '0',
#    '1991': '0',
#    '1993': '0',
#    '1995': '0',
#    '1997': '0',
#    '1999': '-2',
#    '2001': '0',
#    '2004': '0',
#    '2007': '0',
#    '2011': '0',
#    '2015': '0',
#    '2016': '0',
#    '2019': '-1'},
#   'Qatar': {'1916': '0',
#    '1917': '0',
#    '1919': '0',
#    '1920': '0',
#    '1921': '0',
#    '1922': '0',
#    '1923': '0',
#    '1924': '0',
#    '1925': '0',
#    '1926': '0',
#    '1927': '0',
#    '1929': '0',
#    '1935': '0',
#    '1936': '0',
#    '1937': '0',
#    '1939': '0',
#    '1941': '0',
#    '1942': '0',
#    '1945': '0',
#    '1946': '0',
#    '1947': '0',
#    '1949': '0',
#    '1953': '0',
#    '1955': '0',
#    '1956': '0',
#    '1957': '0',
#    '1959': '0',
#    '1963': '0',
#    '1966': '0',
#    '1967': '0',
#    '1975': '0',
#    '1979': '0',
#    '1983': '0',
#    '1987': '0',
#    '1989': '0',
#    '1991': '0',
#    '1993': '0',
#    '1995': '0',
#    '1997': '0',
#    '1999': '0',
#    '2001': '0',
#    '2004': '0',
#    '2007': '0',
#    '2011': '0',
#    '2015': '0',
#    '2016': '0',
#    '2019': '-2'}},
#  'Copa Chevallier Boutell': {'Argentina': {'1923': '0',
#    '1924': '0',
#    '1925': '0',
#    '1926': '2',
#    '1931': '1',
#    '1939': '1',
#    '1940': '2',
#    '1943': '0',
#    '1945': '2',
#    '1950': '1',
#    '1956': '1',
#    '1963': '0',
#    '1964': '0',
#    '1971': '1'},
#   'Paraguay': {'1923': '0',
#    '1924': '0',
#    '1925': '0',
#    '1926': '-2',
#    '1931': '-1',
#    '1939': '-1',
#    '1940': '-2',
#    '1943': '0',
#    '1945': '-2',
#    '1950': '-1',
#    '1956': '-1',
#    '1963': '0',
#    '1964': '0',
#    '1971': '-1'}},
#  'Nordic Championship': {'Denmark': {'1924': '0',
#    '1925': '2',
#    '1926': '1',
#    '1927': '1',
#    '1928': '2',
#    '1929': '-1',
#    '1930': '1',
#    '1931': '-1',
#    '1932': '1',
#    '1933': '2',
#    '1934': '-3',
#    '1935': '1',
#    '1936': '2',
#    '1937': '3',
#    '1938': '-2',
#    '1939': '1',
#    '1947': '1',
#    '1948': '-1',
#    '1949': '1',
#    '1950': '1',
#    '1951': '1',
#    '1952': '-3',
#    '1953': '1',
#    '1954': '-2',
#    '1955': '1',
#    '1956': '0',
#    '1957': '0',
#    '1958': '0',
#    '1959': '0',
#    '1960': '1',
#    '1961': '1',
#    '1962': '1',
#    '1963': '1',
#    '1964': '-1',
#    '1965': '2',
#    '1966': '-3',
#    '1967': '2',
#    '1968': '1',
#    '1969': '-1',
#    '1970': '-1',
#    '1971': '0',
#    '1972': '0',
#    '1973': '2',
#    '1974': '-1',
#    '1975': '1',
#    '1976': '1',
#    '1977': '2',
#    '1978': '2',
#    '1979': '1',
#    '1980': '2',
#    '1981': '3',
#    '1982': '0',
#    '1983': '0',
#    '2000': '1',
#    '2001': '0'},
#   'Norway': {'1924': '-2',
#    '1925': '-2',
#    '1926': '-1',
#    '1927': '-2',
#    '1928': '-2',
#    '1929': '3',
#    '1930': '1',
#    '1931': '0',
#    '1932': '1',
#    '1933': '0',
#    '1934': '2',
#    '1935': '-1',
#    '1936': '-2',
#    '1937': '1',
#    '1938': '2',
#    '1939': '-1',
#    '1947': '-2',
#    '1948': '1',
#    '1949': '-1',
#    '1950': '-1',
#    '1951': '2',
#    '1952': '1',
#    '1953': '0',
#    '1954': '2',
#    '1955': '1',
#    '1956': '2',
#    '1957': '0',
#    '1958': '1',
#    '1959': '0',
#    '1960': '1',
#    '1961': '-3',
#    '1962': '1',
#    '1963': '-2',
#    '1964': '0',
#    '1965': '-1',
#    '1966': '0',
#    '1967': '0',
#    '1968': '0',
#    '1969': '0',
#    '1970': '2',
#    '1971': '-2',
#    '1972': '-1',
#    '1973': '-2',
#    '1974': '-2',
#    '1975': '1',
#    '1976': '0',
#    '1977': '-1',
#    '1978': '-1',
#    '1979': '0',
#    '1980': '0',
#    '1981': '-2',
#    '1982': '2',
#    '1983': '0',
#    '2000': '-1',
#    '2001': '0'},
#   'Sweden': {'1924': '2',
#    '1925': '0',
#    '1926': '0',
#    '1927': '1',
#    '1928': '0',
#    '1929': '1',
#    '1930': '0',
#    '1931': '1',
#    '1932': '-1',
#    '1933': '1',
#    '1934': '0',
#    '1935': '2',
#    '1936': '1',
#    '1937': '-2',
#    '1938': '1',
#    '1939': '3',
#    '1947': '3',
#    '1948': '2',
#    '1949': '0',
#    '1950': '3',
#    '1951': '-1',
#    '1952': '3',
#    '1953': '1',
#    '1954': '2',
#    '1955': '1',
#    '1956': '0',
#    '1957': '3',
#    '1958': '2',
#    '1959': '3',
#    '1960': '1',
#    '1961': '3',
#    '1962': '1',
#    '1963': '0',
#    '1964': '0',
#    '1965': '-1',
#    '1966': '1',
#    '1967': '1',
#    '1968': '2',
#    '1969': '3',
#    '1970': '1',
#    '1971': '3',
#    '1972': '2',
#    '1973': '1',
#    '1974': '2',
#    '1975': '0',
#    '1976': '1',
#    '1977': '0',
#    '1978': '0',
#    '1979': '0',
#    '1980': '0',
#    '1981': '0',
#    '1982': '-1',
#    '1983': '1',
#    '2000': '-1',
#    '2001': '-1'},
#   'Finland': {'1924': '0',
#    '1925': '0',
#    '1926': '0',
#    '1927': '0',
#    '1928': '0',
#    '1929': '-3',
#    '1930': '-2',
#    '1931': '0',
#    '1932': '-1',
#    '1933': '-3',
#    '1934': '1',
#    '1935': '-2',
#    '1936': '-1',
#    '1937': '-2',
#    '1938': '-1',
#    '1939': '-3',
#    '1947': '-2',
#    '1948': '-2',
#    '1949': '0',
#    '1950': '-3',
#    '1951': '-2',
#    '1952': '-1',
#    '1953': '-2',
#    '1954': '-2',
#    '1955': '-3',
#    '1956': '-2',
#    '1957': '-3',
#    '1958': '-3',
#    '1959': '-3',
#    '1960': '-3',
#    '1961': '-1',
#    '1962': '-3',
#    '1963': '1',
#    '1964': '1',
#    '1965': '0',
#    '1966': '2',
#    '1967': '-3',
#    '1968': '-3',
#    '1969': '-2',
#    '1970': '-2',
#    '1971': '-1',
#    '1972': '-1',
#    '1973': '-1',
#    '1974': '1',
#    '1975': '-2',
#    '1976': '-2',
#    '1977': '-1',
#    '1978': '-1',
#    '1979': '-1',
#    '1980': '-2',
#    '1981': '-1',
#    '1982': '-1',
#    '1983': '-1',
#    '2000': '1',
#    '2001': '1'},
#   'Faroe Islands': {'1924': '0',
#    '1925': '0',
#    '1926': '0',
#    '1927': '0',
#    '1928': '0',
#    '1929': '0',
#    '1930': '0',
#    '1931': '0',
#    '1932': '0',
#    '1933': '0',
#    '1934': '0',
#    '1935': '0',
#    '1936': '0',
#    '1937': '0',
#    '1938': '0',
#    '1939': '0',
#    '1947': '0',
#    '1948': '0',
#    '1949': '0',
#    '1950': '0',
#    '1951': '0',
#    '1952': '0',
#    '1953': '0',
#    '1954': '0',
#    '1955': '0',
#    '1956': '0',
#    '1957': '0',
#    '1958': '0',
#    '1959': '0',
#    '1960': '0',
#    '1961': '0',
#    '1962': '0',
#    '1963': '0',
#    '1964': '0',
#    '1965': '0',
#    '1966': '0',
#    '1967': '0',
#    '1968': '0',
#    '1969': '0',
#    '1970': '0',
#    '1971': '0',
#    '1972': '0',
#    '1973': '0',
#    '1974': '0',
#    '1975': '0',
#    '1976': '0',
#    '1977': '0',
#    '1978': '0',
#    '1979': '0',
#    '1980': '0',
#    '1981': '0',
#    '1982': '0',
#    '1983': '0',
#    '2000': '-3',
#    '2001': '0'},
#   'Iceland': {'1924': '0',
#    '1925': '0',
#    '1926': '0',
#    '1927': '0',
#    '1928': '0',
#    '1929': '0',
#    '1930': '0',
#    '1931': '0',
#    '1932': '0',
#    '1933': '0',
#    '1934': '0',
#    '1935': '0',
#    '1936': '0',
#    '1937': '0',
#    '1938': '0',
#    '1939': '0',
#    '1947': '0',
#    '1948': '0',
#    '1949': '0',
#    '1950': '0',
#    '1951': '0',
#    '1952': '0',
#    '1953': '0',
#    '1954': '0',
#    '1955': '0',
#    '1956': '0',
#    '1957': '0',
#    '1958': '0',
#    '1959': '0',
#    '1960': '0',
#    '1961': '0',
#    '1962': '0',
#    '1963': '0',
#    '1964': '0',
#    '1965': '0',
#    '1966': '0',
#    '1967': '0',
#    '1968': '0',
#    '1969': '0',
#    '1970': '0',
#    '1971': '0',
#    '1972': '0',
#    '1973': '0',
#    '1974': '0',
#    '1975': '0',
#    '1976': '0',
#    '1977': '0',
#    '1978': '0',
#    '1979': '0',
#    '1980': '0',
#    '1981': '0',
#    '1982': '0',
#    '1983': '0',
#    '2000': '3',
#    '2001': '0'}},
#  'International Cup': {'Czechoslovakia': {'1927': '1',
#    '1928': '0',
#    '1929': '1',
#    '1930': '0',
#    '1931': '0',
#    '1932': '-1',
#    '1933': '-1',
#    '1934': '0',
#    '1935': '1',
#    '1936': '1',
#    '1937': '0',
#    '1938': '-1',
#    '1948': '0',
#    '1949': '0',
#    '1950': '0',
#    '1951': '0',
#    '1952': '0',
#    '1953': '1',
#    '1955': '0',
#    '1956': '3',
#    '1957': '1',
#    '1958': '1',
#    '1959': '1',
#    '1960': '0'},
#   'Hungary': {'1927': '1',
#    '1928': '0',
#    '1929': '1',
#    '1930': '-1',
#    '1931': '0',
#    '1932': '0',
#    '1933': '0',
#    '1934': '1',
#    '1935': '0',
#    '1936': '0',
#    '1937': '3',
#    '1938': '0',
#    '1948': '1',
#    '1949': '0',
#    '1950': '0',
#    '1951': '0',
#    '1952': '1',
#    '1953': '1',
#    '1955': '4',
#    '1956': '0',
#    '1957': '0',
#    '1958': '0',
#    '1959': '1',
#    '1960': '0'},
#   'Italy': {'1927': '-1',
#    '1928': '3',
#    '1929': '0',
#    '1930': '1',
#    '1931': '2',
#    '1932': '-1',
#    '1933': '4',
#    '1934': '-1',
#    '1935': '0',
#    '1936': '1',
#    '1937': '1',
#    '1938': '0',
#    '1948': '0',
#    '1949': '1',
#    '1950': '-1',
#    '1951': '0',
#    '1952': '1',
#    '1953': '-1',
#    '1955': '-2',
#    '1956': '1',
#    '1957': '-1',
#    '1958': '-1',
#    '1959': '-1',
#    '1960': '1'},
#   'Austria': {'1927': '-1',
#    '1928': '1',
#    '1929': '2',
#    '1930': '0',
#    '1931': '1',
#    '1932': '2',
#    '1933': '0',
#    '1934': '2',
#    '1935': '-1',
#    '1936': '0',
#    '1937': '0',
#    '1938': '0',
#    '1948': '0',
#    '1949': '0',
#    '1950': '1',
#    '1951': '0',
#    '1952': '0',
#    '1953': '0',
#    '1955': '0',
#    '1956': '-1',
#    '1957': '1',
#    '1958': '1',
#    '1959': '0',
#    '1960': '0'},
#   'Switzerland': {'1927': '0',
#    '1928': '-4',
#    '1929': '-4',
#    '1930': '0',
#    '1931': '-3',
#    '1932': '0',
#    '1933': '-3',
#    '1934': '-2',
#    '1935': '0',
#    '1936': '-2',
#    '1937': '-4',
#    '1938': '1',
#    '1948': '-1',
#    '1949': '-1',
#    '1950': '0',
#    '1951': '0',
#    '1952': '-2',
#    '1953': '-1',
#    '1955': '-2',
#    '1956': '-1',
#    '1957': '-1',
#    '1958': '-1',
#    '1959': '-2',
#    '1960': '-1'},
#   'Yugoslavia': {'1927': '0',
#    '1928': '0',
#    '1929': '0',
#    '1930': '0',
#    '1931': '0',
#    '1932': '0',
#    '1933': '0',
#    '1934': '0',
#    '1935': '0',
#    '1936': '0',
#    '1937': '0',
#    '1938': '0',
#    '1948': '0',
#    '1949': '0',
#    '1950': '0',
#    '1951': '0',
#    '1952': '0',
#    '1953': '0',
#    '1955': '0',
#    '1956': '-2',
#    '1957': '0',
#    '1958': '0',
#    '1959': '1',
#    '1960': '0'}},
#  'Baltic Cup': {'Latvia': {'1928': '2',
#    '1929': '1',
#    '1930': '1',
#    '1931': '0',
#    '1932': '2',
#    '1933': '1',
#    '1935': '0',
#    '1936': '2',
#    '1937': '1',
#    '1938': '0',
#    '1940': '1',
#    '1948': '-1',
#    '1949': '-1',
#    '1991': '1',
#    '1992': '0',
#    '1993': '1',
#    '1994': '0',
#    '1995': '2',
#    '1996': '-1',
#    '1997': '0',
#    '1998': '0',
#    '2000': '-1',
#    '2001': '2',
#    '2003': '1',
#    '2005': '-1',
#    '2008': '2',
#    '2010': '0',
#    '2012': '1',
#    '2014': '1',
#    '2016': '1',
#    '2018': '1'},
#   'Estonia': {'1928': '0',
#    '1929': '1',
#    '1930': '-2',
#    '1931': '2',
#    '1932': '-2',
#    '1933': '-1',
#    '1935': '-1',
#    '1936': '0',
#    '1937': '0',
#    '1938': '1',
#    '1940': '0',
#    '1948': '-1',
#    '1949': '-1',
#    '1991': '-2',
#    '1992': '-1',
#    '1993': '0',
#    '1994': '-2',
#    '1995': '-2',
#    '1996': '0',
#    '1997': '-2',
#    '1998': '-1',
#    '2000': '0',
#    '2001': '-2',
#    '2003': '-1',
#    '2005': '0',
#    '2008': '-2',
#    '2010': '-1',
#    '2012': '0',
#    '2014': '-1',
#    '2016': '-1',
#    '2018': '0'},
#   'Lithuania': {'1928': '-2',
#    '1929': '-2',
#    '1930': '1',
#    '1931': '-2',
#    '1932': '0',
#    '1933': '0',
#    '1935': '1',
#    '1936': '-2',
#    '1937': '-1',
#    '1938': '-1',
#    '1940': '-1',
#    '1948': '2',
#    '1949': '2',
#    '1991': '1',
#    '1992': '1',
#    '1993': '-1',
#    '1994': '2',
#    '1995': '0',
#    '1996': '1',
#    '1997': '2',
#    '1998': '1',
#    '2000': '1',
#    '2001': '0',
#    '2003': '0',
#    '2005': '1',
#    '2008': '0',
#    '2010': '1',
#    '2012': '-2',
#    '2014': '0',
#    '2016': '0',
#    '2018': '-1'},
#   'Finland': {'1928': '0',
#    '1929': '0',
#    '1930': '0',
#    '1931': '0',
#    '1932': '0',
#    '1933': '0',
#    '1935': '0',
#    '1936': '0',
#    '1937': '0',
#    '1938': '0',
#    '1940': '0',
#    '1948': '0',
#    '1949': '0',
#    '1991': '0',
#    '1992': '0',
#    '1993': '0',
#    '1994': '0',
#    '1995': '0',
#    '1996': '0',
#    '1997': '0',
#    '1998': '0',
#    '2000': '0',
#    '2001': '0',
#    '2003': '0',
#    '2005': '0',
#    '2008': '0',
#    '2010': '0',
#    '2012': '1',
#    '2014': '0',
#    '2016': '0',
#    '2018': '0'}},
#  'Balkan Cup': {'Romania': {'1929': '1',
#    '1930': '0',
#    '1931': '3',
#    '1932': '-1',
#    '1933': '2',
#    '1934': '1',
#    '1935': '-3',
#    '1936': '2',
#    '1946': '0',
#    '1947': '0',
#    '1948': '-1',
#    '1973': '0',
#    '1974': '1',
#    '1975': '0',
#    '1976': '0',
#    '1977': '1',
#    '1978': '1',
#    '1980': '0'},
#   'Greece': {'1929': '0',
#    '1930': '1',
#    '1931': '-3',
#    '1932': '-3',
#    '1933': '-2',
#    '1934': '1',
#    '1935': '-3',
#    '1936': '-2',
#    '1946': '0',
#    '1947': '0',
#    '1948': '0',
#    '1973': '0',
#    '1974': '-1',
#    '1975': '0',
#    '1976': '0',
#    '1977': '0',
#    '1978': '-1',
#    '1980': '0'},
#   'Bulgaria': {'1929': '0',
#    '1930': '-1',
#    '1931': '1',
#    '1932': '3',
#    '1933': '-1',
#    '1934': '-2',
#    '1935': '3',
#    '1936': '0',
#    '1946': '-1',
#    '1947': '-2',
#    '1948': '0',
#    '1973': '-1',
#    '1974': '1',
#    '1975': '0',
#    '1976': '0',
#    '1977': '0',
#    '1978': '-1',
#    '1980': '0'},
#   'Yugoslavia': {'1929': '-1',
#    '1930': '0',
#    '1931': '-1',
#    '1932': '1',
#    '1933': '1',
#    '1934': '0',
#    '1935': '3',
#    '1936': '0',
#    '1946': '0',
#    '1947': '2',
#    '1948': '2',
#    '1973': '0',
#    '1974': '0',
#    '1975': '0',
#    '1976': '0',
#    '1977': '0',
#    '1978': '1',
#    '1980': '0'},
#   'Turkey': {'1929': '0',
#    '1930': '0',
#    '1931': '0',
#    '1932': '0',
#    '1933': '0',
#    '1934': '0',
#    '1935': '0',
#    '1936': '0',
#    '1946': '0',
#    '1947': '0',
#    '1948': '0',
#    '1973': '1',
#    '1974': '-1',
#    '1975': '0',
#    '1976': '0',
#    '1977': '-1',
#    '1978': '0',
#    '1980': '0'},
#   'Albania': {'1929': '0',
#    '1930': '0',
#    '1931': '0',
#    '1932': '0',
#    '1933': '0',
#    '1934': '0',
#    '1935': '0',
#    '1936': '0',
#    '1946': '1',
#    '1947': '-4',
#    '1948': '1',
#    '1973': '0',
#    '1974': '0',
#    '1975': '0',
#    '1976': '0',
#    '1977': '0',
#    '1978': '0',
#    '1980': '0'},
#   'Hungary': {'1929': '0',
#    '1930': '0',
#    '1931': '0',
#    '1932': '0',
#    '1933': '0',
#    '1934': '0',
#    '1935': '0',
#    '1936': '0',
#    '1946': '0',
#    '1947': '4',
#    '1948': '2',
#    '1973': '0',
#    '1974': '0',
#    '1975': '0',
#    '1976': '0',
#    '1977': '0',
#    '1978': '0',
#    '1980': '0'},
#   'Poland': {'1929': '0',
#    '1930': '0',
#    '1931': '0',
#    '1932': '0',
#    '1933': '0',
#    '1934': '0',
#    '1935': '0',
#    '1936': '0',
#    '1946': '0',
#    '1947': '0',
#    '1948': '-1',
#    '1973': '0',
#    '1974': '0',
#    '1975': '0',
#    '1976': '0',
#    '1977': '0',
#    '1978': '0',
#    '1980': '0'}},
#  'FIFA World Cup': {'Belgium': {'1930': '-2',
#    '1934': '-1',
#    '1938': '-1',
#    '1950': '0',
#    '1954': '-1',
#    '1958': '0',
#    '1962': '0',
#    '1966': '0',
#    '1970': '-1',
#    '1974': '0',
#    '1978': '0',
#    '1982': '0',
#    '1986': '-1',
#    '1990': '0',
#    '1994': '0',
#    '1998': '0',
#    '2002': '0',
#    '2006': '0',
#    '2010': '0',
#    '2014': '3',
#    '2018': '5'},
#   'France': {'1930': '-1',
#    '1934': '-1',
#    '1938': '0',
#    '1950': '0',
#    '1954': '0',
#    '1958': '2',
#    '1962': '0',
#    '1966': '-2',
#    '1970': '0',
#    '1974': '0',
#    '1978': '-1',
#    '1982': '1',
#    '1986': '3',
#    '1990': '0',
#    '1994': '0',
#    '1998': '6',
#    '2002': '-2',
#    '2006': '4',
#    '2010': '-2',
#    '2014': '2',
#    '2018': '6'},
#   'Brazil': {'1930': '0',
#    '1934': '-1',
#    '1938': '2',
#    '1950': '3',
#    '1954': '0',
#    '1958': '5',
#    '1962': '5',
#    '1966': '-1',
#    '1970': '6',
#    '1974': '1',
#    '1978': '4',
#    '1982': '3',
#    '1986': '4',
#    '1990': '2',
#    '1994': '5',
#    '1998': '2',
#    '2002': '7',
#    '2006': '3',
#    '2010': '2',
#    '2014': '1',
#    '2018': '2'},
#   'Peru': {'1930': '-2',
#    '1934': '0',
#    '1938': '0',
#    '1950': '0',
#    '1954': '0',
#    '1958': '0',
#    '1962': '0',
#    '1966': '0',
#    '1970': '0',
#    '1974': '0',
#    '1978': '-1',
#    '1982': '-1',
#    '1986': '0',
#    '1990': '0',
#    '1994': '0',
#    '1998': '0',
#    '2002': '0',
#    '2006': '0',
#    '2010': '0',
#    '2014': '0',
#    '2018': '-1'},
#   'Argentina': {'1930': '3',
#    '1934': '-1',
#    '1938': '0',
#    '1950': '0',
#    '1954': '0',
#    '1958': '-1',
#    '1962': '0',
#    '1966': '1',
#    '1970': '0',
#    '1974': '-2',
#    '1978': '4',
#    '1982': '-1',
#    '1986': '6',
#    '1990': '0',
#    '1994': '0',
#    '1998': '2',
#    '2002': '0',
#    '2006': '3',
#    '2010': '3',
#    '2014': '4',
#    '2018': '-1'},
#   'Chile': {'1930': '1',
#    '1934': '0',
#    '1938': '0',
#    '1950': '-1',
#    '1954': '0',
#    '1958': '0',
#    '1962': '2',
#    '1966': '-2',
#    '1970': '0',
#    '1974': '-1',
#    '1978': '0',
#    '1982': '-3',
#    '1986': '0',
#    '1990': '0',
#    '1994': '0',
#    '1998': '-1',
#    '2002': '0',
#    '2006': '0',
#    '2010': '0',
#    '2014': '1',
#    '2018': '0'},
#   'Bolivia': {'1930': '-2',
#    '1934': '0',
#    '1938': '0',
#    '1950': '-1',
#    '1954': '0',
#    '1958': '0',
#    '1962': '0',
#    '1966': '0',
#    '1970': '0',
#    '1974': '0',
#    '1978': '0',
#    '1982': '0',
#    '1986': '0',
#    '1990': '0',
#    '1994': '-2',
#    '1998': '0',
#    '2002': '0',
#    '2006': '0',
#    '2010': '0',
#    '2014': '0',
#    '2018': '0'},
#   'Paraguay': {'1930': '0',
#    '1934': '0',
#    '1938': '0',
#    '1950': '-1',
#    '1954': '0',
#    '1958': '0',
#    '1962': '0',
#    '1966': '0',
#    '1970': '0',
#    '1974': '0',
#    '1978': '0',
#    '1982': '0',
#    '1986': '0',
#    '1990': '0',
#    '1994': '0',
#    '1998': '0',
#    '2002': '-1',
#    '2006': '-1',
#    '2010': '0',
#    '2014': '0',
#    '2018': '0'},
#   'Uruguay': {'1930': '4',
#    '1934': '0',
#    '1938': '0',
#    '1950': '3',
#    '1954': '1',
#    '1958': '0',
#    '1962': '-1',
#    '1966': '0',
#    '1970': '-1',
#    '1974': '-2',
#    '1978': '0',
#    '1982': '0',
#    '1986': '-2',
#    '1990': '-1',
#    '1994': '0',
#    '1998': '0',
#    '2002': '-1',
#    '2006': '0',
#    '2010': '1',
#    '2014': '0',
#    '2018': '3'},
#   'Austria': {'1930': '0',
#    '1934': '0',
#    '1938': '0',
#    '1950': '0',
#    '1954': '3',
#    '1958': '-2',
#    '1962': '0',
#    '1966': '0',
#    '1970': '0',
#    '1974': '0',
#    '1978': '0',
#    '1982': '0',
#    '1986': '0',
#    '1990': '-1',
#    '1994': '0',
#    '1998': '-1',
#    '2002': '0',
#    '2006': '0',
#    '2010': '0',
#    '2014': '0',
#    '2018': '0'},
#   'Czechoslovakia': {'1930': '0',
#    '1934': '2',
#    '1938': '0',
#    '1950': '0',
#    '1954': '-2',
#    '1958': '-1',
#    '1962': '1',
#    '1966': '0',
#    '1970': '-3',
#    '1974': '0',
#    '1978': '0',
#    '1982': '-1',
#    '1986': '0',
#    '1990': '1',
#    '1994': '0',
#    '1998': '0',
#    '2002': '0',
#    '2006': '0',
#    '2010': '0',
#    '2014': '0',
#    '2018': '0'},
#   'Egypt': {'1930': '0',
#    '1934': '-1',
#    '1938': '0',
#    '1950': '0',
#    '1954': '0',
#    '1958': '0',
#    '1962': '0',
#    '1966': '0',
#    '1970': '0',
#    '1974': '0',
#    '1978': '0',
#    '1982': '0',
#    '1986': '0',
#    '1990': '-1',
#    '1994': '0',
#    '1998': '0',
#    '2002': '0',
#    '2006': '0',
#    '2010': '0',
#    '2014': '0',
#    '2018': '-3'},
#   'Italy': {'1930': '0',
#    '1934': '4',
#    '1938': '4',
#    '1950': '0',
#    '1954': '-1',
#    '1958': '0',
#    '1962': '0',
#    '1966': '-1',
#    '1970': '2',
#    '1974': '0',
#    '1978': '2',
#    '1982': '4',
#    '1986': '0',
#    '1990': '6',
#    '1994': '3',
#    '1998': '3',
#    '2002': '-1',
#    '2006': '5',
#    '2010': '-1',
#    '2014': '-1',
#    '2018': '0'},
#   'Netherlands': {'1930': '0',
#    '1934': '-1',
#    '1938': '-1',
#    '1950': '0',
#    '1954': '0',
#    '1958': '0',
#    '1962': '0',
#    '1966': '0',
#    '1970': '0',
#    '1974': '4',
#    '1978': '1',
#    '1982': '0',
#    '1986': '0',
#    '1990': '-1',
#    '1994': '1',
#    '1998': '2',
#    '2002': '0',
#    '2006': '1',
#    '2010': '5',
#    '2014': '5',
#    '2018': '0'},
#   'Germany': {'1930': '0',
#    '1934': '2',
#    '1938': '-1',
#    '1950': '0',
#    '1954': '4',
#    '1958': '0',
#    '1962': '1',
#    '1966': '3',
#    '1970': '4',
#    '1974': '5',
#    '1978': '0',
#    '1982': '1',
#    '1986': '1',
#    '1990': '5',
#    '1994': '2',
#    '1998': '2',
#    '2002': '4',
#    '2006': '4',
#    '2010': '3',
#    '2014': '6',
#    '2018': '-1'},
#   'Cuba': {'1930': '0',
#    '1934': '0',
#    '1938': '0',
#    '1950': '0',
#    '1954': '0',
#    '1958': '0',
#    '1962': '0',
#    '1966': '0',
#    '1970': '0',
#    '1974': '0',
#    '1978': '0',
#    '1982': '0',
#    '1986': '0',
#    '1990': '0',
#    '1994': '0',
#    '1998': '0',
#    '2002': '0',
#    '2006': '0',
#    '2010': '0',
#    '2014': '0',
#    '2018': '0'},
#   'Hungary': {'1930': '0',
#    '1934': '0',
#    '1938': '2',
#    '1950': '0',
#    '1954': '3',
#    '1958': '-1',
#    '1962': '1',
#    '1966': '0',
#    '1970': '0',
#    '1974': '0',
#    '1978': '-3',
#    '1982': '0',
#    '1986': '-1',
#    '1990': '0',
#    '1994': '0',
#    '1998': '0',
#    '2002': '0',
#    '2006': '0',
#    '2010': '0',
#    '2014': '0',
#    '2018': '0'},
#   'Spain': {'1930': '0',
#    '1934': '0',
#    '1938': '0',
#    '1950': '1',
#    '1954': '0',
#    '1958': '0',
#    '1962': '-1',
#    '1966': '-1',
#    '1970': '0',
#    '1974': '0',
#    '1978': '0',
#    '1982': '-1',
#    '1986': '2',
#    '1990': '1',
#    '1994': '1',
#    '1998': '0',
#    '2002': '3',
#    '2006': '2',
#    '2010': '5',
#    '2014': '-1',
#    '2018': '1'},
#   'Switzerland': {'1930': '0',
#    '1934': '0',
#    '1938': '0',
#    '1950': '0',
#    '1954': '0',
#    '1958': '0',
#    '1962': '-3',
#    '1966': '-3',
#    '1970': '0',
#    '1974': '0',
#    '1978': '0',
#    '1982': '0',
#    '1986': '0',
#    '1990': '0',
#    '1994': '-1',
#    '1998': '0',
#    '2002': '0',
#    '2006': '2',
#    '2010': '0',
#    '2014': '0',
#    '2018': '0'},
#   'Mexico': {'1930': '-3',
#    '1934': '0',
#    '1938': '0',
#    '1950': '-3',
#    '1954': '-2',
#    '1958': '-2',
#    '1962': '-1',
#    '1966': '-1',
#    '1970': '1',
#    '1974': '0',
#    '1978': '-3',
#    '1982': '0',
#    '1986': '3',
#    '1990': '0',
#    '1994': '0',
#    '1998': '0',
#    '2002': '1',
#    '2006': '-1',
#    '2010': '-1',
#    '2014': '1',
#    '2018': '0'},
#   'England': {'1930': '0',
#    '1934': '0',
#    '1938': '0',
#    '1950': '-1',
#    '1954': '0',
#    '1958': '-1',
#    '1962': '-1',
#    '1966': '5',
#    '1970': '0',
#    '1974': '0',
#    '1978': '0',
#    '1982': '3',
#    '1986': '0',
#    '1990': '2',
#    '1994': '0',
#    '1998': '1',
#    '2002': '1',
#    '2006': '3',
#    '2010': '0',
#    '2014': '-2',
#    '2018': '0'},
#   'Sweden': {'1930': '0',
#    '1934': '0',
#    '1938': '-1',
#    '1950': '0',
#    '1954': '0',
#    '1958': '3',
#    '1962': '0',
#    '1966': '0',
#    '1970': '0',
#    '1974': '0',
#    '1978': '-2',
#    '1982': '0',
#    '1986': '0',
#    '1990': '-3',
#    '1994': '2',
#    '1998': '0',
#    '2002': '0',
#    '2006': '0',
#    '2010': '0',
#    '2014': '0',
#    '2018': '1'},
#   'Scotland': {'1930': '0',
#    '1934': '0',
#    '1938': '0',
#    '1950': '0',
#    '1954': '-2',
#    '1958': '-2',
#    '1962': '0',
#    '1966': '0',
#    '1970': '0',
#    '1974': '1',
#    '1978': '0',
#    '1982': '0',
#    '1986': '-2',
#    '1990': '-1',
#    '1994': '0',
#    '1998': '-2',
#    '2002': '0',
#    '2006': '0',
#    '2010': '0',
#    '2014': '0',
#    '2018': '0'},
#   'South Korea': {'1930': '0',
#    '1934': '0',
#    '1938': '0',
#    '1950': '0',
#    '1954': '-2',
#    '1958': '0',
#    '1962': '0',
#    '1966': '0',
#    '1970': '0',
#    '1974': '0',
#    '1978': '0',
#    '1982': '0',
#    '1986': '-2',
#    '1990': '-3',
#    '1994': '-1',
#    '1998': '-2',
#    '2002': '1',
#    '2006': '0',
#    '2010': '-1',
#    '2014': '-2',
#    '2018': '-1'},
#   'Colombia': {'1930': '0',
#    '1934': '0',
#    '1938': '0',
#    '1950': '0',
#    '1954': '0',
#    '1958': '0',
#    '1962': '-2',
#    '1966': '0',
#    '1970': '0',
#    '1974': '0',
#    '1978': '0',
#    '1982': '0',
#    '1986': '0',
#    '1990': '-1',
#    '1994': '-1',
#    '1998': '-1',
#    '2002': '0',
#    '2006': '0',
#    '2010': '0',
#    '2014': '3',
#    '2018': '1'},
#   'Russia': {'1930': '0',
#    '1934': '0',
#    '1938': '0',
#    '1950': '0',
#    '1954': '0',
#    '1958': '0',
#    '1962': '1',
#    '1966': '2',
#    '1970': '1',
#    '1974': '0',
#    '1978': '0',
#    '1982': '1',
#    '1986': '1',
#    '1990': '-1',
#    '1994': '-1',
#    '1998': '0',
#    '2002': '-1',
#    '2006': '0',
#    '2010': '0',
#    '2014': '-1',
#    '2018': '1'},
#   'Bulgaria': {'1930': '0',
#    '1934': '0',
#    '1938': '0',
#    '1950': '0',
#    '1954': '0',
#    '1958': '0',
#    '1962': '-2',
#    '1966': '-3',
#    '1970': '-2',
#    '1974': '-1',
#    '1978': '0',
#    '1982': '0',
#    '1986': '-2',
#    '1990': '0',
#    '1994': '0',
#    '1998': '-2',
#    '2002': '0',
#    '2006': '0',
#    '2010': '0',
#    '2014': '0',
#    '2018': '0'},
#   'North Korea': {'1930': '0',
#    '1934': '0',
#    '1938': '0',
#    '1950': '0',
#    '1954': '0',
#    '1958': '0',
#    '1962': '0',
#    '1966': '-1',
#    '1970': '0',
#    '1974': '0',
#    '1978': '0',
#    '1982': '0',
#    '1986': '0',
#    '1990': '0',
#    '1994': '0',
#    '1998': '0',
#    '2002': '0',
#    '2006': '0',
#    '2010': '-3',
#    '2014': '0',
#    '2018': '0'},
#   'Portugal': {'1930': '0',
#    '1934': '0',
#    '1938': '0',
#    '1950': '0',
#    '1954': '0',
#    '1958': '0',
#    '1962': '0',
#    '1966': '4',
#    '1970': '0',
#    '1974': '0',
#    '1978': '0',
#    '1982': '0',
#    '1986': '-1',
#    '1990': '0',
#    '1994': '0',
#    '1998': '0',
#    '2002': '-1',
#    '2006': '2',
#    '2010': '0',
#    '2014': '0',
#    '2018': '0'},
#   'Israel': {'1930': '0',
#    '1934': '0',
#    '1938': '0',
#    '1950': '0',
#    '1954': '0',
#    '1958': '0',
#    '1962': '0',
#    '1966': '0',
#    '1970': '-1',
#    '1974': '0',
#    '1978': '0',
#    '1982': '0',
#    '1986': '0',
#    '1990': '0',
#    '1994': '0',
#    '1998': '0',
#    '2002': '0',
#    '2006': '0',
#    '2010': '0',
#    '2014': '0',
#    '2018': '0'},
#   'Morocco': {'1930': '0',
#    '1934': '0',
#    '1938': '0',
#    '1950': '0',
#    '1954': '0',
#    '1958': '0',
#    '1962': '0',
#    '1966': '0',
#    '1970': '-2',
#    '1974': '0',
#    '1978': '0',
#    '1982': '0',
#    '1986': '0',
#    '1990': '0',
#    '1994': '-3',
#    '1998': '0',
#    '2002': '0',
#    '2006': '0',
#    '2010': '0',
#    '2014': '0',
#    '2018': '-2'},
#   'El Salvador': {'1930': '0',
#    '1934': '0',
#    '1938': '0',
#    '1950': '0',
#    '1954': '0',
#    '1958': '0',
#    '1962': '0',
#    '1966': '0',
#    '1970': '-3',
#    '1974': '0',
#    '1978': '0',
#    '1982': '-3',
#    '1986': '0',
#    '1990': '0',
#    '1994': '0',
#    '1998': '0',
#    '2002': '0',
#    '2006': '0',
#    '2010': '0',
#    '2014': '0',
#    '2018': '0'},
#   'DR Congo': {'1930': '0',
#    '1934': '0',
#    '1938': '0',
#    '1950': '0',
#    '1954': '0',
#    '1958': '0',
#    '1962': '0',
#    '1966': '0',
#    '1970': '0',
#    '1974': '-3',
#    '1978': '0',
#    '1982': '0',
#    '1986': '0',
#    '1990': '0',
#    '1994': '0',
#    '1998': '0',
#    '2002': '0',
#    '2006': '0',
#    '2010': '0',
#    '2014': '0',
#    '2018': '0'},
#   'German DR': {'1930': '0',
#    '1934': '0',
#    '1938': '0',
#    '1950': '0',
#    '1954': '0',
# ...
#   'Mauritius': {'2008': '0',
#    '2010': '0',
#    '2012': '1',
#    '2013': '-2',
#    '2014': '0',
#    '2015': '-1',
#    '2016': '0',
#    '2017': '-1',
#    '2018': '0',
#    '2019': '0'},
#   'Guinea': {'2008': '0',
#    '2010': '0',
#    '2012': '0',
#    '2013': '0',
#    '2014': '0',
#    '2015': '0',
#    '2016': '0',
#    '2017': '2',
#    '2018': '-1',
#    '2019': '0'},
#   'Liberia': {'2008': '0',
#    '2010': '0',
#    '2012': '-2',
#    '2013': '0',
#    '2014': '0',
#    '2015': '-1',
#    '2016': '0',
#    '2017': '0',
#    '2018': '0',
#    '2019': '0'},
#   'Mozambique': {'2008': '0',
#    '2010': '0',
#    '2012': '2',
#    '2013': '0',
#    '2014': '-3',
#    '2015': '0',
#    '2016': '0',
#    '2017': '-1',
#    '2018': '0',
#    '2019': '0'},
#   'Comoros': {'2008': '0',
#    '2010': '0',
#    '2012': '-1',
#    '2013': '0',
#    '2014': '0',
#    '2015': '-1',
#    '2016': '0',
#    '2017': '0',
#    '2018': '0',
#    '2019': '0'},
#   'Mauritania': {'2008': '0',
#    '2010': '0',
#    '2012': '2',
#    '2013': '1',
#    '2014': '-3',
#    '2015': '0',
#    '2016': '0',
#    '2017': '0',
#    '2018': '-3',
#    '2019': '0'},
#   'Seychelles': {'2008': '0',
#    '2010': '0',
#    '2012': '-2',
#    '2013': '0',
#    '2014': '0',
#    '2015': '-1',
#    '2016': '0',
#    '2017': '-1',
#    '2018': '0',
#    '2019': '-2'},
#   'Sierra Leone': {'2008': '0',
#    '2010': '0',
#    '2012': '0',
#    '2013': '0',
#    '2014': '0',
#    '2015': '-1',
#    '2016': '0',
#    '2017': '-1',
#    '2018': '0',
#    '2019': '0'},
#   'Burundi': {'2008': '0',
#    '2010': '0',
#    '2012': '1',
#    '2013': '0',
#    '2014': '0',
#    '2015': '0',
#    '2016': '0',
#    '2017': '-1',
#    '2018': '0',
#    '2019': '0'},
#   'Togo': {'2008': '0',
#    '2010': '0',
#    '2012': '-2',
#    '2013': '0',
#    '2014': '0',
#    '2015': '-1',
#    '2016': '0',
#    '2017': '0',
#    '2018': '0',
#    '2019': '0'},
#   'Kenya': {'2008': '0',
#    '2010': '0',
#    '2012': '-1',
#    '2013': '0',
#    '2014': '0',
#    '2015': '-1',
#    '2016': '0',
#    '2017': '0',
#    '2018': '0',
#    '2019': '0'},
#   'Eswatini': {'2008': '0',
#    '2010': '0',
#    '2012': '0',
#    '2013': '-2',
#    '2014': '0',
#    '2015': '-1',
#    '2016': '0',
#    '2017': '-2',
#    '2018': '0',
#    '2019': '0'},
#   'Angola': {'2008': '0',
#    '2010': '0',
#    '2012': '0',
#    '2013': '2',
#    '2014': '0',
#    '2015': '1',
#    '2016': '-1',
#    '2017': '2',
#    '2018': '0',
#    '2019': '0'},
#   'Mali': {'2008': '0',
#    '2010': '0',
#    '2012': '0',
#    '2013': '0',
#    '2014': '1',
#    '2015': '1',
#    '2016': '2',
#    '2017': '1',
#    '2018': '0',
#    '2019': '0'},
#   'Nigeria': {'2008': '0',
#    '2010': '0',
#    '2012': '0',
#    '2013': '0',
#    '2014': '3',
#    '2015': '1',
#    '2016': '0',
#    '2017': '0',
#    '2018': '3',
#    '2019': '0'},
#   'DR Congo': {'2008': '0',
#    '2010': '0',
#    '2012': '0',
#    '2013': '1',
#    '2014': '0',
#    '2015': '0',
#    '2016': '3',
#    '2017': '0',
#    '2018': '0',
#    '2019': '0'},
#   'Morocco': {'2008': '0',
#    '2010': '0',
#    '2012': '0',
#    '2013': '0',
#    '2014': '0',
#    '2015': '3',
#    '2016': '0',
#    '2017': '1',
#    '2018': '5',
#    '2019': '0'},
#   'Ivory Coast': {'2008': '0',
#    '2010': '0',
#    '2012': '0',
#    '2013': '0',
#    '2014': '0',
#    '2015': '0',
#    '2016': '2',
#    '2017': '0',
#    '2018': '-2',
#    '2019': '0'},
#   'Niger': {'2008': '0',
#    '2010': '0',
#    '2012': '0',
#    '2013': '1',
#    '2014': '0',
#    '2015': '1',
#    '2016': '-2',
#    '2017': '0',
#    '2018': '0',
#    '2019': '0'},
#   'Rwanda': {'2008': '0',
#    '2010': '0',
#    '2012': '0',
#    '2013': '1',
#    '2014': '0',
#    '2015': '0',
#    '2016': '0',
#    '2017': '0',
#    '2018': '0',
#    '2019': '0'},
#   'Uganda': {'2008': '0',
#    '2010': '0',
#    '2012': '0',
#    '2013': '1',
#    '2014': '0',
#    '2015': '3',
#    '2016': '-1',
#    '2017': '1',
#    '2018': '-2',
#    '2019': '0'},
#   'Cameroon': {'2008': '0',
#    '2010': '0',
#    '2012': '0',
#    '2013': '-1',
#    '2014': '0',
#    '2015': '1',
#    '2016': '1',
#    '2017': '2',
#    '2018': '-2',
#    '2019': '0'},
#   'Congo': {'2008': '0',
#    '2010': '0',
#    '2012': '0',
#    '2013': '0',
#    '2014': '0',
#    '2015': '-1',
#    '2016': '0',
#    '2017': '0',
#    '2018': '2',
#    '2019': '0'},
#   'Sudan': {'2008': '0',
#    '2010': '0',
#    '2012': '0',
#    '2013': '0',
#    '2014': '0',
#    '2015': '-2',
#    '2016': '0',
#    '2017': '1',
#    '2018': '2',
#    '2019': '0'},
#   'Namibia': {'2008': '0',
#    '2010': '0',
#    '2012': '0',
#    '2013': '0',
#    '2014': '0',
#    '2015': '0',
#    '2016': '0',
#    '2017': '0',
#    '2018': '1',
#    '2019': '0'},
#   'Zimbabwe': {'2008': '0',
#    '2010': '0',
#    '2012': '0',
#    '2013': '3',
#    '2014': '1',
#    '2015': '2',
#    '2016': '-2',
#    '2017': '0',
#    '2018': '0',
#    '2019': '0'},
#   'Gabon': {'2008': '0',
#    '2010': '0',
#    '2012': '0',
#    '2013': '0',
#    '2014': '2',
#    '2015': '-1',
#    '2016': '-2',
#    '2017': '0',
#    '2018': '0',
#    '2019': '0'},
#   'Zambia': {'2008': '0',
#    '2010': '0',
#    '2012': '0',
#    '2013': '-1',
#    '2014': '0',
#    '2015': '1',
#    '2016': '2',
#    '2017': '2',
#    '2018': '1',
#    '2019': '0'},
#   'South Africa': {'2008': '0',
#    '2010': '0',
#    '2012': '0',
#    '2013': '0',
#    '2014': '0',
#    '2015': '1',
#    '2016': '0',
#    '2017': '2',
#    '2018': '0',
#    '2019': '0'},
#   'Ghana': {'2008': '0',
#    '2010': '0',
#    '2012': '0',
#    '2013': '0',
#    '2014': '3',
#    '2015': '0',
#    '2016': '0',
#    '2017': '-1',
#    '2018': '0',
#    '2019': '0'},
#   'Libya': {'2008': '0',
#    '2010': '0',
#    '2012': '0',
#    '2013': '0',
#    '2014': '1',
#    '2015': '-3',
#    '2016': '0',
#    '2017': '1',
#    '2018': '0',
#    '2019': '0'},
#   'Ethiopia': {'2008': '0',
#    '2010': '0',
#    '2012': '0',
#    '2013': '-1',
#    '2014': '-3',
#    '2015': '2',
#    '2016': '-2',
#    '2017': '2',
#    '2018': '0',
#    '2019': '0'},
#   'Senegal': {'2008': '0',
#    '2010': '0',
#    '2012': '0',
#    '2013': '-1',
#    '2014': '0',
#    '2015': '2',
#    '2016': '0',
#    '2017': '1',
#    '2018': '0',
#    '2019': '0'},
#   'Tanzania': {'2008': '0',
#    '2010': '0',
#    '2012': '0',
#    '2013': '-1',
#    '2014': '0',
#    '2015': '-1',
#    '2016': '0',
#    '2017': '0',
#    '2018': '0',
#    '2019': '0'},
#   'Djibouti': {'2008': '0',
#    '2010': '0',
#    '2012': '0',
#    '2013': '0',
#    '2014': '0',
#    '2015': '-1',
#    '2016': '0',
#    '2017': '-2',
#    '2018': '0',
#    '2019': '0'},
#   'Lesotho': {'2008': '0',
#    '2010': '0',
#    '2012': '0',
#    '2013': '0',
#    '2014': '0',
#    '2015': '-1',
#    '2016': '0',
#    '2017': '0',
#    '2018': '0',
#    '2019': '0'},
#   'Tunisia': {'2008': '0',
#    '2010': '0',
#    '2012': '0',
#    '2013': '0',
#    '2014': '0',
#    '2015': '0',
#    '2016': '0',
#    '2017': '0',
#    '2018': '0',
#    '2019': '0'},
#   'Somalia': {'2008': '0',
#    '2010': '0',
#    '2012': '0',
#    '2013': '0',
#    '2014': '0',
#    '2015': '0',
#    '2016': '0',
#    '2017': '-2',
#    '2018': '0',
#    '2019': '0'},
#   'Madagascar': {'2008': '0',
#    '2010': '0',
#    '2012': '0',
#    '2013': '0',
#    '2014': '0',
#    '2015': '0',
#    '2016': '0',
#    '2017': '3',
#    '2018': '0',
#    '2019': '0'},
#   'Malawi': {'2008': '0',
#    '2010': '0',
#    '2012': '0',
#    '2013': '0',
#    '2014': '0',
#    '2015': '0',
#    '2016': '0',
#    '2017': '-2',
#    '2018': '0',
#    '2019': '0'},
#   'South Sudan': {'2008': '0',
#    '2010': '0',
#    '2012': '0',
#    '2013': '0',
#    '2014': '0',
#    '2015': '0',
#    '2016': '0',
#    '2017': '1',
#    '2018': '0',
#    '2019': '0'},
#   'Botswana': {'2008': '0',
#    '2010': '0',
#    '2012': '0',
#    '2013': '0',
#    '2014': '0',
#    '2015': '0',
#    '2016': '0',
#    '2017': '-2',
#    '2018': '0',
#    '2019': '2'},
#   'Gambia': {'2008': '0',
#    '2010': '0',
#    '2012': '0',
#    '2013': '0',
#    '2014': '0',
#    '2015': '-1',
#    '2016': '0',
#    '2017': '-1',
#    '2018': '0',
#    '2019': '0'},
#   'Guinea-Bissau': {'2008': '0',
#    '2010': '0',
#    '2012': '0',
#    '2013': '0',
#    '2014': '0',
#    '2015': '0',
#    '2016': '0',
#    '2017': '-2',
#    '2018': '0',
#    '2019': '0'},
#   'Benin': {'2008': '0',
#    '2010': '0',
#    '2012': '0',
#    '2013': '0',
#    '2014': '0',
#    '2015': '0',
#    '2016': '0',
#    '2017': '0',
#    '2018': '0',
#    '2019': '0'},
#   'São Tomé and Príncipe': {'2008': '0',
#    '2010': '0',
#    '2012': '0',
#    '2013': '0',
#    '2014': '0',
#    '2015': '0',
#    '2016': '0',
#    '2017': '-2',
#    '2018': '0',
#    '2019': '0'},
#   'Algeria': {'2008': '0',
#    '2010': '0',
#    '2012': '0',
#    '2013': '0',
#    '2014': '0',
#    '2015': '0',
#    '2016': '0',
#    '2017': '-1',
#    '2018': '0',
#    '2019': '0'},
#   'Egypt': {'2008': '0',
#    '2010': '0',
#    '2012': '0',
#    '2013': '0',
#    '2014': '0',
#    '2015': '0',
#    '2016': '0',
#    '2017': '-1',
#    '2018': '0',
#    '2019': '0'},
#   'Equatorial Guinea': {'2008': '0',
#    '2010': '0',
#    '2012': '0',
#    '2013': '0',
#    '2014': '0',
#    '2015': '0',
#    '2016': '0',
#    '2017': '0',
#    '2018': '-3',
#    '2019': '0'}},
#  'VFF Cup': {'Thailand': {'2008': '1', '2010': '0', '2012': '0'},
#   'Vietnam': {'2008': '0', '2010': '-1', '2012': '0'},
#   'Singapore': {'2008': '0', '2010': '-1', '2012': '0'},
#   'Laos': {'2008': '0', '2010': '0', '2012': '-2'}},
#  'Dragon Cup': {'Philippines': {'2010': '1', '2011': '1'},
#   'Hong Kong': {'2010': '0', '2011': '1'}},
#  'ABCS Tournament': {'Curaçao': {'2010': '1',
#    '2011': '-2',
#    '2012': '0',
#    '2013': '0',
#    '2015': '1'},
#   'Suriname': {'2010': '1',
#    '2011': '1',
#    '2012': '0',
#    '2013': '2',
#    '2015': '2'},
#   'Aruba': {'2010': '-1',
#    '2011': '0',
#    '2012': '2',
#    '2013': '-2',
#    '2015': '-1'},
#   'Bonaire': {'2010': '-1',
#    '2011': '1',
#    '2012': '-2',
#    '2013': '0',
#    '2015': '-2'}},
#  'Nile Basin Tournament': {'Egypt': {'2011': '5'},
#   'Kenya': {'2011': '-2'},
#   'Uganda': {'2011': '0'},
#   'DR Congo': {'2011': '2'},
#   'Tanzania': {'2011': '-2'}},
#  'Nations Cup': {'Republic of Ireland': {'2011': '3'},
#   'Scotland': {'2011': '1'},
#   'Wales': {'2011': '-1'}},
#  'Pacific Games': {'Fiji': {'2011': '2', '2019': '2'},
#   'New Caledonia': {'2011': '5', '2019': '5'},
#   'Papua New Guinea': {'2011': '1', '2019': '3'},
#   'Solomon Islands': {'2011': '3', '2019': '0'},
#   'Tuvalu': {'2011': '-2', '2019': '-4'},
#   'American Samoa': {'2011': '-5', '2019': '-2'},
#   'Tahiti': {'2011': '1', '2019': '-1'},
#   'Vanuatu': {'2011': '3', '2019': '1'},
#   'Cook Islands': {'2011': '-2', '2019': '0'},
#   'Guam': {'2011': '-2', '2019': '0'},
#   'Kiribati': {'2011': '-4', '2019': '0'},
#   'Samoa': {'2011': '0', '2019': '-1'},
#   'Tonga': {'2011': '0', '2019': '-3'}},
#  'OSN Cup': {'Saudi Arabia': {'2013': '-2'},
#   'United Arab Emirates': {'2013': '1'}},
#  'CONIFA World Football Cup': {'Iraqi Kurdistan': {'2014': '0',
#    '2016': '2',
#    '2018': '0'},
#   'Abkhazia': {'2014': '0', '2016': '4', '2018': '3'},
#   'Darfur': {'2014': '-4', '2016': '0', '2018': '0'},
#   'Ellan Vannin': {'2014': '3', '2016': '0', '2018': '1'},
#   'Tamil Eelam': {'2014': '-2', '2016': '0', '2018': '-4'},
#   'Sápmi': {'2014': '-2', '2016': '1', '2018': '0'},
#   'South Ossetia': {'2014': '-2', '2016': '0', '2018': '0'},
#   'Artsakh': {'2014': '0', '2016': '0', '2018': '0'},
#   'Padania': {'2014': '1', '2016': '0', '2018': '3'},
#   'Arameans Suryoye': {'2014': '2', '2016': '0', '2018': '0'},
#   'Occitania': {'2014': '2', '2016': '0', '2018': '0'},
#   'County of Nice': {'2014': '2', '2016': '0', '2018': '0'},
#   'Chagos Islands': {'2014': '0', '2016': '-3', '2018': '0'},
#   'United Koreans in Japan': {'2014': '0', '2016': '-1', '2018': '0'},
#   'Raetia': {'2014': '0', '2016': '-3', '2018': '0'},
#   'Northern Cyprus': {'2014': '0', '2016': '2', '2018': '3'},
#   'Somaliland': {'2014': '0', '2016': '0', '2018': '0'},
#   'Western Armenia': {'2014': '0', '2016': '-2', '2018': '1'},
#   'Székely Land': {'2014': '0', '2016': '-2', '2018': '1'},
#   'Barawa': {'2014': '0', '2016': '0', '2018': '-2'},
#   'Panjab': {'2014': '0', '2016': '2', '2018': '0'},
#   'Kárpátalja': {'2014': '0', '2016': '0', '2018': '4'},
#   'Tuvalu': {'2014': '0', '2016': '0', '2018': '-5'},
#   'Matabeleland': {'2014': '0', '2016': '0', '2018': '0'},
#   'Tibet': {'2014': '0', '2016': '0', '2018': '-4'},
#   'Cascadia': {'2014': '0', '2016': '0', '2018': '1'},
#   'Kabylia': {'2014': '0', '2016': '0', '2018': '-2'}},
#  'CONIFA European Football Cup': {'Székely Land': {'2015': '-3',
#    '2017': '0',
#    '2019': '-4'},
#   'Padania': {'2015': '4', '2017': '2', '2019': '0'},
#   'Romani people': {'2015': '-1', '2017': '0', '2019': '0'},
#   'Felvidék': {'2015': '-1', '2017': '0', '2019': '0'},
#   'County of Nice': {'2015': '2', '2017': '0', '2019': '0'},
#   'Ellan Vannin': {'2015': '-1', '2017': '-1', '2019': '0'},
#   'Northern Cyprus': {'2015': '0', '2017': '3', '2019': '0'},
#   'Abkhazia': {'2015': '0', '2017': '0', '2019': '2'},
#   'Kárpátalja': {'2015': '0', '2017': '0', '2019': '0'},
#   'South Ossetia': {'2015': '0', '2017': '-4', '2019': '3'},
#   'Artsakh': {'2015': '0', '2017': '0', '2019': '2'},
#   'Western Armenia': {'2015': '0', '2017': '0', '2019': '-1'},
#   'Sápmi': {'2015': '0', '2017': '0', '2019': '-3'},
#   'Chameria': {'2015': '0', '2017': '0', '2019': '1'}},
#  'Copa América qualification': {'Trinidad and Tobago': {'2016': '-1'},
#   'Panama': {'2016': '1'}},
#  'World Unity Cup': {'Barawa': {'2016': '-2'},
#   'Chagos Islands': {'2016': '-1'}},
#  'Intercontinental Cup': {'India': {'2018': '2', '2019': '-2'},
#   'Kenya': {'2018': '0', '2019': '0'},
#   'Chinese Taipei': {'2018': '-3', '2019': '0'},
#   'Syria': {'2018': '0', '2019': '0'},
#   'Tajikistan': {'2018': '0', '2019': '0'},
#   'North Korea': {'2018': '0', '2019': '2'}},
#  'AFF Championship qualification': {'Timor-Leste': {'2018': '0'},
#   'Brunei': {'2018': '0'}},
#  'UEFA Nations League': {'Germany': {'2018': '-2', '2019': '0'},
#   'Czech Republic': {'2018': '0', '2019': '0'},
#   'Wales': {'2018': '0', '2019': '0'},
#   'Norway': {'2018': '3', '2019': '0'},
#   'Slovenia': {'2018': '-3', '2019': '0'},
#   'Kazakhstan': {'2018': '-1', '2019': '0'},
#   'Latvia': {'2018': '-2', '2019': '0'},
#   'Armenia': {'2018': '1', '2019': '0'},
#   'Gibraltar': {'2018': '-2', '2019': '0'},
#   'Italy': {'2018': '0', '2019': '0'},
#   'Turkey': {'2018': '-2', '2019': '0'},
#   'Albania': {'2018': '-2', '2019': '0'},
#   'Lithuania': {'2018': '-6', '2019': '0'},
#   'Romania': {'2018': '3', '2019': '0'},
#   'Faroe Islands': {'2018': '-2', '2019': '0'},
#   'Azerbaijan': {'2018': '1', '2019': '0'},
#   'Switzerland': {'2018': '2', '2019': '-1'},
#   'England': {'2018': '1', '2019': '-1'},
#   'Northern Ireland': {'2018': '-4', '2019': '0'},
#   'Finland': {'2018': '2', '2019': '0'},
#   'Estonia': {'2018': '-3', '2019': '0'},
#   'Belarus': {'2018': '4', '2019': '0'},
#   'Luxembourg': {'2018': '1', '2019': '0'},
#   'France': {'2018': '1', '2019': '0'},
#   'Ukraine': {'2018': '2', '2019': '0'},
#   'Denmark': {'2018': '2', '2019': '0'},
#   'Bulgaria': {'2018': '2', '2019': '0'},
#   'Cyprus': {'2018': '-2', '2019': '0'},
#   'Georgia': {'2018': '5', '2019': '0'},
#   'North Macedonia': {'2018': '4', '2019': '0'},
#   'Liechtenstein': {'2018': '-3', '2019': '0'},
#   'Portugal': {'2018': '2', '2019': '2'},
#   'Sweden': {'2018': '1', '2019': '0'},
#   'Scotland': {'2018': '2', '2019': '0'},
#   'Montenegro': {'2018': '-1', '2019': '0'},
#   'Serbia': {'2018': '4', '2019': '0'},
#   'Andorra': {'2018': '-2', '2019': '0'},
#   'Kosovo': {'2018': '4', '2019': '0'},
#   'Malta': {'2018': '-3', '2019': '0'},
#   'Iceland': {'2018': '-4', '2019': '0'},
#   'Spain': {'2018': '0', '2019': '0'},
#   'Bosnia and Herzegovina': {'2018': '3', '2019': '0'},
#   'Hungary': {'2018': '1', '2019': '0'},
#   'San Marino': {'2018': '-6', '2019': '0'},
#   'Moldova': {'2018': '1', '2019': '0'},
#   'Poland': {'2018': '-2', '2019': '0'},
#   'Russia': {'2018': '1', '2019': '0'},
#   'Israel': {'2018': '0', '2019': '0'},
#   'Belgium': {'2018': '2', '2019': '0'},
#   'Croatia': {'2018': '-1', '2019': '0'},
#   'Austria': {'2018': '1', '2019': '0'},
#   'Greece': {'2018': '0', '2019': '0'},
#   'Netherlands': {'2018': '1', '2019': '0'},
#   'Slovakia': {'2018': '-2', '2019': '0'},
#   'Republic of Ireland': {'2018': '-2', '2019': '0'}},
#  'Atlantic Heritage Cup': {'Yorkshire': {'2019': '1'},
#   'Parishes of Jersey': {'2019': '0'}},
#  'Inter Games Football Tournament': {'Jersey': {'2019': '2'},
#   'Ynys Môn': {'2019': '5'},
#   'Alderney': {'2019': '-1'},
#   'Saint Helena': {'2019': '-3'},
#   'Isle of Man': {'2019': '2'},
#   'Guernsey': {'2019': '2'},
#   'Western Isles': {'2019': '-2'},
#   'Orkney': {'2019': '-2'},
#   'Shetland': {'2019': '-2'}}}

# %% [markdown]
# ## 1.4 Convert Dictionary back to DataFrame:

# %%
data_tournamentTypes_homeTeam = pd.DataFrame.from_dict({(i,j,k): dict_tournamentTypes_homeTeam[i][j][k] 
                           for i in dict_tournamentTypes_homeTeam.keys() 
                           for j in dict_tournamentTypes_homeTeam[i].keys()
                            for k in dict_tournamentTypes_homeTeam[i][j].keys()},
                       orient='index')

# %%
data_tournamentTypes_homeTeam.head(20)
# Out:
#                                                  0
# (British Championship, Northern Ireland, 1884)  -3
# (British Championship, Northern Ireland, 1885)  -3
# (British Championship, Northern Ireland, 1886)  -3
# (British Championship, Northern Ireland, 1887)  -1
# (British Championship, Northern Ireland, 1888)  -3
# (British Championship, Northern Ireland, 1889)  -3
# (British Championship, Northern Ireland, 1890)  -3
# (British Championship, Northern Ireland, 1891)  -1
# (British Championship, Northern Ireland, 1892)  -2
# (British Championship, Northern Ireland, 1893)  -2
# (British Championship, Northern Ireland, 1894)  -2
# (British Championship, Northern Ireland, 1895)  -2
# (British Championship, Northern Ireland, 1896)  -2
# (British Championship, Northern Ireland, 1897)  -1
# (British Championship, Northern Ireland, 1898)  -1
# (British Championship, Northern Ireland, 1899)  -1
# (British Championship, Northern Ireland, 1900)  -3
# (British Championship, Northern Ireland, 1901)  -3
# (British Championship, Northern Ireland, 1902)  -1
# (British Championship, Northern Ireland, 1903)   2

# %%
data_tournamentTypes_homeTeam.shape
# Out:
# (34431, 1)

# %%
data_tournamentTypes_homeTeam.tail()
# Out:
#                                                      0
# (Inter Games Football Tournament, Isle of Man, ...   2
# (Inter Games Football Tournament, Guernsey, 2019)    2
# (Inter Games Football Tournament, Western Isles...  -2
# (Inter Games Football Tournament, Orkney, 2019)     -2
# (Inter Games Football Tournament, Shetland, 2019)   -2

# %% [markdown]
# ## 1.5 Edit the Index:

# %%
def task1_newDF_processing(dataFrame):
    
    data = dataFrame.reset_index()
    data = data.rename(columns={"index": "tournament"})
    data['RankPoints'] = data[0]
    data = data.drop(columns=[0])
    data_index = data.index
        
    data_new = pd.DataFrame(columns=['tournament','team','year','RankPoints'], index= data_index)
    # Step 1 - Separate the column data out: 
    for i in range(len(data['tournament'])):
#         print(i, len(test['tournament']))
#         print(test['tournament'][i])
        data_new['tournament'][i] = data['tournament'][i][0]
        data_new['team'][i] = data['tournament'][i][1]
        data_new['year'][i] = data['tournament'][i][2]
        data_new['RankPoints'][i] = data['RankPoints'][i]  
    
    dataFrame = data_new
    return dataFrame;

# %%
data_football_task1_v6 = task1_newDF_processing(data_tournamentTypes_homeTeam)

# %%
data_football_task1_v6.head()
# Out:
#              tournament              team  year RankPoints
# 0  British Championship  Northern Ireland  1884         -3
# 1  British Championship  Northern Ireland  1885         -3
# 2  British Championship  Northern Ireland  1886         -3
# 3  British Championship  Northern Ireland  1887         -1
# 4  British Championship  Northern Ireland  1888         -3

# %%
data_football_task1_v6.tail()
# Out:
#                             tournament           team  year RankPoints
# 34426  Inter Games Football Tournament    Isle of Man  2019          2
# 34427  Inter Games Football Tournament       Guernsey  2019          2
# 34428  Inter Games Football Tournament  Western Isles  2019         -2
# 34429  Inter Games Football Tournament         Orkney  2019         -2
# 34430  Inter Games Football Tournament       Shetland  2019         -2

# %%
len(data_football_task1_v6)
# Out:
# 34431

# %% [markdown]
# # Save the output into CSV format:

# %%
# IGNORE THIS ONE: better method of saving is in the next chunk of code.

# # path_directory
# data_football_grouped.to_csv(path_directory, 'football_task1', sep='\t')

# %%
# USE THIS ONE:

import os
# data_football_grouped_sorted.to_csv(os.path.join(path_directory, r'football_task1_sorted.csv'))
# data_football_grouped.to_csv(os.path.join(path_directory, r'football_task1.csv'))
# champion_df.to_csv(os.path.join(path_directory, r'champion_df.csv'))
# data_football_task1_v2.to_csv(os.path.join(path_directory, r'data_football_task1_v2.csv'))
# data_football.to_csv(os.path.join(path_directory, r'data_football_task1_withRankPoints.csv'))

# data_football_rankingOverTime.to_csv(os.path.join(path_directory, r'data_football_rankingOverTime.csv'))
# data_football.to_csv(os.path.join(path_directory, r'data_football_rankingOverTime_v5.csv'))
# data_tournamentTypes_homeTeam.to_csv(os.path.join(path_directory, r'data_football_rankingOverTime_v6.csv'))
# data_football_task1_v6.to_csv(os.path.join(path_directory, r'data_football_rankingOverTime_v7.csv'))
# data_football.to_csv(os.path.join(path_directory, r'data_football_RelevantTournaments.csv'))

# %% [markdown]
# ## Backup codes:

# %%
# # Plot:

# categorical = list(data_football['tournament'].unique())

# # categorical = ['British Championship', 'Copa Lipton', 'Copa Newton']


# # fig, ax = plt.subplots(len(data_football_tournamentTypes_rankedTop5),1, figsize=(16, 25))
# # fig, ax = plt.subplots(len(categorical),1, figsize=(16, len(categorical)))

# fig, ax = plt.subplots(len(categorical),1, figsize=(16, (len(categorical)*3)))



# for i, (tournament_name, subplot) in enumerate(zip(categorical, ax.flatten())):
#     plt.figure(i)
#     fig.subplots_adjust(hspace=.5)
# #     sns.barplot(x='home_team',
# #                 y='match_scores',
# #                 data=data_football_tournamentTypes_rankedTop5[i]).set(xlabel='Home Teams', ylabel='Match Scores')
#     sns.countplot(x='home_team',
#                   y='match_scores',
#                   data=data_football_tournamentTypes_rankedTop5[i])
    
#     # Add Suplot Titles:
#     ax[i].set_title(tournament_name) 



# # Add Overall Plot title:
# fig.suptitle('Top 5 Ranking Teams in each Tournament')

# %%
# subset_test = data_football_task1_v2.loc[data_football_task1_v2['home_team'] == homeTeam_list[2]]
# len(subset_test)


# input_scores = []
# total_score = 0
# subset_test_scores = []

# print(type(subset_test_scores))

# # Make a list of Input Scores from subset of Data:
# for j in subset_test.index:
#     print(j)
#     point_values = subset_test['rank_points'][j]
#     input_scores.append(point_values)
# #     print('Current taken point is: ', point_values)
# print('input scores: ', input_scores)

# # Cummulative Calculations:
# for values in input_scores:
#     total_score = total_score + values
#     subset_test_scores.append(total_score)

# print('Subset Cummulative scores: ', subset_test_scores)
# subset_test_scores


# subset_test['rank_test'] = pd.DataFrame(subset_test_scores, index = subset_test.index)

# %%
# homeTeam_list = list(data_football_task1_v2['home_team'].unique())

# dict_homeTeam_withTotalScores = {}


# # for i in range(len(homeTeam_list)):
# for i, home_team_name in enumerate(homeTeam_list):
#     print(i, home_team_name)

#     # Step 1 - Grab a Subset from main dataset:
#     print('At index: ',i, '; Current HomeTeam is: ', homeTeam_list[i])
#     data_subset = data_football_task1_v2.loc[data_football_task1_v2['home_team'] == homeTeam_list[i]]

#     # Step 2 - Perform Calculations on Ranking Points: 2 stages.
#     input_scores = []
#     total_score = 0
#     subset_cummulative_scores = []

#     # Make a list of Input Scores from subset of Data:
#     for j in data_subset.index:
#         point_values = data_subset['rank_points'][j]
#         input_scores.append(point_values)
#     print('input scores: ', input_scores)

#     # Cummulative Calculations:
#     for values in input_scores:
#         total_score = total_score + values
#         subset_cummulative_scores.append(total_score)

#     print('Subset Cummulative scores: ', subset_cummulative_scores)

#     # Step 3 - Save the total scores for each of the homeTeams in a Dictionary:
#     dict_homeTeam_withTotalScores[home_team_name] = subset_cummulative_scores

# %%
# data_rankingOverTime = data_football_task1_v2.copy()

# homeTeam_list = list(data_rankingOverTime['home_team'].unique())

# data_football_rankingOverTime = pd.DataFrame()

# for i, home_team_name in enumerate(homeTeam_list):
#     print(i, home_team_name)
    
# #     data_freshCopy = data_football_task1_v2.copy()
    
#     # Get the indexes from subset data:
#     data_subset = data_rankingOverTime[data_rankingOverTime['home_team'] == home_team_name].iloc[:,:]
# #     print(data_subset)
#     index_df = data_subset.index
    
#     # Convert cummulative scores into a dataframe(from list), with the correct indexing by homeTeams:
#     list_score = dict_homeTeam_withTotalScores[home_team_name]
#     print(list_score, type(list_score))
    
#     df_temp = pd.DataFrame(list_score, columns=['RankOverTime'], index = index_df)
#     print(df_temp)

#     # Combine the temporary Dataframe with the Subset of Data taken:
#     mergedDf = pd.merge(data_subset, df_temp, left_index=True, right_index=True)
#     print(mergedDf)
    
#     # Append to the main Dataset with mergeDf:
#     data_football_rankingOverTime = data_football_rankingOverTime.append(mergedDf, ignore_index = True)

# %%
# # Dict of End of Year Ranks by Tournaments:
# dict_EndYearRanks = {}

# # Step 1 - Make of Copy of the Dataset:
# data_tournaments = data_football.copy()

# # Step 2 - Change the format of the Date column to DateTime:
# data_tournaments['date'] = pd.to_datetime(data_tournaments['date'])
# data_tournaments['year'] = data_tournaments['date'].dt.year

# # Step 3 - Take a subset of the DataFrame by Tournament type:
# tournament_list = list(data_tournaments['tournament'].unique())
# data_tournamentTypes_awayTeam = {}

# for i, tournamentName in enumerate(tournament_list):
# #     print(i, tournamentName)
#     subset_data = data_tournaments[data_tournaments['tournament'] == tournamentName].iloc[:,:]
# #     print(subset_data)

#     # List of team names:
#     teamNames_list = list(subset_data['away_team'].unique())

#     # Dict:
#     dict_teamScores = {}
    
#     # Step 4 - Collect the ranking point(Home Team):
#     for j, teamNames  in enumerate(teamNames_list):
#         print(j, teamNames)

#         # Step 5 - Grab a Subset from main dataset:
#         print('At index: ',i, '; Current AwayTeam is: ', teamNames_list[j])
#         data_subset_team = subset_data.loc[subset_data['away_team'] == teamNames_list[j]]
# #         print(data_subset_team)
        
#         # Step 6 - 
#         # List of dates: by YEAR
#         years_list = list(subset_data['year'].unique())
        
#         # Dict:
#         dict_yearAndScores = {}

#         # Step 7 - make a list of the column['home_team_rank_points']:
#         for k, year  in enumerate(years_list):
#             print('At index: ',k, '; Current AwayTeam is: ', years_list[k])
#             data_subset_team_byYear = data_subset_team.loc[data_subset_team['year'] == years_list[k]]
# #             print(data_subset_team_byYear)
            
#             # Dictionaries and Lists:
#             input_scores = []
#             total_score = 0
#             subset_cummulative_scores = []
            
#             # Make a list of the Input Socres from subset of Data:
#             for l in data_subset_team_byYear.index:
#                 point_values = data_subset_team_byYear['away_team_rank_points'][l]
#                 input_scores.append(point_values)
            
#             # Append to Dict {dict_yearAndScores}: dict[key] = value
#             dict_yearAndScores[year] = input_scores

#         # Step 8 - Update both the Home and Away team score to the overall Dictionary: 
            
#         # Append to Dict {dict_teamScores}: dict[key] = value
#         dict_teamScores[teamNames] = dict_yearAndScores
        
#     # Append to Dict {dict_teamScores}: dict[key] = value
#     data_tournamentTypes_awayTeam[tournamentName] = dict_teamScores

# %%
# # Dict of End of Year Ranks by Tournaments:
# dict_EndYearRanks = {}

# # Step 1 - Make of Copy of the Dataset:
# data_tournaments = data_football.copy()

# # Step 2 - Change the format of the Date column to DateTime:
# data_tournaments['date'] = pd.to_datetime(data_tournaments['date'])
# data_tournaments['year'] = data_tournaments['date'].dt.year

# # Step 3 - Take a subset of the DataFrame by Tournament type:
# tournament_list = list(data_tournaments['tournament'].unique())
# data_tournamentTypes_homeTeam = {}

# for i, tournamentName in enumerate(tournament_list):
# #     print(i, tournamentName)
#     subset_data = data_tournaments[data_tournaments['tournament'] == tournamentName].iloc[:,:]
# #     print(subset_data)

#     # List of team names:
#     teamNames_list_home = list(subset_data['home_team'].unique())
#     teamNames_list_away = list(subset_data['away_team'].unique())

#     # Dict:
#     dict_teamScores = {}
    
#     # Step 4 - Collect the ranking point(Home Team):
#     for j, teamNames  in enumerate(teamNames_list):
#         print(j, teamNames)

#         # Step 5 - Grab a Subset from main dataset:
#         print('At index: ',i, '; Current HomeTeam is: ', teamNames_list[j])
#         data_subset_team = subset_data.loc[subset_data['home_team'] == teamNames_list[j]]
# #         print(data_subset_team)
        
#         # Step 6 - 
#         # List of dates: by YEAR
#         years_list = list(subset_data['year'].unique())
        
#         # Dict:
#         dict_yearAndScores = {}

#         # Step 7 - make a list of the column['home_team_rank_points']:
#         for k, year  in enumerate(years_list):
#             print('At index: ',k, '; Current HomeTeam is: ', years_list[k])
#             data_subset_team_byYear = data_subset_team.loc[data_subset_team['year'] == years_list[k]]
# #             print(data_subset_team_byYear)
            
#             # Dictionaries and Lists:
#             input_scores = []
#             total_score = 0
#             subset_cummulative_scores = []
            
#             # Make a list of the Input Socres from subset of Data:
#             for l in data_subset_team_byYear.index:
#                 point_values = data_subset_team_byYear['home_team_rank_points'][l]
#                 input_scores.append(point_values)
            
#             # Append to Dict {dict_yearAndScores}: dict[key] = value
#             dict_yearAndScores[year] = input_scores
            
            
            
            
            
            

#         # Step 8 - Update both the Home and Away team score to the overall Dictionary: 
            
#         # Append to Dict {dict_teamScores}: dict[key] = value
#         dict_teamScores[teamNames] = dict_yearAndScores
        
#     # Append to Dict {dict_teamScores}: dict[key] = value
#     data_tournamentTypes_homeTeam[tournamentName] = dict_teamScores

# %%
# # Dict of End of Year Ranks by Tournaments:
# dict_EndYearRanks = {}

# # Step 1 - Make of Copy of the Dataset:
# data_tournaments = data_football.copy()

# # Step 2 - Change the format of the Date column to DateTime:
# data_tournaments['date'] = pd.to_datetime(data_tournaments['date'])
# data_tournaments['year'] = data_tournaments['date'].dt.year

# # Step 3 - Take a subset of the DataFrame by Tournament type:
# tournament_list = list(data_tournaments['tournament'].unique())
# data_tournamentTypes_homeTeam = {}

# for i, tournamentName in enumerate(tournament_list):
# #     print(i, tournamentName)
#     subset_data = data_tournaments[data_tournaments['tournament'] == tournamentName].iloc[:,:]
# #     print(subset_data)

#     # List of team names:
#     teamNames_list = list(subset_data['home_team'].unique())

#     # Dict:
#     dict_teamScores = {}
    
#     # Step 4 - Collect the ranking point(Home Team):
#     for j, teamNames  in enumerate(teamNames_list):
#         print(j, teamNames)

#         # Step 5 - Grab a Subset from main dataset:
#         print('At index: ',i, '; Current HomeTeam is: ', teamNames_list[j])
#         data_subset_team = subset_data.loc[subset_data['home_team'] == teamNames_list[j]]
# #         print(data_subset_team)
        
#         # Step 6 - 
#         # List of dates: by YEAR
#         years_list = list(subset_data['year'].unique())
        
#         # Dict:
#         dict_yearAndScores = {}
               
#         # Step 7 - make a list of the column['home_team_rank_points']:
#         for k, year  in enumerate(years_list):
#             print('At index: ',k, '; Current HomeTeam is: ', years_list[k])
#             data_subset_team_byYear = data_subset_team.loc[data_subset_team['year'] == years_list[k]]
# #             print(data_subset_team_byYear)
            
#             # Dictionaries and Lists:
#             input_scores = []
#             total_score = 0
#             subset_cummulative_scores = []
            
#             # Make a list of the Input Socres from subset of Data:
#             for l in data_subset_team_byYear.index:
#                 point_values = data_subset_team_byYear['home_team_rank_points'][l]
#                 input_scores.append(point_values)
                
#                 point_values2 = data_subset_team_byYear['away_team_rank_points'][l]
#                 input_scores.append(point_values2)
                
            
#             # Append to Dict {dict_yearAndScores}: dict[key] = value
#             dict_yearAndScores[year] = input_scores
            
#         # Append to Dict {dict_teamScores}: dict[key] = value
#         dict_teamScores[teamNames] = dict_yearAndScores    

#         # Step 8 - Update XXX to the overall Dictionary: 
            
# #         # Append to Dict {dict_teamScores}: dict[key] = value
# #         dict_teamScores[teamNames] = dict_yearAndScores
        
#     # Append to Dict {dict_teamScores}: dict[key] = value
#     data_tournamentTypes_homeTeam[tournamentName] = dict_teamScores

# %% [markdown]
# ## Place the Ranking Points back to the respective year: A.K.A the last game of the year

# %%
# def task1_football_processing(data_football):
#     print('Start of Processing...')
    
#     # Step 1 - make copy of dataset:
#     data_football_tournaments = data_football.copy()
    
#     # Step 2 - reformat the date column to datetime format:
#     data_football_tournaments['date'] = pd.to_datetime(data_football_tournaments['date'])
    
#     # Step 3 - Partition each competition into a Dictionary:
    
#     tournament_list = list(data_football_tournaments['tournament'].unique())
#     data_football_tournamentTypes = {}
    
#     for i, j in enumerate(tournament_list):
    
#         data_football_tournamentTypes[i] = data_football_tournaments[data_football_tournaments['tournament']== j].iloc[:,:]
 
    
#     # Step 4 - reformat the date column to datetime format:
#     data_football_tournaments['date'] = pd.to_datetime(data_football_tournaments['date'])
    
#     # Step 5 - Get the Winning Teams from each competition, then place them into a dictionary.
#     #          This step should make a Nested Dictionary of the required data.
#     dict_winners_inEachYear_allTournaments = {}

#     # For all tournaments:
#     for i, dataframe_tournaments in data_football_tournamentTypes.items():
#     #     print(i, pd.DataFrame(dataframe_tournaments))
#         print('Tournament index (OuterLoop):', i)

#         # Time Calculations:
#         dataframe_tournaments['year'], dataframe_tournaments['month'] = dataframe_tournaments['date'].dt.year, dataframe_tournaments['date'].dt.month
#         inYear = dataframe_tournaments['year'].unique()
# #         print(inYear)

#         # Number of Games played in each year: 
#         nb_gamesPlayed_inThisTournament = dataframe_tournaments.year.value_counts().to_frame()
# #         print('Length of nb_game: ',len(nb_gamesPlayed_inThisTournament))

#         dict_winners_inEachYear = {}
#         df_forAppend = []

#         # for individual tournaments:
#         for k in range(len(nb_gamesPlayed_inThisTournament)):
#             print(k)
#             idx_game = nb_gamesPlayed_inThisTournament.get_value(nb_gamesPlayed_inThisTournament.index[k], col = 'year')
#             print('index: ' , idx_game)

#             gameYear = nb_gamesPlayed_inThisTournament.index[k]
#             print('The yr of this game: ', gameYear, ' and there were ', idx_game, ' played.')

#             # take out the winners from this game (from the main Dataframe):
#             temp_series = dataframe_tournaments[dataframe_tournaments['year'] == gameYear].iloc[idx_game-1,:]
#             temp_df = temp_series.to_frame()
#             temp_df = temp_df.transpose()        
#             df_forAppend.append(temp_df)

#             # Find index for key/value: key part -> key_tournamentName
#             index_temp_df = temp_df.index
#             key_tournamentName = temp_df.get_value(index_temp_df[0], col = 'tournament')

#             # Append to the Dictionary for a specific Tournament:
#             dict_winners_inEachYear[key_tournamentName] = df_forAppend

#     #         print(dict_winners_inEachYear)

#             # ==== End of Loop ====
#         dict_winners_inEachYear_allTournaments[i] = dict_winners_inEachYear
#         print('--- Adding innder dictionary data to the partial Nested Dict: Complete.')
        
#         data_final = dict_winners_inEachYear_allTournaments
        
#     return data_final;

# %%
# tournament_list = list(data_tournaments['tournament'].unique())
# teamNames_list = list(subset_data['home_team'].unique())
# years_list = list(subset_data['year'].unique())

# %% [markdown]
# ## Find the Winning teams in each of the tournaments.
# This is done by taking the last teams (a.k.a Winning Teams) in each competition year, for individual types of tournament.

# %%
# def task1_football_processing(data_football):
#     print('Start of Processing...')
    
#     # Step 1 - make copy of dataset:
#     data_football_tournaments = data_football.copy()
    
#     # Step 2 - reformat the date column to datetime format:
#     data_football_tournaments['date'] = pd.to_datetime(data_football_tournaments['date'])
    
#     # Step 3 - Partition each competition into a Dictionary:
    
#     tournament_list = list(data_football_tournaments['tournament'].unique())
#     data_football_tournamentTypes = {}
    
#     for i, j in enumerate(tournament_list):
    
#         data_football_tournamentTypes[i] = data_football_tournaments[data_football_tournaments['tournament']== j].iloc[:,:]
 
    
#     # Step 4 - reformat the date column to datetime format:
#     data_football_tournaments['date'] = pd.to_datetime(data_football_tournaments['date'])
    
#     # Step 5 - Get the Winning Teams from each competition, then place them into a dictionary.
#     #          This step should make a Nested Dictionary of the required data.
#     dict_winners_inEachYear_allTournaments = {}

#     # For all tournaments:
#     for i, dataframe_tournaments in data_football_tournamentTypes.items():
#     #     print(i, pd.DataFrame(dataframe_tournaments))
#         print('Tournament index (OuterLoop):', i)

#         # Time Calculations:
#         dataframe_tournaments['year'], dataframe_tournaments['month'] = dataframe_tournaments['date'].dt.year, dataframe_tournaments['date'].dt.month
#         inYear = dataframe_tournaments['year'].unique()
# #         print(inYear)

#         # Number of Games played in each year: 
#         nb_gamesPlayed_inThisTournament = dataframe_tournaments.year.value_counts().to_frame()
# #         print('Length of nb_game: ',len(nb_gamesPlayed_inThisTournament))

#         dict_winners_inEachYear = {}
#         df_forAppend = []

#         # for individual tournaments:
#         for k in range(len(nb_gamesPlayed_inThisTournament)):
#             print(k)
#             idx_game = nb_gamesPlayed_inThisTournament.get_value(nb_gamesPlayed_inThisTournament.index[k], col = 'year')
#             print('index: ' , idx_game)

#             gameYear = nb_gamesPlayed_inThisTournament.index[k]
#             print('The yr of this game: ', gameYear, ' and there were ', idx_game, ' played.')

#             # take out the winners from this game (from the main Dataframe):
#             temp_series = dataframe_tournaments[dataframe_tournaments['year'] == gameYear].iloc[idx_game-1,:]
#             temp_df = temp_series.to_frame()
#             temp_df = temp_df.transpose()        
#             df_forAppend.append(temp_df)

#             # Find index for key/value: key part -> key_tournamentName
#             index_temp_df = temp_df.index
#             key_tournamentName = temp_df.get_value(index_temp_df[0], col = 'tournament')

#             # Append to the Dictionary for a specific Tournament:
#             dict_winners_inEachYear[key_tournamentName] = df_forAppend

#     #         print(dict_winners_inEachYear)

#             # ==== End of Loop ====
#         dict_winners_inEachYear_allTournaments[i] = dict_winners_inEachYear
#         print('--- Adding innder dictionary data to the partial Nested Dict: Complete.')
        
#         data_final = dict_winners_inEachYear_allTournaments
        
#     return data_final;

# %%
# def task1_football_convert2DataFrame(data, data_football):
    
#     dict_winners_inEachYear_allTournaments = data
    
#     categorical = list(data_football['tournament'].unique())

#     champion_df = pd.DataFrame()

#     for i, tournament_names in enumerate(categorical):
#         print(i, tournament_names)
#         dict_temp = dict_winners_inEachYear_allTournaments[i]
#         dict_temp_tour = dict_temp[tournament_names]
#         champion_df = champion_df.append(dict_temp_tour, ignore_index = True)

#     return champion_df;

# %% [markdown]
# ### Perform the processing on the dataset for Task 1:
# This will be a 2 stage process.

# %%
# # Part 1 - Process the Dataset:
# data_football_task1 = task1_football_processing(data_football)
# type(data_football_task1)

# %%
# Part 2 - Extract the information into single Dataframe:
# data_football_task1_df = task1_football_convert2DataFrame(data_football_task1, data_football)

# %%
# data_football_task1_df.head()

# %% [markdown]
# ### Label which Teams won their Championships:

# %%
# def task1_winningTeam(data):
    
#     data_football = data
    
#     data_football['winning_team'] = np.nan

#     list_teamOutcomes = []

#     for idx in range(len(data_football)):
# #         print(idx)
#         if (data_football['home_score'][idx] > data_football['away_score'][idx]):
# #             print('home')
#             list_teamOutcomes.append('home')

#         elif (data_football['home_score'][idx] < data_football['away_score'][idx]):
# #             print('away')
#             list_teamOutcomes.append('away')

#         else:
# #             print('draw')
#             list_teamOutcomes.append('draw')

#     data_football['winning_team'] = list_teamOutcomes
    
#     return data_football;

# %%
# data_football_task1_v2 = task1_winningTeam(data_football_task1_df)
# data_football_task1_v2.head()

# %%
# data_football_task1_v2.head(20)

# %% [markdown]
# ## Cummulative count of the Ranking points over the years:

# %%
# def task1_createDict_rankingCummulative(data):
    
#     homeTeam_list = list(data['home_team'].unique())

#     dict_homeTeam_withTotalScores = {}

#     for i, home_team_name in enumerate(homeTeam_list):
# #         print(i, home_team_name)

#         # Step 1 - Grab a Subset from main dataset:
#         print('At index: ',i, '; Current HomeTeam is: ', homeTeam_list[i])
#         data_subset = data.loc[data['home_team'] == homeTeam_list[i]]

#         # Step 2 - Perform Calculations on Ranking Points: 2 stages.
#         input_scores = []
#         total_score = 0
#         subset_cummulative_scores = []

#         # Make a list of Input Scores from subset of Data:
#         for j in data_subset.index:
#             point_values = data_subset['rank_points'][j]
#             input_scores.append(point_values)
#         print('input scores: ', input_scores)

#         # Cummulative Calculations:
#         for values in input_scores:
#             total_score = total_score + values
#             subset_cummulative_scores.append(total_score)

#         print('Subset Cummulative scores: ', subset_cummulative_scores)

#         # Step 3 - Save the total scores for each of the homeTeams in a Dictionary:
#         dict_homeTeam_withTotalScores[home_team_name] = subset_cummulative_scores
    
#     return dict_homeTeam_withTotalScores;

# %%
# def task1_convert2DF_rankingCummulative(dict_homeTeam_withTotalScores, data_football_task1_v2):
   
#     data_rankingOverTime = data_football_task1_v2.copy()

#     homeTeam_list = list(data_rankingOverTime['home_team'].unique())

#     data_football_rankingOverTime = pd.DataFrame()

#     for i, home_team_name in enumerate(homeTeam_list):
#         print(i, home_team_name)

#         # Get the indexes from subset data:
#         data_subset = data_rankingOverTime[data_rankingOverTime['home_team'] == home_team_name].iloc[:,:]
#         index_df = data_subset.index

#         # Convert cummulative scores into a dataframe(from list), with the correct indexing by homeTeams:
#         list_score = dict_homeTeam_withTotalScores[home_team_name]
#         df_temp = pd.DataFrame(list_score, columns=['RankOverTime'], index = index_df)

#         # Combine the temporary Dataframe with the Subset of Data taken:
#         mergedDf = pd.merge(data_subset, df_temp, left_index=True, right_index=True)

#         # Append to the main Dataset with mergeDf:
#         data_football_rankingOverTime = data_football_rankingOverTime.append(mergedDf, ignore_index = True)

    
#     return data_football_rankingOverTime;

# %%
# Output Dictionary:
# dict_homeTeam_withTotalScores = task1_createDict_rankingCummulative(data_football)

# %%
# Output DataFrame:
# data_football_rankingOverTime2 = task1_convert2DF_rankingCummulative(dict_homeTeam_withTotalScores, data_football)

# %%
# data_football_rankingOverTime2.head()

# %%
# def task1_football_processing(data_football):
#     print('Start of Processing...')
    
#     # Step 1 - make copy of dataset:
#     data_football_tournaments = data_football.copy()
    
#     # Step 2 - reformat the date column to datetime format:
#     data_football_tournaments['date'] = pd.to_datetime(data_football_tournaments['date'])
    
#     # Step 3 - Partition each competition into a Dictionary:
    
#     tournament_list = list(data_football_tournaments['tournament'].unique())
#     data_football_tournamentTypes = {}
    
#     for i, j in enumerate(tournament_list):
    
#         data_football_tournamentTypes[i] = data_football_tournaments[data_football_tournaments['tournament']== j].iloc[:,:]
 
    
#     # Step 4 - reformat the date column to datetime format:
#     data_football_tournaments['date'] = pd.to_datetime(data_football_tournaments['date'])
    
#     # Step 5 - Get the Winning Teams from each competition, then place them into a dictionary.
#     #          This step should make a Nested Dictionary of the required data.
#     dict_winners_inEachYear_allTournaments = {}

#     # For all tournaments:
#     for i, dataframe_tournaments in data_football_tournamentTypes.items():
#     #     print(i, pd.DataFrame(dataframe_tournaments))
#         print('Tournament index (OuterLoop):', i)

#         # Time Calculations:
#         dataframe_tournaments['year'], dataframe_tournaments['month'] = dataframe_tournaments['date'].dt.year, dataframe_tournaments['date'].dt.month
#         inYear = dataframe_tournaments['year'].unique()
# #         print(inYear)

#         # Number of Games played in each year: 
#         nb_gamesPlayed_inThisTournament = dataframe_tournaments.year.value_counts().to_frame()
# #         print('Length of nb_game: ',len(nb_gamesPlayed_inThisTournament))

#         dict_winners_inEachYear = {}
#         df_forAppend = []

#         # for individual tournaments:
#         for k in range(len(nb_gamesPlayed_inThisTournament)):
#             print(k)
#             idx_game = nb_gamesPlayed_inThisTournament.get_value(nb_gamesPlayed_inThisTournament.index[k], col = 'year')
#             print('index: ' , idx_game)

#             gameYear = nb_gamesPlayed_inThisTournament.index[k]
#             print('The yr of this game: ', gameYear, ' and there were ', idx_game, ' played.')

#             # take out the winners from this game (from the main Dataframe):
#             temp_series = dataframe_tournaments[dataframe_tournaments['year'] == gameYear].iloc[idx_game-1,:]
#             temp_df = temp_series.to_frame()
#             temp_df = temp_df.transpose()        
#             df_forAppend.append(temp_df)

#             # Find index for key/value: key part -> key_tournamentName
#             index_temp_df = temp_df.index
#             key_tournamentName = temp_df.get_value(index_temp_df[0], col = 'tournament')

#             # Append to the Dictionary for a specific Tournament:
#             dict_winners_inEachYear[key_tournamentName] = df_forAppend

#     #         print(dict_winners_inEachYear)

#             # ==== End of Loop ====
#         dict_winners_inEachYear_allTournaments[i] = dict_winners_inEachYear
#         print('--- Adding innder dictionary data to the partial Nested Dict: Complete.')
        
#         data_final = dict_winners_inEachYear_allTournaments
        
#     return data_final;
